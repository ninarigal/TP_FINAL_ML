# %%
import pandas as pd
import numpy as np
from category_encoders import TargetEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import joblib

# %%
# Cargar los datos
data = pd.read_csv('fixed_dataset.csv')

# A la columna de Kilómetros le sacamos el km y lo convertimos a número
data['Kilómetros'] = data['Kilómetros'].str.replace(' km', '').str.replace(',', '').astype(int)

# Definir las características (features) y el objetivo (target)
X = data[['Kilómetros', 'Edad']]
y = data['Precio']

# %%
for modelo in data['Modelo'].unique():

    print(f"Modelo: {modelo}")
    X_modelo = X[data['Modelo'] == modelo]
    y_modelo = y[data['Modelo'] == modelo]

    precios_okm = y_modelo[X_modelo['Kilómetros'] == 0]

    if len(precios_okm) < 2:
        print("Cantidad de precios 0km: ", len(precios_okm))
        print("No hay suficientes datos para entrenar el modelo para el modelo ", modelo)
        print()
        continue

    if len(X_modelo) < len(precios_okm) + 2:
        print("Cantidad de datos: ", len(X_modelo))
        print("Cantidad de precios 0km: ", len(precios_okm))
        print("No hay suficientes datos para entrenar el modelo para el modelo ", modelo)
        print()
        continue

    # Calcular Q1 y Q3
    Q1 = np.percentile(precios_okm, 25)
    Q3 = np.percentile(precios_okm, 75)

    # Calcular el rango intercuartil (IQR)
    IQR = Q3 - Q1

    # Determinar los límites
    limite_inferior = Q1 - 1.5 * IQR
    limite_superior = Q3 + 1.5 * IQR

    # Filtrar los outliers
    datos_filtrados = [x for x in precios_okm if limite_inferior <= x <= limite_superior]

    # Calcular el promedio sin outliers
    precio_okm = np.mean(datos_filtrados)

    # Filtrar datos donde los kilómetros no son 0
    X_modelo = X_modelo[X_modelo['Kilómetros'] != 0]
    y_modelo = y_modelo[X_modelo.index]

    y_modelo = precio_okm - y_modelo

    # Dividir los datos en entrenamiento y prueba
    X_train, X_test, y_train, y_test = train_test_split(X_modelo, y_modelo, test_size=0.2, random_state=42)

    # Entrenar el modelo
    model = LinearRegression()
    model.fit(X_train, y_train)

    # Predecir los precios
    y_pred = model.predict(X_test)

    # Evaluar el modelo
    mse = mean_squared_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)
    print(f"Mean Squared Error: {mse}")
    print(f"R^2: {r2}")
    print()

    # # Guardar el modelo
    # joblib.dump(model, f'model_{modelo}.joblib')
    # print(f"Modelo guardado en model_{modelo}.joblib")
    # print()
# Out:
# Modelo: 2008
# Mean Squared Error: 2756223.089244061
# R^2: 0.7176594149122152
#
# Modelo: 208
# Cantidad de datos:  3
# Cantidad de precios 0km:  3
# No hay suficientes datos para entrenar el modelo para el modelo  208
#
# Modelo: 3008
# Mean Squared Error: 20103663.43789289
# R^2: 0.7541547826269408
#
# Modelo: 4008
# Cantidad de precios 0km:  0
# No hay suficientes datos para entrenar el modelo para el modelo  4008
#
# Modelo: 4Runner
# Cantidad de precios 0km:  0
# No hay suficientes datos para entrenar el modelo para el modelo  4Runner
#
# Modelo: 5008
# Mean Squared Error: 1844602.755428766
# R^2: nan
#
# Modelo: 500X
# Cantidad de precios 0km:  0
# No hay suficientes datos para entrenar el modelo para el modelo  500X
#
# Modelo: DS7
# Cantidad de datos:  19
# Cantidad de precios 0km:  18
# No hay suficientes datos para entrenar el modelo para el modelo  DS7
#
# Modelo: Actyon
# Cantidad de precios 0km:  0
# No hay suficientes datos para entrenar el modelo para el modelo  Actyon
#
# Modelo: Agile
# Cantidad de precios 0km:  0
# No hay suficientes datos para entrenar el modelo para el modelo  Agile
#
# Modelo: Aircross
# Cantidad de datos:  4
# Cantidad de precios 0km:  3
# No hay suficientes datos para entrenar el modelo para el modelo  Aircross
#
# Modelo: Amigo
# Cantidad de precios 0km:  0
# No hay suficientes datos para entrenar el modelo para el modelo  Amigo
#
# Modelo: Blazer
# Cantidad de precios 0km:  0
# No hay suficientes datos para entrenar el modelo para el modelo  Blazer
#
# Modelo: Bronco
# Mean Squared Error: 150204115.12583205
# R^2: nan
#
# Modelo: Bronco Sport
# Mean Squared Error: 17240633.3129272
# R^2: 0.44431909919848434
#
# Modelo: C-HR
# Cantidad de precios 0km:  0
# No hay suficientes datos para entrenar el modelo para el modelo  C-HR
#
# Modelo: C3
# Mean Squared Error: 268.219996882818
# R^2: nan
#
# Modelo: C3 Aircross
# Cantidad de datos:  12
# Cantidad de precios 0km:  12
# No hay suficientes datos para entrenar el modelo para el modelo  C3 Aircross
#
# Modelo: C4
# Cantidad de precios 0km:  1
# No hay suficientes datos para entrenar el modelo para el modelo  C4
#
# Modelo: C4 Aircross
# Cantidad de precios 0km:  0
# No hay suficientes datos para entrenar el modelo para el modelo  C4 Aircross
#
# Modelo: C4 Cactus
# Mean Squared Error: 2489776.4658397506
# R^2: 0.7179728664503721
#
# Modelo: C5 Aircross
# Mean Squared Error: 15519849.67009717
# R^2: 0.3658813068805358
#
# Modelo: Captiva
# Cantidad de precios 0km:  0
# No hay suficientes datos para entrenar el modelo para el modelo  Captiva
#
# Modelo: Captur
# Mean Squared Error: 2644195.4954956993
# R^2: 0.41848529846872307
#
# Modelo: Cayenne
# Mean Squared Error: 262836757.2020012
# R^2: 0.12573932742566352
#
# Modelo: Cherokee
# Mean Squared Error: 12049011.649011595
# R^2: 0.5314938981070276
#
# Modelo: Clase E
# Cantidad de precios 0km:  0
# No hay suficientes datos para entrenar el modelo para el modelo  Clase E
#
# Modelo: Clase GL
# Cantidad de precios 0km:  0
# No hay suficientes datos para entrenar el modelo para el modelo  Clase GL
#
# Modelo: Clase GLA
# Mean Squared Error: 76965589.23862691
# R^2: 0.7564697354916259
#
# Modelo: Clase GLB
# Mean Squared Error: 105859965.41263653
# R^2: -0.3752786025450565
#
# Modelo: Clase GLC
# Cantidad de precios 0km:  0
# No hay suficientes datos para entrenar el modelo para el modelo  Clase GLC
#
# Modelo: Clase GLE
# Mean Squared Error: 1171874286.7514858
# R^2: 0.1833117024185098
#
# Modelo: Clase GLK
# Cantidad de precios 0km:  0
# No hay suficientes datos para entrenar el modelo para el modelo  Clase GLK
#
# Modelo: Clase ML
# Cantidad de precios 0km:  0
# No hay suficientes datos para entrenar el modelo para el modelo  Clase ML
#
# Modelo: Commander
# Mean Squared Error: 161498569.7425662
# R^2: -0.18956095046759214
#
# Modelo: Compass
# Mean Squared Error: 7090022457.414195
# R^2: 0.004696996121896557
#
# Modelo: Cooper Countryman
# Mean Squared Error: 6080100624.999993
# R^2: nan
#
# Modelo: Corolla Cross
# Mean Squared Error: 9679026.072005566
# R^2: 0.3780233859502261
#
# Modelo: Countryman
# Cantidad de datos:  2
# Cantidad de precios 0km:  2
# No hay suficientes datos para entrenar el modelo para el modelo  Countryman
#
# Modelo: Coupe
# Cantidad de precios 0km:  0
# No hay suficientes datos para entrenar el modelo para el modelo  Coupe
#
# Modelo: CR-V
# Mean Squared Error: 22507373.678802073
# R^2: 0.6416972203166738
#
# Modelo: Creta
# Mean Squared Error: 12255499.534062771
# R^2: 0.7707796672558628
#
# Modelo: Crossfox
# Cantidad de precios 0km:  0
# No hay suficientes datos para entrenar el modelo para el modelo  Crossfox
#
# Modelo: Defender
# Cantidad de precios 0km:  1
# No hay suficientes datos para entrenar el modelo para el modelo  Defender
#
# Modelo: Discovery
# Cantidad de precios 0km:  0
# No hay suficientes datos para entrenar el modelo para el modelo  Discovery
#
# Modelo: DS3
# Cantidad de datos:  5
# Cantidad de precios 0km:  5
# No hay suficientes datos para entrenar el modelo para el modelo  DS3
#
# Modelo: DS7 Crossback
# Mean Squared Error: 176486829.2550264
# R^2: -0.12053351061111028
#
# Modelo: Duster
# Mean Squared Error: 52820363.25760687
# R^2: 0.03009104037558763
#
# Modelo: Duster Oroch
# Mean Squared Error: 5439688.360648864
# R^2: 0.2894175379835553
#
# Modelo: E-tron
# Cantidad de datos:  4
# Cantidad de precios 0km:  3
# No hay suficientes datos para entrenar el modelo para el modelo  E-tron
#
# Modelo: Ecosport
# Mean Squared Error: 832515653.5756077
# R^2: -0.009557125910971465
#
# Modelo: Emgrand X7 Sport
# Cantidad de precios 0km:  0
# No hay suficientes datos para entrenar el modelo para el modelo  Emgrand X7 Sport
#
# Modelo: Equinox
# Mean Squared Error: 16758448.252067367
# R^2: 0.5471308369238899
#
# Modelo: Evoque
# Cantidad de precios 0km:  0
# No hay suficientes datos para entrenar el modelo para el modelo  Evoque
#
# Modelo: Explorer
# Cantidad de precios 0km:  0
# No hay suficientes datos para entrenar el modelo para el modelo  Explorer
#
# Modelo: F-PACE
# Cantidad de precios 0km:  0
# No hay suficientes datos para entrenar el modelo para el modelo  F-PACE
#
# Modelo: Feroza
# Cantidad de precios 0km:  0
# No hay suficientes datos para entrenar el modelo para el modelo  Feroza
#
# Modelo: Forester
# Cantidad de precios 0km:  1
# No hay suficientes datos para entrenar el modelo para el modelo  Forester
#
# Modelo: Freelander
# Cantidad de precios 0km:  0
# No hay suficientes datos para entrenar el modelo para el modelo  Freelander
#
# Modelo: Galloper
# Cantidad de precios 0km:  0
# No hay suficientes datos para entrenar el modelo para el modelo  Galloper
#
# Modelo: Grand Blazer
# Cantidad de precios 0km:  0
# No hay suficientes datos para entrenar el modelo para el modelo  Grand Blazer
#
# Modelo: Grand Cherokee
# Mean Squared Error: 176628484.55387488
# R^2: 0.5634598367003141
#
# Modelo: Grand Santa Fé
# Cantidad de precios 0km:  0
# No hay suficientes datos para entrenar el modelo para el modelo  Grand Santa Fé
#
# Modelo: Grand Vitara
# Cantidad de precios 0km:  0
# No hay suficientes datos para entrenar el modelo para el modelo  Grand Vitara
#
# Modelo: H1
# Cantidad de precios 0km:  1
# No hay suficientes datos para entrenar el modelo para el modelo  H1
#
# Modelo: H6
# Mean Squared Error: 17965165.630341064
# R^2: nan
#
# Modelo: Hilux
# Cantidad de precios 0km:  0
# No hay suficientes datos para entrenar el modelo para el modelo  Hilux
#
# Modelo: Hilux SW4
# Mean Squared Error: 24947043.041896228
# R^2: 0.7721208914531588
#
# Modelo: HR-V
# Mean Squared Error: 4325663.982728696
# R^2: 0.6764777729040979
#
# Modelo: Jimny
# Cantidad de precios 0km:  0
# No hay suficientes datos para entrenar el modelo para el modelo  Jimny
#
# Modelo: Jolion
# Cantidad de datos:  2
# Cantidad de precios 0km:  2
# No hay suficientes datos para entrenar el modelo para el modelo  Jolion
#
# Modelo: Journey
# Cantidad de precios 0km:  0
# No hay suficientes datos para entrenar el modelo para el modelo  Journey
#
# Modelo: Kangoo
# Cantidad de datos:  5
# Cantidad de precios 0km:  4
# No hay suficientes datos para entrenar el modelo para el modelo  Kangoo
#
# Modelo: Kicks
# Mean Squared Error: 1807743.321999035
# R^2: 0.8370224411269722
#
# Modelo: Koleos
# Cantidad de precios 0km:  1
# No hay suficientes datos para entrenar el modelo para el modelo  Koleos
#
# Modelo: Kona
# Cantidad de precios 0km:  0
# No hay suficientes datos para entrenar el modelo para el modelo  Kona
#
# Modelo: Kuga
# Mean Squared Error: 17409860.790496767
# R^2: 0.8461349030122756
#
# Modelo: Land Cruiser
# Cantidad de precios 0km:  0
# No hay suficientes datos para entrenar el modelo para el modelo  Land Cruiser
#
# Modelo: LX
# Cantidad de precios 0km:  0
# No hay suficientes datos para entrenar el modelo para el modelo  LX
#
# Modelo: Macan
# Mean Squared Error: 69119005.28578958
# R^2: 0.7114029006856385
#
# Modelo: Mohave
# Cantidad de precios 0km:  0
# No hay suficientes datos para entrenar el modelo para el modelo  Mohave
#
# Modelo: Montero
# Cantidad de precios 0km:  0
# No hay suficientes datos para entrenar el modelo para el modelo  Montero
#
# Modelo: Murano
# Cantidad de precios 0km:  0
# No hay suficientes datos para entrenar el modelo para el modelo  Murano
#
# Modelo: Musso
# Cantidad de precios 0km:  0
# No hay suficientes datos para entrenar el modelo para el modelo  Musso
#
# Modelo: Mustang
# Cantidad de datos:  3
# Cantidad de precios 0km:  3
# No hay suficientes datos para entrenar el modelo para el modelo  Mustang
#
# Modelo: Myway
# Cantidad de precios 0km:  0
# No hay suficientes datos para entrenar el modelo para el modelo  Myway
#
# Modelo: Nativa
# Cantidad de precios 0km:  0
# No hay suficientes datos para entrenar el modelo para el modelo  Nativa
#
# Modelo: Nivus
# Mean Squared Error: 9564298.720963318
# R^2: 0.09714286434654329
#
# Modelo: NX
# Cantidad de precios 0km:  0
# No hay suficientes datos para entrenar el modelo para el modelo  NX
#
# Modelo: Oroch
# Mean Squared Error: 11633775.986549765
# R^2: 0.2873520811441449
#
# Modelo: Outback
# Cantidad de precios 0km:  0
# No hay suficientes datos para entrenar el modelo para el modelo  Outback
#
# Modelo: Outlander
# Cantidad de precios 0km:  0
# No hay suficientes datos para entrenar el modelo para el modelo  Outlander
#
# Modelo: Panamera
# Cantidad de precios 0km:  0
# No hay suficientes datos para entrenar el modelo para el modelo  Panamera
#
# Modelo: Pathfinder
# Cantidad de precios 0km:  0
# No hay suficientes datos para entrenar el modelo para el modelo  Pathfinder
#
# Modelo: Patriot
# Cantidad de precios 0km:  0
# No hay suficientes datos para entrenar el modelo para el modelo  Patriot
#
# Modelo: Pilot
# Cantidad de precios 0km:  1
# No hay suficientes datos para entrenar el modelo para el modelo  Pilot
#
# Modelo: Pulse
# Mean Squared Error: 39789190.10788938
# R^2: -0.513612481153094
#
# Modelo: Q2
# Mean Squared Error: 18878928.214652523
# R^2: 0.47896024459817366
#
# Modelo: Q3
# Mean Squared Error: 15054420.168136979
# R^2: 0.6843997392784988
#
# Modelo: Q3 Sportback
# Mean Squared Error: 6918187.5114686005
# R^2: -0.11543689722711226
#
# Modelo: Q5
# Mean Squared Error: 80446201.91215067
# R^2: 0.8058003807227107
#
# Modelo: q5 sportback
# Cantidad de datos:  34
# Cantidad de precios 0km:  34
# No hay suficientes datos para entrenar el modelo para el modelo  q5 sportback
#
# Modelo: Q7
# Mean Squared Error: 79348858.30767272
# R^2: 0.7126033440567572
#
# Modelo: Q8
# Mean Squared Error: 329534380.33827364
# R^2: -0.4271884174555025
#
# Modelo: Range Rover
# Cantidad de precios 0km:  0
# No hay suficientes datos para entrenar el modelo para el modelo  Range Rover
#
# Modelo: Range Rover Sport
# Cantidad de precios 0km:  0
# No hay suficientes datos para entrenar el modelo para el modelo  Range Rover Sport
#
# Modelo: RAV4
# Cantidad de precios 0km:  0
# No hay suficientes datos para entrenar el modelo para el modelo  RAV4
#
# Modelo: Renegade
# Mean Squared Error: 8594329.334756203
# R^2: 0.5843714707699708
#
# Modelo: Rodeo
# Cantidad de precios 0km:  0
# No hay suficientes datos para entrenar el modelo para el modelo  Rodeo
#
# Modelo: S2
# Cantidad de datos:  3
# Cantidad de precios 0km:  3
# No hay suficientes datos para entrenar el modelo para el modelo  S2
#
# Modelo: S5
# Cantidad de precios 0km:  0
# No hay suficientes datos para entrenar el modelo para el modelo  S5
#
# Modelo: Samurai
# Cantidad de precios 0km:  0
# No hay suficientes datos para entrenar el modelo para el modelo  Samurai
#
# Modelo: Sandero
# Mean Squared Error: 171005917.1597633
# R^2: nan
#
# Modelo: Sandero Stepway
# Mean Squared Error: 7633143.180432381
# R^2: -2.4812199673874735
#
# Modelo: Santa Fe
# Cantidad de precios 0km:  0
# No hay suficientes datos para entrenar el modelo para el modelo  Santa Fe
#
# Modelo: Seltos
# Mean Squared Error: 1537600.0000000023
# R^2: nan
#
# Modelo: Serie 4
# Cantidad de precios 0km:  0
# No hay suficientes datos para entrenar el modelo para el modelo  Serie 4
#
# Modelo: Sorento
# Cantidad de precios 0km:  1
# No hay suficientes datos para entrenar el modelo para el modelo  Sorento
#
# Modelo: Soul
# Cantidad de precios 0km:  0
# No hay suficientes datos para entrenar el modelo para el modelo  Soul
#
# Modelo: Spin
# Cantidad de precios 0km:  1
# No hay suficientes datos para entrenar el modelo para el modelo  Spin
#
# Modelo: Sportage
# Mean Squared Error: 16137660.498713404
# R^2: 0.7864321207912002
#
# Modelo: SQ5
# Cantidad de precios 0km:  0
# No hay suficientes datos para entrenar el modelo para el modelo  SQ5
#
# Modelo: Stelvio
# Mean Squared Error: 19597486.285803147
# R^2: 0.9281619968822211
#
# Modelo: Suran
# Cantidad de precios 0km:  0
# No hay suficientes datos para entrenar el modelo para el modelo  Suran
#
# Modelo: SW4
# Mean Squared Error: 33339685.73931083
# R^2: 0.7981761152002289
#
# Modelo: T-Cross
# Mean Squared Error: 17323210.42119267
# R^2: -0.13129013951736845
#
# Modelo: Taos
# Mean Squared Error: 33432138.32093667
# R^2: -0.08762114989669922
#
# Modelo: Terios
# Cantidad de precios 0km:  0
# No hay suficientes datos para entrenar el modelo para el modelo  Terios
#
# Modelo: Terrano II
# Cantidad de precios 0km:  0
# No hay suficientes datos para entrenar el modelo para el modelo  Terrano II
#
# Modelo: Territory
# Mean Squared Error: 17399293.01214409
# R^2: 0.4557706161850752
#
# Modelo: Tiggo
# Cantidad de precios 0km:  0
# No hay suficientes datos para entrenar el modelo para el modelo  Tiggo
#
# Modelo: Tiggo 2
# Cantidad de precios 0km:  1
# No hay suficientes datos para entrenar el modelo para el modelo  Tiggo 2
#
# Modelo: Tiggo 3
# Cantidad de precios 0km:  0
# No hay suficientes datos para entrenar el modelo para el modelo  Tiggo 3
#
# Modelo: Tiggo 4
# Mean Squared Error: 1708140.8347461217
# R^2: 0.1875667849007745
#
# Modelo: Tiggo 4 Pro
# Mean Squared Error: 158669929.4555475
# R^2: nan
#
# Modelo: Tiggo 5
# Cantidad de precios 0km:  0
# No hay suficientes datos para entrenar el modelo para el modelo  Tiggo 5
#
# Modelo: Tiggo 8 Pro
# Mean Squared Error: 0.0
# R^2: nan
#
# Modelo: Tiguan
# Mean Squared Error: 8959615.883653203
# R^2: 0.7087114640481673
#
# Modelo: Tiguan Allspace
# Mean Squared Error: 27917923.63202686
# R^2: 0.5043755410547179
#
# Modelo: Touareg
# Cantidad de precios 0km:  0
# No hay suficientes datos para entrenar el modelo para el modelo  Touareg
#
# Modelo: Tracker
# /Users/ninarigal/Library/Python/3.9/lib/python/site-packages/sklearn/metrics/_regression.py:1187: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/ninarigal/Library/Python/3.9/lib/python/site-packages/sklearn/metrics/_regression.py:1187: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/ninarigal/Library/Python/3.9/lib/python/site-packages/sklearn/metrics/_regression.py:1187: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/ninarigal/Library/Python/3.9/lib/python/site-packages/sklearn/metrics/_regression.py:1187: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/ninarigal/Library/Python/3.9/lib/python/site-packages/sklearn/metrics/_regression.py:1187: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/ninarigal/Library/Python/3.9/lib/python/site-packages/sklearn/metrics/_regression.py:1187: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/ninarigal/Library/Python/3.9/lib/python/site-packages/sklearn/metrics/_regression.py:1187: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/ninarigal/Library/Python/3.9/lib/python/site-packages/sklearn/metrics/_regression.py:1187: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/ninarigal/Library/Python/3.9/lib/python/site-packages/sklearn/metrics/_regression.py:1187: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# Mean Squared Error: 8251720.247326997
# R^2: 0.6918330478598613
#
# Modelo: Trailblazer
# Mean Squared Error: 6651556.148609884
# R^2: 0.9272797036922534
#
# Modelo: Trooper
# Cantidad de precios 0km:  0
# No hay suficientes datos para entrenar el modelo para el modelo  Trooper
#
# Modelo: Tucson
# Mean Squared Error: 13861134.35615627
# R^2: 0.7454924628921913
#
# Modelo: UX
# Cantidad de precios 0km:  0
# No hay suficientes datos para entrenar el modelo para el modelo  UX
#
# Modelo: Veracruz
# Cantidad de precios 0km:  0
# No hay suficientes datos para entrenar el modelo para el modelo  Veracruz
#
# Modelo: Vitara
# Cantidad de precios 0km:  0
# No hay suficientes datos para entrenar el modelo para el modelo  Vitara
#
# Modelo: Wrangler
# Mean Squared Error: 137323042.71625295
# R^2: 0.669765192785714
#
# Modelo: X-Terra
# Cantidad de precios 0km:  0
# No hay suficientes datos para entrenar el modelo para el modelo  X-Terra
#
# Modelo: X-Trail
# Mean Squared Error: 41217078.91262835
# R^2: 0.8132867137720659
#
# Modelo: X1
# Mean Squared Error: 18035170.282592393
# R^2: 0.8687846694654378
#
# Modelo: X2
# Mean Squared Error: 86010075.12602083
# R^2: 0.3630521564336846
#
# Modelo: X25
# Cantidad de precios 0km:  0
# No hay suficientes datos para entrenar el modelo para el modelo  X25
#
# Modelo: X3
# Mean Squared Error: 780831367.1276287
# R^2: 0.4281438172306219
#
# Modelo: X35
# Mean Squared Error: 1416598.4054616117
# R^2: -5.128771341389147
#
# Modelo: X4
# Cantidad de precios 0km:  0
# No hay suficientes datos para entrenar el modelo para el modelo  X4
#
# Modelo: X5
# Mean Squared Error: 141318738.58098054
# R^2: 0.8439347146327536
#
# Modelo: X55
# Mean Squared Error: 20642102.63667133
# R^2: nan
#
# Modelo: X6
# Cantidad de precios 0km:  0
# No hay suficientes datos para entrenar el modelo para el modelo  X6
#
# Modelo: X70
# Mean Squared Error: 98104484.22328544
# R^2: -8.523199288752384
#
# Modelo: XC40
# Mean Squared Error: 86663715.66534865
# R^2: 0.2925555342515569
#
# Modelo: XC60
# Cantidad de precios 0km:  1
# No hay suficientes datos para entrenar el modelo para el modelo  XC60
# /Users/ninarigal/Library/Python/3.9/lib/python/site-packages/sklearn/metrics/_regression.py:1187: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
