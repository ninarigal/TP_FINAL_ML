# %%
# %load_ext autoreload
# %autoreload 2
import pandas as pd
import numpy as np

# %%
file_path = r'/Users/ninarigal/UDESA/TERCER AÑO/APRENDIZAJE AUTOMÁTICO Y APRENDIZAJE AUTÓNOMO/TP_FINAL_ML/pf_suvs_i302_1s2024.csv'
data = pd.read_csv(file_path)

peugeot = data[data['Marca'] == 'Peugeot']

# %%
peugeot
# Out:
#        Marca Modelo     Año                    Versión     Color  \
# 0    Peugeot   2008  2022.0        1.6 Feline Tip am20    Blanco
# 1    Peugeot   2008  2021.0                 1.6 Allure    Marrón
# 2    Peugeot   2008  2021.0                 1.6 Allure    Marrón
# 3    Peugeot   2008  2018.0                 1.6 Feline    Blanco
# 4    Peugeot   2008  2016.0              1.6 Thp Sport      Gris
# ..       ...    ...     ...                        ...       ...
# 909  Peugeot   5008  2024.0              GT PACK NAFTA      Gris
# 910  Peugeot   5008  2024.0            GT PACK AM 23.5  Plateado
# 911  Peugeot   5008  2023.0                    GT Pack      Gris
# 912  Peugeot   5008  2024.0                    GT PACK    Blanco
# 913  Peugeot   5008  2022.0  ALLURE PLUS HDI TIPTRONIC      Gris
#
#     Tipo de combustible  Puertas            Transmisión           Motor  \
# 0                 Nafta      5.0             Automática             1.6
# 1                 Nafta      5.0                 Manual             1.6
# 2                 Nafta      5.0                 Manual             1.6
# 3                 Nafta      5.0                 Manual             1.6
# 4                 Nafta      5.0                 Manual             1.6
# ..                  ...      ...                    ...             ...
# 909               Nafta      5.0  Automática secuencial   1.6 TURBO THP
# 910               Nafta      5.0  Automática secuencial  THP 1.6 165 CV
# 911               Nafta      4.0                    NaN           Turbo
# 912               Nafta      5.0             Automática             1.6
# 913              Diésel      5.0             Automática            1997
#
#     Tipo de carrocería Kilómetros                                  Título  \
# 0                  SUV   23000 km        Peugeot 2008 1.6 Feline Tip am20
# 1                  SUV   17000 km                 Peugeot 2008 1.6 Allure
# 2                  SUV   17500 km                 Peugeot 2008 1.6 Allure
# 3                  SUV  123600 km                 Peugeot 2008 1.6 Feline
# 4                  SUV   43000 km              Peugeot 2008 1.6 Thp Sport
# ..                 ...        ...                                     ...
# 909                SUV       0 km                   Peugeot 5008 Gt Pack
# 910                SUV       0 km         Peugeot 5008 Gt Pack Thp Am23.5
# 911                SUV    5400 km       Peugeot 5008 Gt Pack - 7 Asientos
# 912                SUV       0 km        Peugeot 5008 2024 - Avec Peugeot
# 913                SUV   17000 km  Peugeot 5008 ALLURE PLUS HDI TIPTRONIC
#
#          Precio Moneda Tipo de vendedor Con cámara de retroceso
# 0    22499999.0      $           tienda                     NaN
# 1    21999999.0      $           tienda                     NaN
# 2    20500000.0      $           tienda                     NaN
# 3    15000000.0      $           tienda                     NaN
# 4    12500000.0      $           tienda                     NaN
# ..          ...    ...              ...                     ...
# 909  54700000.0      $           tienda                     NaN
# 910  55000000.0      $    concesionaria                      Sí
# 911     46500.0    U$S       particular                     NaN
# 912  55500000.0      $           tienda                      Sí
# 913     42000.0    U$S    concesionaria                      Sí
#
# [906 rows x 16 columns]

# %%
peugeot2008 = peugeot[peugeot['Modelo'] == '2008']

# %%
version_peugeot2008 = peugeot2008['Versión'].unique()
print(version_peugeot2008)
len(version_peugeot2008)
# Out:
# ['1.6 Feline Tip am20' '1.6 Allure' '1.6 Feline' '1.6 Thp Sport'
#  '1.6 Thp Sport Tip' '1.6 Feline Tip' '1.6 Allure am20' '1.6 Allure Tip'
#  '1.6 In Concert Tiptronic' '1.6 Feline am20' '1.6 In Concert'
#  '1.6 FELINE TIPTRONIC AT' 'CONCERT 1.6 THP TIPTRONIC AM20' '1.6 Active'
#  '1.6 Thp Sport am20' '1.6 Crossway' 'Active Pack TipTroni'
#  '1.6 FELINE L/19 TIPTRONIC' '1.6 THP SPORT TIPTRONIC' '1.6 FELINE MT 4x2'
#  '1.6 Féline Mt' '1.6 THP SPORT MT' '1.6 ACTIVE MT 4x2'
#  '1.6 Feline Tiptronic' '1.6 Allure Mt' '1.6 ALLURE L/19 MT'
#  '1.6 Thp In Concert' '1.6 FELINE TIPTRONIC L19' 'Allure 1.6'
#  '1.6 ALLURE L19' '1.6 ALLURE TIPTRONIC L16' '1.6 FELINE L16'
#  '1.6 FELINE TIPTRONIC L17' '1.6 THP SPORT L19' '1.6 CROSSWAY L18'
#  '1.6 FELINE L19' '1.6 ALLURE L16' '1.6 Active am20' 'SPORT 1.6 THP'
#  '1.6 THP SPORT L16' 'Allure' 'Active 1.6']
# 42
