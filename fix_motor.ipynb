# %%
# %load_ext autoreload
# %autoreload 2
import pandas as pd
import numpy as np
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
file_path = r'pf_suvs_i302_1s2024.csv'
data = pd.read_csv(file_path)

# %%
current_year = 2024
data['Edad'] = current_year - data['Año']
data = data.drop(columns=['Año']) # Drop the original year column (we already have the age)
data = data.drop(columns=[ 'Tipo de combustible', 'Tipo de carrocería', 'Con cámara de retroceso', 'Puertas'])
# Drop the columns that are not useful for the model

print(data.columns)
# Out:
# Index(['Marca', 'Modelo', 'Versión', 'Color', 'Transmisión', 'Motor',
#        'Kilómetros', 'Título', 'Precio', 'Moneda', 'Tipo de vendedor', 'Edad'],
#       dtype='object')

# %%
# Fix the column 'Transmisión'
data['Transmisión'] = data['Transmisión'].replace('Semiautomática', 'Automática secuencial')

# %% [markdown]
# Ver que hacer con los 32 que no especifican

# %%
print(data['Transmisión'].unique())
print(data['Transmisión'].isnull().sum()) #Hay 32 autos sin transmisión especificada
for i in range(len(data)):
    if pd.isnull(data['Transmisión'][i]):
        print(data['Marca'][i], data['Modelo'][i], data['Título'][i], data['Versión'][i])
# Out:
# ['Automática' 'Manual' 'Automática secuencial' nan]
# 32
# Peugeot 5008 Peugeot 5008 Gt Pack - 7 Asientos GT Pack
# Ford Bronco Ford Bronco Big Beng 4x4 At 1.5 BIG BENG 1.5 4X4
# Renault Captur Renault Captur bose
# Mercedes-Benz Clase GLA Mercedes Benz Clase Gla 2016 250 4matic
# Mercedes-Benz Clase GLC Mercedes Benz Glc 300 Coupe Amg Line -usado Certificado-.  GLC 300 Coupe AMG Line
# Mercedes-Benz Clase GLE Mercedes Benz Gle 53 Amg 53 amg
# Jeep Commander Jeep Commander Limited 1.3 Turbo Nafta 175cv At6/ds LIMITE 1.3L TURBO NAFTA
# Jeep Compass Jeep Compass Limited Limited
# Hyundai Creta Hyundai Creta 1.5 At Safety + 2024 1.5 At Safety +
# Renault Duster Renault Duxter 1,6 Privilege Ph2 Nafta Gnc exprecion
# Renault Duster Renault Duster Dakar 2.0 4x4 Dakar 2.0 4x4
# hiunday Galloper Hiunday Galloper Permuta Financio Con Dni 4x4
# Toyota Hilux SW4 Toyota Hilux Sw4  Srx 7a Aut Full Titular Vendo O Permuto SW4 SRX 7A AUT FULL
# Toyota Hilux SW4 Toyota Hilux Sw4 Sw4 Sw4
# Nissan Kicks Nissan Kicks Sense 2018 Sense
# Ford Kuga Ford Kuga 2.5l Hibrida Titanium At Awd  Híbrida
# Toyota RAV4 Toyota Rav4 Hv 2.5 Xle Cvt Hibrida HV 2.5 XLE CVT
# Jeep Renegade Jeep Renegade Sport At Sport At
# JAC S5 Jac Motors Jac S5 Intelligent Dct 2018 La Plata 313 S5 INTELLIGENT DCT
# Kia Sportage Kia  New Sportage 4 X 4 2024 1.6 T 7 At 4x4 New Sportage 1.6 T / At
# Kia Sportage Kia Sportage 1.6t 2023 X LINE 1.6T
# Toyota SW4 Toyota Sw4 Diamond Ii 0km Año 2024 Rentaltrucks Vial Diamond
# Toyota SW4 Toyota SW4 3.0 Srv Cuero 171cv 4x4 5at - A4 3.0 Srv Cuero 171cv 4x4 5at - A4
# Toyota SW4 Toyota Sw4 2.8 Tdi Diamante Ii 4x4 7as 6at 2.8 Tdi Diamante Ii 4x4 7as 6at
# Volkswagen Taos Volkswagen Taos Comfortline Comfortline
# Volkswagen Taos Vw Taos 1.4 Turbo 150cv 0km Entrega Inmediata Permuta Mz 2024
# Volkswagen Taos Volkswagen Taos High Line High Line
# Volkswagen Tiguan Volkswagen Tiguan 2018 HIGHLINE 2.0 TSI 4MOTION DSG
# Chevrolet Tracker Chevrolet Tracker Ltz Ltz
# Hyundai Tucson Hyundai Tucson 2.0 Dohc 2013 2.0 DOHC
# BMW X5 Bmw X5 Xdrive 40i 2024 + Adicionales Autopremium 40i
# Volvo XC40 Volvo Xc40 Xc 40 T5 Awd Cassano Automobili XC 40 T5 AWD

# %%
def pesos_dolares(x):
    for i in range(len(x)):
        if x['Moneda'][i] == '$':
            x.loc[i, 'Precio'] = x.loc[i, 'Precio'] / 1040 # 1 peso = 1040 dolars (9th may 2024)
    return x

# %%
pesos_dolares(data)
data = data.drop(columns='Moneda') # Drop the column 'Moneda' since we already converted the prices to dollars (is not useful anymore)

# %%
data.head()
# Out:
#      Marca Modelo              Versión   Color Transmisión Motor Kilómetros  \
# 0  Peugeot   2008  1.6 Feline Tip am20  Blanco  Automática   1.6   23000 km
# 1  Peugeot   2008           1.6 Allure  Marrón      Manual   1.6   17000 km
# 2  Peugeot   2008           1.6 Allure  Marrón      Manual   1.6   17500 km
# 3  Peugeot   2008           1.6 Feline  Blanco      Manual   1.6  123600 km
# 4  Peugeot   2008        1.6 Thp Sport    Gris      Manual   1.6   43000 km
#
#                              Título        Precio Tipo de vendedor  Edad
# 0  Peugeot 2008 1.6 Feline Tip am20  21634.614423           tienda   2.0
# 1           Peugeot 2008 1.6 Allure  21153.845192           tienda   3.0
# 2           Peugeot 2008 1.6 Allure  19711.538462           tienda   3.0
# 3           Peugeot 2008 1.6 Feline  14423.076923           tienda   6.0
# 4        Peugeot 2008 1.6 Thp Sport  12019.230769           tienda   8.0

# %%
len(data['Modelo'].unique())
# Out:
# 164

# %%
print(data['Marca'].unique())
len(data['Marca'].unique())
# Out:
# ['Peugeot' 'Toyota' 'Fiat' 'DS7' 'DS' 'Ssangyong' 'Chevrolet' 'Citroën'
#  'Isuzu' 'Ford' 'Renault' 'Porsche' 'Jeep' 'Mercedes-Benz' 'MINI' 'Honda'
#  'Hyundai' 'Volkswagen' 'Land Rover' 'DS AUTOMOBILES' 'Audi' 'Geely'
#  'Jaguar' 'Daihatsu' 'Subaru' 'hiunday' 'Suzuki' 'Haval' 'Dodge' 'Nissan'
#  'Lexus' 'Kia' 'Mitsubishi' 'Lifan' 'Abarth' 'JAC' 'Sandero' 'BMW'
#  'Alfa Romeo' 'Chery' 'BAIC' 'Jetur' 'Jetour' 'Volvo']
# 44

# %%
for i in range(len(data)):
    if (data['Marca'][i] == 'DS7') or (data['Marca'][i] == 'DS AUTOMOBILES'):
        data.loc[i, 'Marca'] = 'DS'

# %%
for i in range(len(data)):
    if (data['Marca'][i] == 'Sandero'):
        data.loc[i, 'Marca'] = 'Renault'

# %%
for i in range(len(data)):
    if (data['Marca'][i] == 'Jetur'):
        data.loc[i, 'Marca'] = 'Jetour'

# %%
for i in range(len(data)):
    if (data['Marca'][i] == 'hiunday'):
        data.loc[i, 'Marca'] = 'Hyundai'

# %%
for i in range(len(data)):
    if (data['Marca'][i] == 'Abarth'):
        data.loc[i, 'Marca'] = 'Fiat'

# %%
#Convierto a minusculas las marcas
data['Marca'] = data['Marca'].str.lower()

# %%
for marca in data['Marca'].unique():
    print(marca, len(data[data['Marca'] == marca]))
# Out:
# peugeot 906
# toyota 1906
# fiat 616
# ds 33
# ssangyong 14
# chevrolet 2101
# citroën 850
# isuzu 24
# ford 2606
# renault 2203
# porsche 94
# jeep 3099
# mercedes-benz 505
# mini 9
# honda 1019
# hyundai 574
# volkswagen 2250
# land rover 132
# audi 839
# geely 14
# jaguar 4
# daihatsu 12
# subaru 72
# suzuki 138
# haval 23
# dodge 272
# nissan 311
# lexus 23
# kia 448
# mitsubishi 80
# lifan 16
# jac 6
# bmw 637
# alfa romeo 26
# chery 341
# baic 98
# jetour 13
# volvo 63

# %% [markdown]
# Analizar los modelos de cada marca:

# %%
#DS --> DS7 = 7
data['Modelo'] = data['Modelo'].replace('7', 'DS7')

# %%
#ML --> CLASE ML
data['Modelo'] = data['Modelo'].replace('ML', 'Clase ML')

# %%
for marca in data['Marca'].unique():
    #Ver los modelos de cada marca
    print(marca, data[data['Marca'] == marca]['Modelo'].unique())
# Out:
# peugeot ['2008' '208' '3008' '4008' '5008']
# toyota ['4Runner' 'C-HR' 'Corolla Cross' 'Hilux' 'Hilux SW4' 'Land Cruiser'
#  'RAV4' 'SW4']
# fiat ['500X' 'Pulse']
# ds ['DS7' 'DS3' 'DS7 Crossback']
# ssangyong ['Actyon' 'Musso']
# chevrolet ['Agile' 'Blazer' 'Captiva' 'Equinox' 'Grand Blazer' 'Grand Vitara' 'Spin'
#  'Tracker' 'Trailblazer']
# citroën ['Aircross' 'C3' 'C3 Aircross' 'C4' 'C4 Aircross' 'C4 Cactus'
#  'C5 Aircross']
# isuzu ['Amigo' 'Rodeo' 'Trooper']
# ford ['Bronco' 'Bronco Sport' 'Ecosport' 'Explorer' 'Kuga' 'Mustang'
#  'Territory']
# renault ['Captur' 'Duster' 'Duster Oroch' 'Kangoo' 'Koleos' 'Oroch' 'Sandero'
#  'Sandero Stepway']
# porsche ['Cayenne' 'Macan' 'Panamera']
# jeep ['Cherokee' 'Commander' 'Compass' 'Grand Cherokee' 'Patriot' 'Renegade'
#  'Wrangler']
# mercedes-benz ['Clase E' 'Clase GL' 'Clase GLA' 'Clase GLB' 'Clase GLC' 'Clase GLE'
#  'Clase GLK' 'Clase ML' 'Coupe']
# mini ['Cooper Countryman' 'Countryman']
# honda ['CR-V' 'HR-V' 'Pilot']
# hyundai ['Creta' 'Galloper' 'Grand Santa Fé' 'Kona' 'Santa Fe' 'Tucson' 'Veracruz']
# volkswagen ['Crossfox' 'Ecosport' 'Nivus' 'Suran' 'T-Cross' 'Taos' 'Tiguan'
#  'Tiguan Allspace' 'Touareg']
# land rover ['Defender' 'Discovery' 'Evoque' 'Freelander' 'Range Rover'
#  'Range Rover Sport']
# audi ['E-tron' 'Q2' 'Q3' 'Q3 Sportback' 'Q5' 'q5 sportback' 'Q7' 'Q8' 'SQ5']
# geely ['Emgrand X7 Sport']
# jaguar ['F-PACE']
# daihatsu ['Feroza' 'Terios']
# subaru ['Forester' 'Outback']
# suzuki ['Grand Vitara' 'Jimny' 'Samurai' 'Vitara']
# haval ['H1' 'H6' 'Jolion']
# dodge ['Journey']
# nissan ['Kicks' 'Murano' 'Pathfinder' 'Terrano II' 'X-Terra' 'X-Trail']
# lexus ['LX' 'NX' 'UX']
# kia ['Mohave' 'Seltos' 'Sorento' 'Soul' 'Sportage']
# mitsubishi ['Montero' 'Nativa' 'Outlander']
# lifan ['Myway' 'X70']
# jac ['S2' 'S5']
# bmw ['Serie 4' 'X1' 'X2' 'X3' 'X4' 'X5' 'X6']
# alfa romeo ['Stelvio']
# chery ['Tiggo' 'Tiggo 2' 'Tiggo 3' 'Tiggo 4' 'Tiggo 4 Pro' 'Tiggo 5'
#  'Tiggo 8 Pro']
# baic ['X25' 'X35' 'X55']
# jetour ['X70']
# volvo ['XC40' 'XC60']

# %%
len(data['Marca'].unique())
# Out:
# 38

# %% [markdown]
# Versiones de cada auto

# %%
#Quiero ver las versiones de cada modelo de cada marca (me las dan escritas de manera diferente)
for marca in data['Marca'].unique():
    #print(marca)
    for modelo in data[data['Marca'] == marca]['Modelo'].unique():
        #print(modelo)
        #print(data[(data['Marca'] == marca) & (data['Modelo'] == modelo)]['Versión'].unique())
        print()

#primero me fijo las palabras que se repiten en las versiones por cada modelo
for marca in data['Marca'].unique():
    print(marca)
    for modelo in data[data['Marca'] == marca]['Modelo'].unique():
        print(modelo)
        versiones = data[(data['Marca'] == marca) & (data['Modelo'] == modelo)]['Versión'].unique()
        print(versiones)
        #me fijo si hay palabras que se repiten en las versiones
# Out:
# peugeot
# 2008
# ['1.6 Feline Tip am20' '1.6 Allure' '1.6 Feline' '1.6 Thp Sport'
#  '1.6 Thp Sport Tip' '1.6 Feline Tip' '1.6 Allure am20' '1.6 Allure Tip'
#  '1.6 In Concert Tiptronic' '1.6 Feline am20' '1.6 In Concert'
#  '1.6 FELINE TIPTRONIC AT' 'CONCERT 1.6 THP TIPTRONIC AM20' '1.6 Active'
#  '1.6 Thp Sport am20' '1.6 Crossway' 'Active Pack TipTroni'
#  '1.6 FELINE L/19 TIPTRONIC' '1.6 THP SPORT TIPTRONIC' '1.6 FELINE MT 4x2'
#  '1.6 Féline Mt' '1.6 THP SPORT MT' '1.6 ACTIVE MT 4x2'
#  '1.6 Feline Tiptronic' '1.6 Allure Mt' '1.6 ALLURE L/19 MT'
#  '1.6 Thp In Concert' '1.6 FELINE TIPTRONIC L19' 'Allure 1.6'
#  '1.6 ALLURE L19' '1.6 ALLURE TIPTRONIC L16' '1.6 FELINE L16'
#  '1.6 FELINE TIPTRONIC L17' '1.6 THP SPORT L19' '1.6 CROSSWAY L18'
#  '1.6 FELINE L19' '1.6 ALLURE L16' '1.6 Active am20' 'SPORT 1.6 THP'
#  '1.6 THP SPORT L16' 'Allure' 'Active 1.6']
# 208
# ['FELINE TIPTRONIC' 'Feline' 'ACTIVE PACK AT']
# 3008
# ['1.6 Gt-line Thp Pack Tiptronic' '2.0 Gt-line Hdi Tiptronic'
#  '2.0 Gt-line Hdi Pack Tiptronic' '1.6 Gt-line Thp Tiptronic'
#  'GT PACK TIP' 'GT-LINE HDI TIPTRONIC' 'GT PACK HDI TIPTRONIC'
#  'GT LINE THP TIPTRONIC' 'GT Line 2.0 HDI Triptonic'
#  '1.6 ALLURE TIPTRONIC L17' 'HYBRID 4' 'GT PACK' 'GT LINE 1.6THP AT'
#  '1.6 Gt Thp Pack Tiptronic' 'GT PACK THP 1.6 TURBO' 'GT PACK THP 1.6'
#  'GT PACK AT' '3008 Gt Pack Am23.5 Ultima Unidad (p)'
#  'GT PACK THP TIPTRONIC' 'Gt Pack Hybrid4' 'ALLURE PACK AM23,5'
#  '2.0 HDI GT Pack Tiptronic' '1.6 Hybrid 4' 'GT Pack'
#  '2.0 Feline Hdi 163cv' 'GT Pack 1.6 THP' '1.6 Gt-line Thp'
#  '1.6 Allure Thp Tiptronic' 'GT PACK THP TIP.' 'Gt-pack Nafta' 'Gt'
#  'GT Line Tiptronic']
# 4008
# ['2.0 Feline 4x4 150cv Cvt' '2.0 Allure 4x4 150cv Cvt' '2.0 ALLURE 4x4 MT'
#  '2.0 Allure 4x4 150cv Mt5']
# 5008
# ['1.6 Allure At' '1.6 Allure Tiptronic' 'GT PACK TIPTRONIC' 'GT PACK THP'
#  'gt pack thp' 'GT PACK NAFTA' 'GT PACK AM 23.5' 'GT Pack' 'GT PACK'
#  'ALLURE PLUS HDI TIPTRONIC']
# toyota
# 4Runner
# ['2.8 Sl D' '2.8 L D' '2.7 NAFTA LIMITED 4X4']
# C-HR
# ['Hev Cvt']
# Corolla Cross
# ['2.0 Seg Cvt' '2.0 Xli Cvt' '1.8 Seg Ecvt' '2.0 Xei Cvt' '1.8 Xei Ecvt'
#  '2.0 Grs Cvt 170cv' '2.0 CROSS GR-SPORT CVT' '2.0 SEG GRS CVT' 'XLI CVT'
#  'SEG 2.0 CVT' 'HIBRIDA 1.8 ECVT' 'XLI 2.0 CVT' 'SEG HV 1.8 ECVT'
#  'Seg 2.0 Cvt' 'SEG HYBRID' '1.8 Xei Ecvt Hibrida' 'XEI HEV' 'Hibrido'
#  'GAZOO RACING' '1.8 Xei Hv E-Cvt' 'Seg' 'SEG 2.0CVT' 'XEI HEV 1.8 ECVT'
#  'SEG HEV' 'XEI Hibrido' 'SEG' 'xei nafta' '2.0 Cvt' '1.8 XEI hibrido'
#  'SEG HEV 1.8 eCVT' '1.8 SEG HV E-CVT' 'XLI CVT 2.0'
#  '1.8 XEI hybrid híbri' 'Seg hybrida' '2.0 XLI AT' 'SEG HV'
#  'XLI Automatico' 'Xli CVT 2.0' '1.8 XEI ecvt hibrid' 'XEI 2.0 CVT']
# Hilux
# ['2.8 Cd Srx 177cv 4x4']
# Hilux SW4
# ['2.8 Srx 177cv 4x4 7as At' 'Sw4 4x4 SRX 2.8 TDI' '2.8 Sr 177cv 4x4'
#  '3.0 Srv Cuero I 171cv 4x4 4at' 'SRX 4X4' 'HILUX SW4 4X4 at cue'
#  '3.0 srv cuero manual' 'SRX 7 As AT' '3.0 Srv Cuero At'
#  'SW4 SRX 7A AUT FULL' 'Srx at 7a' '3.0 Srv Cuero'
#  '3.0 Srv Cuero I 171cv 4x4' '3.0 Srv' '3.0 I Runner Tc Cu'
#  'Srv cuero 4x4 manual' '3.0 TD SRV' 'Grs' 'Diamons' 'SW4 SRX At'
#  '2.8 Tdi Diamante Ii 4x4 7as 6at' 'Sw4' '3.0'
#  '2.7 Srv Cuero Vvti 4x2 4at 7 As - C4' 'SRX 2.8 TDI AT6 7AS'
#  '3.0 Srv Cuero I 171cv 4x4 5at' '3.0 I Srv c/cuero'
#  '4X4 SRX AT 7 Asiento' 'SW4 4X4 SRV 3.0 TDI' 'SRX' 'SRX AT'
#  'SW4 3.0 srv 4x4' 'Srv 4x4 3.0 manual' '3.0 srv  cuero 4x4'
#  'Sw4 con cuero' '2.8 SRX 4 x 4' 'sw4 srv manual cuero'
#  '3.0 SRV manual/pana' 'SRX AT 7A' 'Srx 177cv automática'
#  '3.0 Srv Cuero 171cv 4x4 5at - A4' 'Toyota SW4' '2.8 srx 177cv 4x4 at'
#  '2.8 tdi srx 4x4 at 7' '3.0 SRV 4x4 Manual']
# Land Cruiser
# ['4.0 Prado Vx At' '4.5 200 V8 D4-d 235cv At' '3.0 Prado At' '4.2 Dl'
#  'Prado VX' '4.5 200 Vx 265cv At W/floormat' '4.0 Prado Txl At'
#  '4.0 Prado Vx Mt' '3.0 Prado Mt' '4.0 V6' '3.0 Prado' 'vx 100' 'VX 3.0'
#  'PRADO VX A/T' '4.5 Td 200 Vx 265cv At W/floormat' 'PRADO VX'
#  'Prado 2.8 4x4 AT']
# RAV4
# ['2.0 4x2 Vx Cvt' '2.5 Vx' '2.4 4x4 At' '2.4 4x2 At' '2.0 Vx' '2.5 Tx'
#  '2.0 4x2 Cvt' '2.0 Tx' '2.5 4x4 Vx 6at' 'HV 2.5 Limited' 'LIMITED HV'
#  '2.5 Limited' 'Limited CVT' 'Rav 4 2.5 Hybrid Limited'
#  'HV 2.5 LIMITED 4X2' 'Limited' 'Hv 2.5 Awd Limited'
#  'Limited 4x4 HV Hibrida' 'Xle' '2.5 4x4 VX AT' '2.5 VX AT 4x4'
#  '2.0 4x2 Tx Cvt' '2.5 4x4 6at' '2.5 HYBRID LIMITED AT 4x2'
#  'RAV4 HV 2.5 AWD LIMITED CVT' 'RAV4 HV 2.5 LIMITED CVT'
#  'HV 2.5 AWD Limited CVT' 'Rav4' 'Hv 2.5 AWD LIMITED CVT' 'HV 2.5 XLE CVT'
#  'HV 2.5 AWD LIMITED' '4x2' 'HV 2.5 LIMITED CVT' 'Hv 2.5 4x2 Limited Cvt'
#  '2.0 N 4x4 at o pmto.' 'HV 2.5 Limited CVT' '4wd'
#  'HD 2.5 AWD LIMITED CVT' 'LIMITED HIBRIDA 4X4 AT']
# SW4
# ['2.8 Srx 204Cv 4X4 7As At' '3.0 I Srv At C/cuero 4x4 (2009)'
#  '2.8 Tdi Gr-s 4x4 7as 6at' '2.8 Tdi Diamante Ii 4x4 7as 6at'
#  '2.8 Srx 177cv 4x4 7as 6at' '2.8 Srx 177cv 4x4 7as At' '2.8 Sr 177cv 4x4'
#  '3.0' '3.0 Srv Cuero I 171cv 4x4' '2.8 Srx 177cv 4x4 7as'
#  '3.0 Srv Cuero 171cv 4x4 - E4' '3.0 Srv Cuero' '3.0 Srv 171cv 4x4 - C3'
#  '3.0 Srv Cuero 171cv 4x4 5at' '2.7 Srv Cuero Vvti 4x2 4at 7 Asientos'
#  '3.0 Srv I 171cv 4x4' '3.0 I Srv C/cuero 4x4 (2009)'
#  '3.0 Srv Cuero I 171cv 4x4 4at' 'SRX 204Cv 7A AT'
#  '3.0 Srv Cuero I 171cv 4x4 5at' 'SW4 SRX 2.8 TDI 6 AT'
#  '3.0 I Srv 4x4 (2009)' '3.0 Srv Cuero At'
#  '2.7 Srv Cuero Vvti 4x2 4at 7 As - C4' '3.0 Srv' '3.0 SRV At/cuero 4x4'
#  'srx 2.8 tdi 204 CV' 'SRX AT 7A' '3.0 I Runner' 'SRX 4X4 AT'
#  '4X4 DIAMOND II 2.8 TDI 6 AT' '4x4 SRX 2.8 TDI 6 A/T 7A' 'Diamond'
#  '4X4 DIAMOND II 2.8 TDI 6 AT 7A' 'SRX Y DIAMOND' 'DIAMOND'
#  '2.8 SRX 7AS AT 4x4' '2.7 Srv Cuero Vvti 4x2 4at 5 Asientos' '3.0 Srv At'
#  '4x4 SR 2.8 TDI 6A/T 5A' '2.8 GR-SPORT 224CV 4X4 7AS AT'
#  'SW4 SRV 4X4 TDI 3.0 MT 5AS' '3.0 Srv 171cv 4x4'
#  '3.0 Srv Cuero I 171cv 4x4 5at - A4' '4X4 SRX 2.8 TDI 6 A/T 7A'
#  'SRX 204cv' 'SW4 TDI SRV CUERO AT L/12' '3.0 Srv Cuero I 171cv 4x4 - E4'
#  'SRV M/T' 'gr' 'srx' '204 cv SRX 7 asiento' 'GR Sport' 'GR' 'GR-Sport'
#  '4x4' 'Hilux asientos de cuero' '2.8 TDI DIAMOND II 7As AT 4x4'
#  '3.0 Srv Cuero 171cv 4x4 5at - A4' 'Srv 4x4 Cuero 7 Asie'
#  '3.0 I Runner Tc Cu' '2.8 GR-SPORT 204CV 4X4 7AS AT' '2.8 srv 4x4'
#  '3.0 Srv Cuero 171cv 4x4' 'SRX 2.8 TDI AT 7AS' '2.7 Runner'
#  'Srx 2.8tdi 204cv 4x4 At My24 L/nva' 'Fortuner' '3.0 Wide Body'
#  'Toyota SW4 SRX 4x4 2.8 204cv' '4x4 Diamond II 2.8 TDI 6 at 7as'
#  '3.0 Turbo' '2.8 srx 204cv 7as at' 'Toyota SW4 2.8 Srx' '3.0 srv 4x4'
#  'SW4 4X4 SRX 2.8 TDI 6 AT 7A FULL' '2.8srx204cv4x4 7a6at'
#  '2.8 Srx 204cv 4x4 7a' 'SW4 4X4 SRV 3.0 TDI C/CUERO'
#  '4x4 SR 2.8 TDI 6A/T' '2.8 srx 204cv 4x4' 'SRX 2.8 TDI 6 A/T  7A'
#  'sw4 3.0 td']
# fiat
# 500X
# ['1.4 T 16v Cross At9' '1.4 T 16v Pop' '1.4 POP STAR MT' 'X'
#  'CROSS 1.4T AT9 4X4']
# Pulse
# ['1.0 Impetus T3 Cvt' '1.3 Abarth Gse At' '1.3 Drive Gse Cvt'
#  '1.3 Drive Gse Mt' 'Drive 1.3' 'ANTICIPO Y CUOTAS' 'AUDACE 1.0 TURBO'
#  'Audace 1.0 Turbo' 'Audace' 'ABARTH' 'PACK PLUS' '1.0t audace'
#  'AUDANCE 1.0' 'Abarth 1.3 T 270' 'Audace 1.0T CVT' 'AUDACE TURBO'
#  'Drive cvt 2024' 'Drive mt 2024' 'Abarth' '1.3 T ABARTH AT6 L24'
#  'ABARTH TURBO 270' '1.0 IMPETUS L22' 'Abarth Turbo 270 AT6'
#  '1.0 TURBO AUDACE' '1.3 DRIVE 4x2 CVT' '1.3 DRIVE 4x2 MT'
#  'IMPETUS 1.0T CVT' 'Impetus 1.0T CVT' '1.3 TURBO 270' 'Drive CVT'
#  'Drive Mt' 'Audance' 'Cvt' 'MT 1.3' '1.0 IMPETUS' '1.3 Drive Mt'
#  'Impetus 1.0T' 'Audace 1.0 turbo' '1.O TURBO 270 ABARTH' 'Nafta'
#  'AUDACE 1.0T CVT' 'AUDACE TURB0 1000' 'audace 1.0t']
# ds
# DS7
# ['Bastille' 'Rivoli' 'Bastille 1.6T 215 HP' 'RIVOLLI 215' 'BASTILLE 215'
#  'BASTILLE' 'DS 7 BASTILLE 215 MY23' 'BASTILLE 215 MY 23'
#  'BASTILLE 215 MY23' '1.6 THP CROSSBACK PTECH B CHIC']
# DS3
# ['Rivoli' 'RIVOLI']
# DS7 Crossback
# ['NEW BASTILLE 215 AT8 MY23' 'BASTILLE 215 MY23' '2.0 HDI BASTILLE+'
#  'bastille' 'Híbrido enchufable'
#  'Ds Ds7 E-tense Hibrida 4x4 300 Bastille+'
#  'HDI 180 AUTOMATIC RIVOLI MY21' '1.6 Puretech 165 At Be Chic'
#  'DS7 Crossback E-tense 4x4 300 Bastille']
# ssangyong
# Actyon
# ['2.3 Equipamiento 2 150cv 4x2']
# Musso
# ['2.3 601 D' '2.9 602 D El At' '2.9 602 Dti' '2.9 602 D El']
# chevrolet
# Agile
# ['Lt 1.4n']
# Blazer
# ['2.8 Cdoble Dlx 4x2 Electronico' '2.8 Dlx 4x2' '2.8 Dlx I 4x2'
#  'DLX 2.8 4X2' '4.3 4x4 200 Hp Tahoe Lt' '2.8 Dlx 4x4' '4.3 4x2 160 Hp'
#  '2.8 Dlx I 4x4' '4.3 4x4 160 Hp' '4.3 4x4 200 Hp'
#  '2.8 Cdoble Dlx 4x4 Electronico' '2.4']
# Captiva
# ['2.4 Ls Mt Fwd 167cv' '2.2 Ltz 184cv' '2.4 Ls 167cv' '2.4 Lt 167cv'
#  '2.0 Vcdi Lt Mt' '2.4 Lt Mt Awd 167cv' '2.2 Ltz 184cv 7as Mt'
#  '2.2 Ltz Awd D 184cv At' '2.2 Lt Awd D 184cv Mt' 'Lt 2.2 D 7 asientos'
#  '2.0 Vcdi Ltz At' '2.4 Lt Mt' '2.4 LS MT 4x2' '2.4 LS 167CV MT 4x2'
#  'LT 2.4' '2.4 Ls' '2.2 ltz 200 cv' '2.4 Ls - 167 cv' 'LT']
# Equinox
# ['1.5t Premier 4wd' '1.5t Lt 2wd' '1.5T RS FWD AT'
#  '1.5 T AWD PREMIER AT6 L18' '1.5t Rs Fwd At' 'Rs' 'RS' 'Rs 1.5T'
#  'RS 1.5 TURBO FWD' '1.5T PREMIER AT 4x4' '1.5T LS AT 4x2'
#  '1.5 T LS 2WD AT' '1.5 Turbo RS 2WD']
# Grand Blazer
# ['4.2 Dlx']
# Grand Vitara
# ['2.0' '2.0 I']
# Spin
# ['1.8 ACTIV 7AS AT' 'Ltz' 'ACTIV' '1.8 Lt 5as 105cv'
#  '1.8 Activ LTZ AT 5AS' 'Premier M/T 7as' 'Premier 7p 1.8']
# Tracker
# ['1.2 Turbo Mt' '1.2 Ltz Turbo At' '1.2 Premier Turbo At' '1.8 Ltz'
#  '1.2 Turbo At' '1.2 Turbo Ltz At' '1.8 Ltz+ Awd At 140cv'
#  '1.8 Ltz Fwd Mt 140cv' '1.8 Ltz Awd At 140cv' '1.2 Turbo Premier At'
#  '1.8 Ltz+ 140cv' '1.8 Ltz 140cv' '1.2 T PREMIER AT 4x2'
#  '1.8 Ltz Fwd At 140cv' 'Premier At' 'PREMIER' 'TRACKER LT AT' 'Premier'
#  'PREMIER 1.2 AT' 'PREMIER 1.2T AT' '1.2 Turbo At argentina' 'Ltz'
#  'ltz at' '1.2 TURBO PREMIER' '1.8 Ltz+' 'LTZ 1.2T AT'
#  '1.2 T AT PREMIER Cr' 'Premier 1.2T AT' 'LTZ 1.2 AT' 'Premier AT 1.2'
#  'PREMIER TURBO AT' '1.2 Turbo Mt argentina' '1.8 LTZ PLUS 4X4 AUT'
#  'premier' '1.2T AT Premier' '1.8 4X4 LTZ + AWD PREMIER'
#  '1.8 4X2 FWD LTZ L' '1.8 LTZ + AWD 4x4 Premier AT' '1.8 oremier ltz'
#  '1.8 Lt Fwd Mt 4x2' 'TRACKER 5P 1,8 LTZ A/T 4X4 A' '1.2T AT LTZ'
#  'LTZ AUTOMATICA 0KM 2022 STOCK' '1.8 PREMIER 4X2 MT' 'LT AT 1.2 TURBO'
#  'LTZ AT' 'LTZ + AWD AT' '1.2 T AT 4x2' '1.8 LTZ L/17 MT 4x2'
#  '1.8 LTZ MT 4x2' '1.2 T LTZ AT 4x2' '1.8 LTZ+ AT 4x4' '1.2 AT'
#  '1.8 Ltz Mt' 'Tracker LTZ AT' '1.2 TURBO AT6' '1.8 LTZ+ 4X4 AUT'
#  'AWD LTZ 4x4' '1.2 T AUTOMATICA LTZ' '1.8 Ltz Awd 140cv'
#  '1.8 ltz premier' '1.8 LTZ 4x4' 'AWD Premier'
#  'Ltz Fwd 1.8 Mt 140Hp 178Nm Torque - Anticipo -' '1.8 Fwd Premier'
#  'FWD Premier' 'Premier AT 1,2 Turbo' 'Premier 1.8 MT' 'Fwd Premier'
#  'AWD PREMIER +' '1.8 4X2 LTZ L13' '1.8 4X4 LTZ PLUS PREMIER AT L17'
#  '1.8 4X2 LTZ PREMIER L17' '1.8 4X4 LTZ PLUS AT L13' '1.2 T LTZ AT6'
#  '1.8 4X4 LTZ AT L13' '1.8 LTZ MT 4X2' '1.8 PREMIER LTZ'
#  '1.8 4X4 LTZ AT AWD' '1.2 Turbo At6 L/22' 'Premier LTZ MT'
#  'LT Automatica' '1.8 LTZ PREMIER MT' 'Ltz+4x4' 'Tracker FWD PREMIER'
#  'Awd ltz 4x4' '1.8 LTZ AWD' 'Awd ltz']
# Trailblazer
# ['2.8 Nueva Ltz Tdci 200cv' '2.8 4x4 Ltz At Tdci 180cv'
#  'Chevrolet Trailblazer Premier 2.8 Diesel Turbo Automático Awd'
#  'Chevrolet Trailblazer Premier 2.8d Turbo Automático Awd 2024'
#  '2.8 4X4 PREMIER AT' 'Premier 4x4' '2.8 4x4 Premier AT'
#  '2.8 TDI 4X4 PREMIER AT' '4x4 Premier 2.8 AT Kb' '2.8 4x4 Premier At BL'
#  'Premier' 'trailblazer' '2.8 4x4 Lt At Tdci 180cv' '2.8 NUEVA LTZ TDCI'
#  '2.8 4X4 LTZ AT L16' '2.8 CTDI 4X4 LTZ A/T']
# citroën
# Aircross
# ['1.6 Shine 115cv' 'T200 AT7 Shine' 'T200 Shine 0km 2024'
#  'T.200 120 CV  SHINE']
# C3
# ['1.6 TENDANCE PK SECURE' 'AIRCROSS T200 SHINE' 'Firts Edition EAT6'
#  'Aircross 1.6 Shine' 'AIRCROSS' 'aircross shine' 'VTI 1.6 N'
#  'feel pack desing' 'C3 picasso' 'Aircross T200 Shine']
# C3 Aircross
# ['Shine T200' 'T200 Shine' 'SHINE T200' 'SHINE' 'T200 Shine 0km (S)'
#  'Shine' 'Manual y Automatico' 'shine t200' 'T200 SHINE']
# C4
# ['SHINE  TOPE DE GAMA' 'C4 Catus']
# C4 Aircross
# ['2.0 Tendance 4wd 150cv At6' '2.0 TENDENCE 2WD MT'
#  '2.0 Tendence 2wd 150cv At' '2.0 Tendence 2wd 150cv Mt']
# C4 Cactus
# ['1.6 Vti 115 At6 Feel Pk' '1.6 Vti 115 At6 Shine' '1.6 Thp 165 At6 Shine'
#  '1.6 Vti 115 Feel Pk' '1.2 Puretech 110 At6 S&s Shine' '1.6 Noir 165 At6'
#  '1.6 Vti 115 At6 Shine Bi Tono' '1.2 Puretech 110 At6 Rip Curl'
#  'THP AT NOIR' 'Thp At Noir' '1.6 Vti 115 Feel' '1.6 VTI RIP CURL AT'
#  '1.6 Vti 115 At6 X-series' '1.6 Vti 115 X-series' 'noir'
#  '1.6 Feel AT plus' 'SHINE  TOPE DE GAMA' 'FEEL + AUTOMATICA' 'Shine'
#  'Noir THP' 'FEEL DESIGN' 'Feel +' 'FEEL AT +MY23' 'FEEL + MY 23'
#  'FEEL+ AT' '1.6 THP 165 SHINE BI TONO AT' '1.6 VTI 115 FEEL MT'
#  '1.6 THP SHINE AT' '1.6 THP 165 SHINE AT' '1.6 VTI 115 FEEL PK MT'
#  '1.6 VTI 115 FEEL+ AT' 'SHINE THP TIP.' '1.6 Vti 115 Live'
#  '1.6 115 Feel Pack' 'C4 CACTUS NOIR' '1.6 Vti 115 Origins'
#  'Citroën C4 Cactus 1.6 Thp 165 At6 Shine' 'FEEL + AT BITONO' 'Thp Noir'
#  'C4 Cactus Feel+ tip.' '1.6 VTI FEEL PACK' 'FELL +' '1.6 Vti Live'
#  'C4 1.6 THP 165 AT6' '1.6 VTI FEEL PACK PLUS BT'
#  '1.6 THP SHINE AT6 BT L18' 'SHINE 1.6 TURBO AUTO' 'Thp shine' 'Feel + at'
#  'THP SHINE' '1.6 VTI FEEL L18' 'feel pack c-series 1.6 mt5'
#  'Feel Pack  AM 21']
# C5 Aircross
# ['1.6 Thp Eat6 Feel Pack' 'FEEL PACK THP 1.6 EAT6'
#  'THP 165 EAT6 FEEL PACK' '1.6 THP FEEL PACK AT6 L20'
#  '1.6 THP FEEL PACK AT6']
# isuzu
# Amigo
# ['2.2 Xs 4x4']
# Rodeo
# ['3.2 Xs V6 4x4' '3,1 nafta v6 4x4' '3.2 V6 4x4 At' '3.2 Ls V6 4x4 Ct'
#  '3.2 Ls V6 4x4 Ct At' '4x4']
# Trooper
# ['2.6 Ls' '3.1 Di Banzai Wagon' '3.1 I Scout Wagon' '3.0 I Kuroi Wagon'
#  '3.1 I Ls Wagon' '2.6 Hard Top' '3.2 V6 Wagon' '3.0 I Ls At Wagon'
#  '3.0 I Ls Wagon' 'tdi 3.1 turbo diesel']
# ford
# Bronco
# ['Wildtrack' 'Bronco 2.0T Sport Wildtrack Ecoboost' 'WILDTRACK 2.0 4X4'
#  'BIG BENG 1.5 4X4' 'Wildrack' 'Bronco 1.5T Sport Big Bend Ecoboost']
# Bronco Sport
# ['2.0 4Wd Wildtrak At8' '1.5 Ecoboost 4Wd Big Bend At8'
#  '1.5 4Wd Big Bend At8' '2.0 Ecoboost 4Wd Wildtrak At8' 'BIG BEND 1.5 AT'
#  'Wildtrack']
# Ecosport
# ['2.0 Titanium 143cv 4x2' '1.6 Xl Plus Mp3 4x2' '1.6 My10 Xls 4x2'
#  '2.0 Titanium Powershift 143cv 4x2' '1.6 Freestyle 110cv 4x2'
#  '1.6 Titanium 110cv 4x2' '1.5 Titanium 123cv 4x2 Manual'
#  '1.5 S 123cv 4x2' '2.0 My10 Xls 4x2' '1.5 Se Tdci 90cv 4x2'
#  '1.5 Se 123cv 4x2 Automática' '1.5 Se 123cv 4x2'
#  '1.5 Se 123cv 4x2 Manual' '1.6 Se 110cv 4x2' '2.0 Freestyle 143 4x4'
#  '1.6 S 110cv 4x2' '2.0 Titanium Powershift 4x2 Dps6'
#  '1.5 Freestyle 123cv 4x2' '1.6 My10 Xl Plus Mp3 4x2' '2.0 Xlt Plus 4x2'
#  '1.6 Xls' '2.0 Xlt' '2.0 Gdi Freestyle 170cv 4x4' '1.6 My10 Xls Plus 4x2'
#  '1.5 D Se 100cv 4x2' '1.5 Titanium 123cv 4x2 Automática'
#  '1.5 S Tdci 90cv 4x2' 'TITANIUM 2.0L AT' '2.0 Freestyle 4x4'
#  '2.0 Titanium At' '1.6 Xls Mp3 4x2' '1.5 Titanium 123Cv 4X2'
#  '2.0 Se 143cv 4x2' '2.0 My10 Xlt Plus 4x2' '2.0 Gdi Titanium 170cv 4x2'
#  '1.6 L 4x2 XLS' '1.4 Tdci Xls Mp3 4x2' 'TITANIUN 2.0' '1.6 Xl Plus'
#  'Storm 4x4' '1.6 FREESTYLE MT 4x2' '1.6 SE MT 4x2' '1.5 TITANIUM AT 4x2'
#  '1.6 FREESTYLE MT' '1.5 S MT 4x2' '1.5 Se' '1.6 SE MT 4X2'
#  '1.6 TITANIUM MT 4X2' '1.5 TITANIUM MT 4x2' '1.5 TITANIUM'
#  '2.0 TITANIUM MT 4x2' '2.0 GDI TITANIUM AT 4x2' '1.5 SE L18'
#  '2.0 My10 Xlt Plus At 4x2' '1.5 SE MT 4x2' '2.0 Xls 4x2'
#  '1.5 Freestyle 123cv 4x4' '2.0 Gdi Se 170cv 4x2' '1.6 Xls Gnc'
#  'Ford Ecosport freest' '2.0 Gdi 170cv 4x4 At' 'FREESTYLE' '2.0 Xlt 4x4'
#  'Xl' '1.6 S' 'Titanium 2.0 at' '1.6 SE L13' '2.0 TITANIUM AT L13'
#  '1.5 TITANIUM L18' '1.4 Tdci Xl Plus' '1.6 Xl Plus Gnc' 'Titanium 1.5'
#  'STORM 2.0 GDI 4X4 AT' '2.0 My10 Xlt Plus 4wd 4x4' 'TITANIUM 2.0L MT N'
#  '1.5 FREESTYLE L18' '1.4 Tdci Xls' '2.0 Xlt Plus At 4x2' 'Se 1.5'
#  '1.4 My10 Tdci Xls 4x2' 'Se 2.0' '1.4 Tdci Xl Plus Mp3 4x2'
#  '2.0L XLT PLUS 4WD' 'TITANIUM 2.0 AT' '2.0 Xlt Plus 4wd 4x4'
#  '1.6 Freestyle' 'TITANIUM 1.6L  MT N' 'Xl plus' '1.6 My10 Xlt Plus 4x2'
#  '2.0 titanuim' 'storm' 'TITANIUM 2.O AUTOMAT' '1.5 TDCI SE L18' 'STORM'
#  '2.0 SE AT L18' 'Se' '1.6 My10 Freestyle 4x2' '1.6 L 4x2 XL PLUS' '.'
#  '2.0 XLT 4wd' 'Ford EcoSport 1.6 xl' '1.6 My10 Xls 4x2 S/aa'
#  '1.6 Xls Seguridad' '1.4 My10 Tdci Xl Plus 4x2' '1.6 Xlt He'
#  '1.6 L.4.2 XL PLUS' 'xls plus' '1.6 l 4x2 xls' 'Ford Ecosport 1.6 se'
#  '2.0 Xlt 4x4 Plus' '1.6L 4x2 XLS MP3' '1.6 Xlt' 'Titanium'
#  'Titanium 1.6L MT N' '2.0 Storm AWD AT']
# Explorer
# ['4.0 Xlt 4x4 Limited' '4.0 Xlt 4x4 Sport' '4.0 Xlt 4x2' '4.0 Xlt 4x4 At']
# Kuga
# ['2.5 Titanium At 4x4 L (ku05)' '2.0 Sel At'
#  '2.5 Trend Mt 4x4 (ku01/ku04)' '2.5 Platinum Hibrida'
#  '2.0 Titanium At Awd' '1.6 Titanium At Awd T 180cv' '2.0 Titanium'
#  '1.6 Sel 6mt Fwd T 150 Cv' 'TITANIUM HIBRIDA' '1.6 Sel 6at Awd T 180cv'
#  'Kuga Se 2.5L Hibr. At' '2.0 SEL AT AWD' '2.0 Sel' 'KUGA SEL 4X4 AT AWD'
#  'Se 2.5l Hibrida At Fwd' 'TITANIUM 2.5 HIBRIDA' 'KUGA HIBRIDA PLATINUM'
#  'Híbrida' 'Hibrida awd' 'HÍBRIDO 2.5L AT AWD' 'Se 2.5 Hibrido At Fwd'
#  'HIBRIDO AWD 2.5' 'H´BRIDA TITANIUM 2.5' '2.0 TITANIUM AT 4x4'
#  '2.0 SEL 4x4 AT' '2.5 Titanium At 4x4 L (ku02)'
#  '2.5 Titanium At 4x4 (ku03)' '2.0 SEL 4x4 automati' 'Se híbrida'
#  '2.5 Híbrido Titanium' 'Kuga Se 2.5L Hibrida At' 'TITANIUM 2.5L  AT AWD'
#  'Titanium Permuto!!!' 'SE 2.5 HIBRIDO' '1.6 Se Plus 6mt Fwd T 150 Cv'
#  '1.6 SEL' '2.5 SE Hybrid FWD']
# Mustang
# ['Mach-E  100% Eléctrico 487cv' 'MACH - E AT AWD ELECTRICO' 'Mach-E']
# Territory
# ['1.8 Ecoboost Titanium At' '1.5t Titanium' '1.8 Ecobost Titanium At'
#  '1.8 Ecoboost Sel At' '1.8T Titanium' 'TITANIUM 1.8' 'titanium 1.8 AT'
#  '2.0 Titanium At Awd' '1.5t Sel' '1.8 Sel At'
#  'Titanium 1.8 nafta solo para empresas!!' 'TITANIUM 1.8 TURBO 7AT'
#  'SEL 1.8 AT' 'TITANIUM AT 180 CV 1.8 4X2' '1.8 Ecobost Sel At'
#  'SEL 1.8 NAFTA' 'TITANIUM 1.8 AT'
#  'Titanium 1.8 At Directo Fabrica! EMPRESAS Hd' 'TITANIUM 1.8L'
#  '1.5T Sel Cvt 143Cv' 'Titanium' '1.8' 'titanium 1.8l' 'SEL 1.8L TURBO'
#  '1.5 Trend 4x2 Aut' 'SEL 1.8 180cv Entrega inmediata' '1.8 Titanium At'
#  'Titanium 1.8 AT' '1.5T TITANIUM CVT' '1.5T SEL CVT' '1.8T SEL CVT'
#  '1.8T ECOBOOST TITANIUM' 'Titanium 1.5 Turbo AT'
#  'Titanium 1.5 Gtdi 4x2 At' '1.8L AUTOMATICA SEL' 'Titanium 1.8 l at'
#  'TITANIUM AT' 'TITANIUM' '1.8L Ecoboost 185cv' 'SEL' 'TITANIUM 1.5L GTDI'
#  'SEL EUS Turbo']
# renault
# Captur
# ['2.0 Intens Manual' '2.0 Intens' '1.6 Intens Cvt' 'BOSE 1.6 CVT'
#  '2.0 Zen' '1.6 Life' '1.6 Intens Mt' '2.0 Intens Mt' '1.6 BOSE CVT'
#  '2.0 Intens Automática' '2.0 Zen Mt' 'INTENS 2.0' 'INTENS 1.6 CVT'
#  '2.0 ZEN L18' 'bose']
# Duster
# ['1.6 4x2 Confort Abs 110cv' '1.3 Tce Turbo Iconic 155Cv Cvt X-Tronic'
#  '1.6 Hr16 Intens 115Cv' '1.3 Tce Turbo Iconic 155Cv'
#  '2.0 Ph2 4x4 Privilege 143cv' '1.6 4x2 Dynamique 110cv'
#  '1.6 Ph2 4x2 Privilege 110cv' '1.6 Ph2 4x2 Expression 110cv'
#  '2.0 4x4 Luxe Nav 138cv' '1.6 Ph2 4x2 Expression' '2.0 Ph2 4x4 Privilege'
#  '2.0 Ph2 4x2 Privilege 143cv' '1.6 Ph2 4x2 Dakar 110cv'
#  '1.6 Ph2 4x2 Privilege' 'Iconic 1.3 tce cvt' 'iconic 4x4' 'iconic'
#  'Iconic' '1.6 Ph2 4x4 Dakar 110cv' 'ICONIC 1.3 T 4X4' 'ICONIC 1.3 T| 4X4'
#  'ICONIC 1.3 TURBO 4X4' '1.6 4x2 Confort Plus Abs 110cv'
#  '1.6 Ph2 4x2 Dynamique 110cv' '1.6 4x2 Confort Plus Abs 110cv Alu'
#  '2.0 4x2 Luxe Nav 138cv' '1.6 4x2 Tech Road 110cv'
#  '1.6 Ph2 4x2 Dynamique' '2.0 4x4 Tech Road 138cv' 'PH2 EXPRESSION 1.6'
#  '1.6 4x2 Confort 110cv' '2.0 Ph2 4x2 Privilege'
#  '1.6 4x2 Expression 110cv' 'Intense 1.6 Manual' '1.3 Iconic CVT'
#  '2.0 4x2 Privilege 138cv' 'ICONIC 1.3 CVT' 'Zen' 'DUSTER PRIVILEGE 1.6'
#  'INTENS CVT' '1.6 4x2 Confort Plus 110cv' '2.0 4x2 Los Pumas 138cv Nav'
#  '1.6 4x2 Dakar Spirit 110cv' '2.0 4x2 Luxe 138cv' '2.0 4x4 Luxe 138cv'
#  'ICONIC 1,3T 4X4 MT 2024' 'Iconic 1.3 4x4'
#  'Renault Duster Iconic 1.3t CVT' 'ICONIC 1.3T 4X4' 'ICONIC 1.3T'
#  'ICONIC 1.3T CVT 4X2' 'ICONIC 1.3T CVT' 'intense/iconic'
#  'iconic 1.3T cvt 4x2' 'ICONIC' 'ICONIC 1,3 CVT' '2.0 Privilege' 'ZEN 1.6'
#  '1.3 T 4X4 ICONIC' '1.3 T 4X2 ICONIC CVT' '1.6' 'Iconic 1.3 CVT 4x2'
#  'duster iconic 1.3T CVT' 'INTENSE/ICONIC'
#  'iconic 4x2 cvt polo, yaris, cronos' 'ICONIC 4X2 1.3 TURBO'
#  'Dakar 2.0 4x4' 'INTENS' '1.3 Tce Turbo Iconic 155 Cv CVT X-Tronic'
#  'Dynamique 1.6 4x2 16V 110 hp - Anticipo -' '2.0 PRIVILEGE MT 4x2'
#  '2.0 PH2 PRIVILEGE MT 4x2' '1.6 PH2 PRIVILEGE MT 4x2'
#  '1.6 PH2 DYNAMIQUE MT 4x2' '1.6 TECH ROAD MT 4x2' '1.6 4X2 PRIVILEGE L15'
#  '1.6 4X2 INTENS' '1.6 PH2 EXPRESSION MT 4x2'
#  '1.6 Dynamique Full 4X2 1.6 110Hp 16v - Anticipo -' '1.3Tce Iconic 4x4'
#  'EXPRESSION 1.6 4X2' '1.6 4X2 DYNAMIQUE L15' '1.3 CVT' 'intens 4x2 MT'
#  'Iconic 1.3 TCe Turbo' 'Intens 4x2 MT' 'DUSTER ZEN 1.6 M/T' '1.6 Intens'
#  'Iconic 4x4 1.3t mt' 'INTENS CVT 1.6' 'exprecion' 'ICONIC 4X4 1.3 TURBO'
#  '2.0 4X4 PRIVILEGE L15' '2.0 4X2 PRIVILEGE L15'
#  '1.6 Dynamique Full E. 1.6 110Hp 16v - Anticipo -' '2.0 PRIVILEGE 4X2'
#  '1.6 4X2 EXPRESSION L15' 'Luxe Nav 4x4' '2.0 16V DAKAR 6MT'
#  '1.6 Hr16 Intens 115Cv Cvt X-Tronic' '2.0 4X2 DAKAR L17'
#  '1.3l T Iconic CVT' '1.6 4X2 INTENS CVT L21' '1.6 16v Intens Cvt'
#  'Intens 1.6 CVT' 'Dakar 4x4 2.0' 'Intense 1.6 4x2 MT'
#  'EXPRESSION 1.6 RURAL' '2.0 4x4 Los Pumas 138cv Nav' 'Outsider'
#  'Privilege']
# Duster Oroch
# ['2.0 Privilege' '2.0 Outsider Plus' '1.6 Outsider' '1.6 Dynamique'
#  '2.0 Dynamique' 'Emotion 1.6 Nafta' '2.0 Dynamique 4x4' '1.6 EMOTION SCE'
#  'OUTSIDER 1.6' 'DYNAMIC 1.6' 'OUTSIDER PLUS 2.0' '2.0 outsider 4x4']
# Kangoo
# ['stepway 1.6' 'KANGOO STEPWAY 1.6 NAFTA' 'KANGOO STEPWAY 1.5 Dci'
#  'STEPWAY 1.6' 'stepway 1.6 berlingo partner']
# Koleos
# ['2.5 4wd Cvt' '2.5 Expression 4x2 Mt' '2.5 Privilege 4x4 Mt'
#  '2.5 Privilege 4x4 Cvt' '2.5 4X4 INTENS CVT' '2.5 Dynamique 4x4 Mt'
#  '2.5 Dynamique 4x4 Mt Sin Climatizador' '2.5 2wd Cvt'
#  '2.5 Ph3 Dynamique Plus 4 Cvt' '2.5 4X4 INTENS CVT L18'
#  '2.5 Ph3 Dynamique Plus 4 6mt' '2.5 Ph3 Privilege 4x4 Cvt'
#  'Expression L 2.5 4x2' '2.5 Ph3 Privilege 4x4 Cv' '2.5 Dynamique 4x4 Cvt']
# Oroch
# ['1.3 Tce 163 Iconic Cvt 2wd' '1.6 Sce 114 Emotion 2wd'
#  'OUTSIDER 1.3 TCe  4X4 4X2' '1.3 Tce 163 Outsider Mt 2wd'
#  '1.3Tce Outsider 4x4' 'EMOTION 1.6 SCe 114 2WD' 'OUTSIDER 4X4'
#  '1.3 TCE Outsider 4x4' 'OUTSIDER 1.3Tce 4x4']
# Sandero
# ['INTENS CVT  AUTOMATICO' 'STEPWAY ZEN' 'Stepway Volcom' nan]
# Sandero Stepway
# ['intens cvt' 'Volvom 1.6 nafta' '1.6 16v Intense' '1.6 Expression'
#  '1.6 INTENS OKM' 'Stepway 1.6' '1.6 Intense CVT' '1.6 Dynamique 105cv'
#  '1.6 Privilege Mt' 'EXPRESIÓN' 'Expression']
# porsche
# Cayenne
# ['3.0 S Hybrid 380cv Tiptronic (958)' '3.6 300cv (958)'
#  '4.8 S 400cv (958)' '3.0 Diesel 245cv (958)' '3.6 V6' '3.0 V6 340hp'
#  '3.0 V6 353HP' 'V6 353HP' 'V8 4.0 659HP' '4.8 V8 S (957)' '3.6 V6 300cv'
#  '3.6 V6 (957)' '4.8 V8 Turbo S (957)' '4.8 S 400cv' '4.8 V8 Gts (957)'
#  '4.8 Turbo S 550cv' '3.0 V6 Turbo 340CV Tiptronic S' '4.8 V8 Turbo (957)'
#  '4.8 S']
# Macan
# ['3.0 S 340cv Automática' '2.0 252cv' '3.0 S 340cv' '3.6 Turbo 400cv'
#  '3.0 Gts 360cv' '3.0 440HP' '2.0 265HP' 'Turbo Electric' 'Electric'
#  '3.0 S 245cv Automática']
# Panamera
# ['4.8 Turbo 500cv (970)']
# jeep
# Cherokee
# ['3.7 Limited 205hp Atx' '2.5 Sport' '2.5 Classic' '3.7 Limited Atx'
#  '4.0 Sport' '4.0 Classic' '3.7 Sport' 'Limited' '2.8 Crdi' 'Trailhawk'
#  '3.6 Overland At' 'GRAND CHEROKEE LIMITED' 'LIMITED 3.6L AT8'
#  '4.0 Classic At' '3.7 Limited' 'TrailHawk' '2.4 Sport'
#  'Trailhawk 3.2 V6 At' '2.8 Sport At' '5.2 V8 Limited Tc' '2.1'
#  '3.7 Sport Atx' '2.5 Se' '4.0 Laredo']
# Commander
# ['2.0 Td380 At9 4x4 7pas Limited' 'Limited 4X2'
#  '2.0 Td380 At9 4x4 7pas Overland' 'Limited 2.0 TD 4x4'
#  'Commander Limited' '2.0 TD AT9 4X4 LIMITED BLINDADO RB3' 'Limited'
#  'Limited 2.0L AT 4x4' '2.0 TD 4X4 LIMITED AT9 L22' 'LIMITE'
#  'LIMITED 4X2 1.3 T270' '1.3 AT6' 'LIMITE 1.3L TURBO NAFTA'
#  '1.3 T270 4X2 AT6' '1.3 Turbo nafta' '1.3 LIMITED' '1.3 TURBO LIMITED'
#  'Limited T270 AT6 4X2' '1.3 Turbo' 'LIMITED 1.3L AT6 4X2' 'Limited T270'
#  'LIMITED GSE 1.3T AT6 4X2' '2.0 TD 4X4 LIMITED AT9' 'Limited 1.3 T 270'
#  'LIMITED 2.0']
# Compass
# ['1.3 Longitude At6' '1.3 T270 Sport' '1.3 T270 Limited' '1.3 Sport At6'
#  '2.0 Td At9 4x4 Trailhawk' '2.4 Longitude Plus' '2.4 Limited 170cv Atx'
#  '1.3 T270 Longitude' '1.3 T270 Longitude Plus At6' '2.4 Longitude'
#  '2.4 Sport At 4X2' '5' '1.3 T 270 SERIE-S AT6' '2.4 Limited' '2.4 Sport'
#  '2.4 Limited Plus' '1.3 T270 Serie-S At6' '2.0 Td At9 4x4 Limited Plus'
#  'S' 'longitude' '2.4 Longitude Plus 4X4' '2.4 Sport Automática' 'Limited'
#  'Longitude AT6 AWD' '2.4 Limited Cvt' '1.3 T 270 LIMITED PLUS'
#  'Limited 4X2' 'Limited 4x2 AT6' 'Sport' '1.3 T 270 SERIE-S AT6 L23'
#  'Sport T270' '1.3 T 270 LONGITUDE AT6 L21' '2.4 Opening Edition'
#  '2.0 TD TRAILHAWK AT9 L21' 'SPORT 2.4 AT6' '2.4 Sport Automática 1630 mm'
#  '2.4 Sport Manual' 'SPORT T270 AT6 4X2' 'Sport 2.4 Automática'
#  'LONGITUDE T270 AT6 4X2' '2.4 At' 'Serie S' 'SERIE S'
#  'SERIE-S 1.3 TURBO NAFTA 175CV AT6' 'Trailhawk 2.0 TD 4x4'
#  'TrailHawk 2.0 TD' 'Longitude 4x4 AT9' '1.3T At6 4X2'
#  '2.4 Sport 170cv Atx' 'Serie S 4x2' 'Serie S t270' 'S Limited' 'Series S'
#  'Sport 1.3T AT6 4x2' '1.3T SPORT T270 AT 4X2' 'serie s' 'SPORT T270'
#  '2.4 LONGITUDE AT9 OE L17' '2.4 LIMITED PLUS AT 4x4'
#  '2.4 LONGITUDE AT 4x4' '2.4 SPORT MT 4x2' '1.3T LONGITUD T270 AT 4x2'
#  '2.4 LONGITUDE PLUS AT 4x4' '2.4 SPORT AT 4x2'
#  '2.4 LONGITUDE AT6 4X2 L18' '1.3T LIMITED T270 AT 4x2'
#  'LIMITED 2.0 AT9 4WD' '2.4 Sport Mtx' '2.4 SPORT AT6'
#  '2.4 LONGITUDE PLUS AT9 L17' '2.4 LIMITED AT9 L17' 'sport 1.3 at6'
#  '2.4 LONGITUDE PLUS AT9' '2.4 Sport Cvt' 'Longitude 4x4 At9'
#  '1.3 Turbo Sport 6at' 'COMPASS SERIE S T270 1.3T' 'SPORT 1.3T AT6 4X2'
#  'SerieS 1.3L' '1.3 T 270 SPORT AT6' 'Serie s (limited)'
#  'Longitude Plus 1.3T AT6 4x2' 'LONGITUDE 1.3 T AT6'
#  '2.4 LONGITUDE AT9 PLUS 4X4' 'Serie S 1.3t at6' '2.4 4X2 SPORT L17'
#  '2.4 SPORT MT6' 'LONGITUDE 1.3T AT6 4X2' 'limited serie s'
#  '2.4 LIMITED AT9 PLUS L17' '2.4 Sport Automática 1635 mm'
#  '2.4 Limited At' '2.4 Limited Mtx' '1.3t Limited aut. 4x2'
#  '2.4 L SPORT AT 4X4' 'Longitud 1.3T AT6 4X2' '1.3 T270 Serie-S'
#  '2.4 Sport At' 'Compass Longitude 2.4 AT9 AWD' 'Limited 4X4']
# Grand Cherokee
# ['3.6 Limited 293Cv At8 4X4' '3.6 Limited 286hp Techo + Llantas 18'
#  '3.6 Overland 286hp At' '3.6 Limited 286hp Atx' '3.1 Laredo' 'Limited'
#  '3.0 Crd Limited Automática' '4.7 Limited Atx' '6.1 Srt-8 Hemi'
#  '2.5 Laredo' '5.2 V8 Tc Limited' 'LIMITED 3.6L AT8 4X4' '2.5 Limited'
#  'LIMITED 3,6L V6 AT8 4X4' '3.0 Limited Atx' '4.7 V8 Scv Limited'
#  '5.2 V8 Limited' '4.0 Laredo Automática' 'cherokee'
#  '6.4 Srt Atx 465hp At' '4.7 V8 Limited' 'OVERLAND 3.6 V6'
#  '3.0 Limited Crd' '6.4 Srt8' '3.0 Crd Limited' '3.0 Laredo Atx'
#  '5.7 Overland Atx' 'Crd3.0 Limited Atx' '2.7 Crd Limited Automática'
#  '4.7 V8 Limited Automática' '2.7 Crd Laredo' '4.0 Laredo'
#  '3.0 Crd Laredo Automática' 'OVERLAND AT' '3.1 Limited'
#  '4.7 V8 Limited Scv' '4.7 V8 Scv Limited Automática' 'Srt8'
#  '5.7 Overland Automática' '5.2 V8 Limited Tc' '5.7 Overland'
#  '3.0 Laredo Crd Automática' '4.0 Limited' 'Overland' 'LAREDO 3.6 V6 AT']
# Patriot
# ['2.0 Sport 4x2 156cv Mtx' '2.4 Sport 4x4 170cv Atx'
#  '2.4 Sport 4x4 170cv Mtx' '2.4 Sport Mtx' 'SPORT 2.4 4X4' '2.4 Mtx']
# Renegade
# ['1.3 Serie-S At6' '1.8 Sport At6' '1.8 Sport At Plus'
#  '2.4 Trailhawk At9 4x4' '1.8 Longitude At6' '2.4 Longitude At'
#  '1.8 Sport' '1.8 Sport Plus' 'TRAILHAWK' 'SPORT MT5' 'SERIE S' 'Sport Mt'
#  'Sport' 'serie S' 'renegade sport at' 'Sport At' 'Sport 1.8 MT'
#  '1.8 Sport At' 'Trailhawk 1.3 T270 AT9 4x4' 'SERIE-S T270 AT6'
#  'Serie S t270 at6' 'Sport At6' '1.8 4X2 SPORT L16' '1.8 Sport MT'
#  '2.4 4X4 LONGITUDE AT' '1.8 4X2 SPORT AT6 L23' 'Renegade Sport Manua'
#  '1.3 t270 At6' 't270 1.3 At6' 'Longitude T270 AT6' 'SPORT 1.8L AT6 4X2'
#  '1.8 Sport Manual' 'Serie S' 'S 1.3TURBO' 'Longitude' '1.3 TURBO SERIE S'
#  'MT5' 'Serie S t270 At6' '1.3 T270 Trailhawk' 'TRAILHWK 1.3 AT 9'
#  '1.3 T 270 4X4 TRAILHAWK AT9 L23' 'Serie S 1.3 AT6 T270'
#  'Longitude 1.3 T270' 'TrailHawk 4x4' 'Trailhawk 4x4 at9 t270'
#  'SERIE S 1.3T 4X2' '1.8 sport MT' 'Mt' 'Serie S 1.3 4x2' 'T270'
#  '2.4 4X4 LONGITUDE AT L16' '1.8 SPORT AT 4x2' '1.8 SPORT PLUS AT 4x2'
#  '1.8 SPORT MT 4x2' '1.8 SPORT L/18 MT 4x2' '1.8 4X2 SPORT'
#  '1.8 LONGITUDE AT 4x2' '1.8 4X2 LONGITUDE AT L18' '1.8 SPORT L/19 MT 4x2'
#  '1.8 SPORT L/18 AT 4x2' '1.8 4X2 SPORT AT L18' '1.8 SPORT MT5 FWD'
#  '1.8 4X2 SPORT AT6' 'longitude T270 AT6' '1.8 Sport Wild' 'Sport 1.8 mt'
#  'Longitud' 'SPORT 1,8 MT' '1.8 Sport M/T5' '1.3 T 270 SERIE-S AT6'
#  'Serie S 1.3T' '1.3 TURBO T270 A/T9 TRAILHAWK 4x4' '80 ANIVERSARIO EDIC'
#  'TRAILHAWK 1.3T 4X4 AT9' '1.8 4X2 SPORT PLUS L16' 'Serie S 1.3t at6'
#  'Sport 1.8L ML5' '1.8 At6 Sport Plus 16v 130cv 2019 - Anticip' '1.8 AT6'
#  'SPORT 1.8L MT5 FWD' '1.8 SPORT MT5' '1.3T Longitude T270'
#  'SPORT 1.8 MT5 FWD' 'LONGITUDE 1.8L AT6' '1.8L SPORT' 'SPORT 1.8 AT6'
#  'Sport 1.8 mt5' 'SPORT 1.8L AT6' 'Sport at6' '80 ANIVERSARIO'
#  'Manual de 5 Marchas' '1.3 Turbo Serie S' 'Sport 1.8 manual' 'Trailhawk'
#  'Otras versiones' 'Sport 1.8 At6' 'Sport Plus MT' 'Sport 1.8mt'
#  'Anniversary' 'SPORT 1.8 MT5' '1.8 sport automatica' 'Sport 1.8 Mt']
# Wrangler
# ['3.8 Sport Unlimited 199cv Mtx' '3.6 Rubicon 284hp Atx'
#  '3.6 Unlimited 284hp Atx' '3.8 Sport Mtx Unlimited' '3.6 Sport 284hp Mtx'
#  '3.8 Sport Atx Unlimited' 'Sport Mtx Unlimited'
#  '3.8 Sport Unlimited 199cv Atx' '3.6 Unlimited 284hp Mtx' '3.8 Sport Mtx'
#  '3.8 Sport 199cv Mtx 2011' '3.8 Sport At' 'Unlimited Sport V6'
#  'UNLIMITED MT' 'Wrangler Unlimited Sport V6' '3.8 Sport Atx Mountain'
#  '4.0 Hard Top']
# mercedes-benz
# Clase E
# ['GLE 53 AMG']
# Clase GL
# ['4.7 Gl500 4matic Sport V8 Bit 435cv']
# Clase GLA
# ['1.6 Gla250 Amg-line 211cv' '1.6 Gla250 At Sport B.efficiency'
#  '1.6 Gla200 Urban 156cv' 'GLA 200 PROGRESSIVE FACELIFT'
#  '1.6 Gla200 Progressive 163cv' '1.3 Gla200 Progressive 163Cv'
#  '1.6 Gla200 At Urban 156cv' 'GLA 200 PROGRESSIVE' 'GLA250'
#  'GLA 250 4MATIC' '1.6 Gla250 Urban 211cv' '2.0 Gla45 Amg 381cv'
#  '250 4matic' '250 AMG AT']
# Clase GLB
# ['2.0 Glb250 Progressive 224cv' '1.4 Glb200 Advance 163Cv'
#  '2.0 Glb200 Advance 163cv' '2.0 Gla250 Progressive 224cv' 'PROGRESSIVE'
#  '250 4MATIC 7 PLAZAS']
# Clase GLC
# ['2.0 Glc250 300 4matic Atomático' 'GLC 300 amg line'
#  '3.0 Glc43 Amg 4matic 367cv' 'glc 300 coupe' '2.0 Glc300'
#  'GLC 300 Coupe AMG Line' '2.0 Glc300 4matic Coupe At' 'AMG 2.0 4MATIC'
#  '2.0 GLC 300 4 Matic' 'GLC 300 AMG-LINE' 'GLC 300 COUPE'
#  'GLC300 Coupe 4matic']
# Clase GLE
# ['3.0 Gle400 Sport Coupe 4matic 333cv' '3.0 Gle400 Sport 4matic 333cv'
#  '3.0 Gle450 4matic 367cv' '53 amg' '5.5 V8 Gle Coupé 63 S 4matic 585 Cv'
#  '5.5 Gle43 Amg 585cv' 'GLE 53 COUPE 435 CV' 'GLE 53S' 'GLE 63 AMGs V8'
#  'GLE-53 AMG coupe']
# Clase GLK
# ['3.0 Glk300 4matic City 231cv At' '3.0 Glk300 4matic Sport 231cv At'
#  '3.5 Glk300 4matic 247cv At' '3.5 Glk300 4matic Sport 247cv At'
#  '2.5 Glk280 V6 Sport' '2.5 Glk280 V6 Nature' '2.5 Glk300 V6 City 4matic'
#  '300 4matic Todo Terr' '300 4MATIC AMG SPORT'
#  '2.5 Glk300 V6 Sport 4matic' '2.5 Glk300 V6 Nature 4matic'
#  'GLK 280 4MATIC']
# Clase ML
# ['3.5 Ml350 4matic Sport B.efficiency' '350 Sport 4matic'
#  '5.5 Ml500 V8 Facelift' 'ML350' 'Blue Efficiency' 'ML 350 4 MATIC LUXURY'
#  '350 AMG' '500' '63 Amg' '3.5 Ml350 Luxury At' '3.5 Ml350 Sport'
#  '4.3 Ml430 At Luxury' '3.2 Ml320 Cdi Sport'
#  '3.5 Ml350 4matic Sport B.eff Techo' '3.0 Ml350 Cdi Sport Facelift'
#  '3.5 Ml350 4matic Sport W164' '3.0 Ml400 4matic Sport B.eff Techo'
#  '350 4MATIC AT' '3.0 Ml400 4matic Sport 333cv Techo' '3.2 Ml320 Cdi'
#  '350 3.5 4matic Sport B.efficiency' '5.0 Ml500 Nafta' '3.0 Ml320 Cdi'
#  '3.5 Ml350 4matic Sport Facelift' '350 CDI 4MATIC' '5.0 Ml500 Sport'
#  '2.7 Ml270 Cdi Luxury At' '3.2 Ml320 At Luxury']
# Coupe
# ['GLC 300 COUPÉ 4MATIC']
# mini
# Cooper Countryman
# ['1.5 Peppers Automatico' 'S' 'Classic'
#  'Countryman Cooper S Classic Confort' 'Jonh Cooper Works 4ALL'
#  '1.6 Jcw 211cv All4' 'COOPER S ALL4']
# Countryman
# ['John Cooper Works' 'John Cooper Works 4ALL']
# honda
# CR-V
# ['2.4 Lx 2wd 185cv At' '2.4 Lx At 2wd (mexico)' 'Lx 2Wd'
#  '2.4 Lx 2wd 175cv Cvt' '2.4 Lx At 4wd' '2.4 Ex L 4wd 185cv At'
#  '2.4 4x2 Active At Lx' '2.4 4X2 LX CVT L17' '2.4 Ex At 4wd (mexico)'
#  '2.4 4x4 Ex At' '2.0 4x4 Si' '2.4 4x4 Ex-l At' '2.4 Ex Mt 4wd' 'Ex'
#  'LX 2WD 1.5 t 191 cv' 'Lx' '2.4 LX 4X2 AT' 'CRV EXT 4x4 turbo' 'EX 2WD'
#  '2.4 lx at ( japon)' 'Ex-l 4wd 175cv Cvt' '2.4 Lx Mt 4wd' '2.0 Lx Mt 2wd'
#  '2.4 Ex L At 4wd' '2,4 Lx 2wd A/t 2012' '2.4 4x4 Lx' '2.0 4x4 Si At'
#  '2.4 Ex-l 4wd 175cv Cvt' '2.0 4x4 I' '2.4 4x2 Lx At' '1.5 Turbo LX 4x2'
#  'EX 1.5 Turbo 4X2' 'Ext 1.5' 'Ex 1.5 Turbo' 'ex 1.5 Turbo'
#  '2.0 Ex At 4wd' 'New Cr-v Ex 1.5t 2wd' '1.5 4x4 EX T'
#  'New Cr-v Lx 1.5t 2wd' '2.0 Ex L At 4wd' '2.0 4x4 I Scout' '2.4 Lx At'
#  'Exl 2.4 At 4x4' '2.0 4x4 I At' '2.4 4x4 Ex' '2.4 Ex 4wd 185cv At'
#  'EXT 1.5 Turbo VTEC AWD CVT' '2.4 AT lx' '2.4 4x2 Active At'
#  '1.5 T Ex 4wd At' 'Elx' 'LX AT 4x2' 'EXT 4WD 1.5 TURBO'
#  '2.4 Ex At 4wd(Japón)' 'EX-T 1.5 TURBO AWD' 'EXL']
# HR-V
# ['1.8 Ex 2wd Cvt' '1.8 Ex-l 2wd Cvt' '1.8 Ex-l 2wd Cvt l20' 'EX-L'
#  'Lx 1.8L Cvt' '1.8 Lx 2wd Cvt' 'LX CVT 2WD' 'EXL CVT'
#  '1.8 Ex 2wd Cvt l20' '1.8 Lx 2wd' 'Lx' 'EXL' 'EX-L 1.5' 'Ex-l 1.5 At Cvt'
#  '1.8 EXL CVT L15' '1.8 EX CVT' 'Honda HR-V LX CVT' '1.8 Lx 2wd Cvt l20'
#  'EXL 1.5' 'LX 1.5' 'EXL 1.5 121cv' 'EX-L 1.5 AT CVT' 'LX 1.5 AT CVT 2WD'
#  'LX AT CVT 1.5' '1.8 LX CVT L15' '1.6 Style Pack' 'Exl cvt 2024 0km'
#  'LX 1.5 CVT 2024' 'Honda HR-V EXL 1.5' 'EXL 1.5 hp' 'Hyundai creta'
#  '1.8 EXL CVT L19' '1.8 EX CVT L21' 'Lx cvt']
# Pilot
# ['3.5 At 257cv' 'TOURING AWD TODO TERRENO' 'EX V6' '3.5 V6 EX 2WD']
# hyundai
# Creta
# ['1.6 At Safety+' '1.6 At Style' '1.6 At Safety' 'New Creta Safety'
#  '1.6 SAFETY PLUS AT' 'NEW CRETA 1.5 CVT SAFETY'
#  'NEW CRETA 1.5 CVT SAFETY +' 'NEW CRETA' 'Safety Plus' 'Safety 1.6'
#  'Safety 1.6 At' '1.6 Gl Connect Automática' '1.6 Gl Automática'
#  'Style 1.6 At' 'New 1.5 AT Safety +' '1.6 Style At' '1.5 At Safety +'
#  'NEW CRETA SAFETY' '1.6 Gl Manual' '1.6 Gl Connect Manual' '1.6 Gl'
#  '1.5 At Safety' 'SAFETY +' 'CRETA' 'AT Safety' 'safety 1.6 AT'
#  'Automatica']
# Galloper
# ['2.5 I 4x4 Exd' '2.5 4x4 Xl Ll' '2.5 4x4' '4x4']
# Grand Santa Fé
# ['2.2 Crdi Premium 7as' '2.2 Crdi Premium 7as Gps']
# Kona
# ['1.6 Tgdi Tct Ultimate' '1.6 Tgdi Tct Safety']
# Santa Fe
# ['2.4 Seguridad 7as 6at 2wd' '2.2 Crdi Premium 7as 6at 4wd'
#  '2.4 Gls 7as 6mt 2wd' '2.4 Premium 5as 6at 4wd' '2.7 V6 7 Pas. Pre At'
#  '2.2 Gls Premium 5as Crdi 6at 4wd' '2.4 Gls Premium 5as 6at 4wd'
#  '2.4 Premium 7as 6at 4wd' '2.2 Gls Premium 7as Crdi 6at 4wd'
#  '2.2 Gls Crdi 5at Premium' '2.7 V6 Gls 4at Premium'
#  '2.2 Gls Crdi 5at 7p Premium' '2.7 V6 Gls 4at 7p Premium'
#  '2.2 Crdi 7 Pa.pre' '2.2 Gls Premium 7as Crdi 6mt 4wd'
#  '2.4 Gls Premium 7as 6at 4wd' '2.7 V6 Gls 5mt Premium' '2.7 V6 5 As.pre'
#  '2.2 Gls Crdi 5mt Premium' '2.4 Gls 7as 6mt 4wd'
#  '2.2 Gls 7as Crdi 6mt 4wd' '2.7 V6 5 Pas. At' '2.7 V6 5 Pas. Pre'
#  '2.7 V6 5 As. At' '2.4 Seguridad 7as 6mt 2wd' '2.7 V6 5 Pas. Pre At'
#  '2.7 V6 Gls 5mt 7p' '2.2 Crdi Chapelco 7as' '2.2 Crdi 5 As.pre At'
#  '2.2 Gls Crdi 5mt 7p']
# Tucson
# ['2WD AT 2.0' '2.0 Gl 5mt 2wd' '2.0 16v' '2.0 CRDI 4WD FULL PREMIUM'
#  '2.0 Gl 6at 2wd' '2.0 Crdi 2wd 4at' '2.0 Premium' '2.0 Gls 6at 4wd'
#  '2.0 Gls Premium 6at 4wd' '2.0 Gl 154cv 6at 2wd' '2.0 C/techo' '2.0'
#  '2.0 4x4 Crdi At' '2,0 2WD' '2.0 4WD CRDI AT FULL PREMIUM' '1.6 Tgdi Tct'
#  '2,0 EXCLUSIVE CRDI 4X4 AT' 'TUCSON 2.0 2WD AT' '2.0 Gl 154cv 6mt 2wd'
#  '2.0 DOHC' '2.0 4x2 AT' '2.0 Gls 5mt 4wd' '2.0 4X2 GL AT'
#  '2.0 Gls 154cv 6at 4wd' '2.0 Crdi 4wd Mt' '2.0 N 2wd Mt'
#  'PREMIUN 2.0 CRDI DE 180CV 4X4 AUT' '2.0 N 4wd Mt Cvvt' 'Style 2.0 At'
#  '2.0 4X2 AT' '2.0 DOHC MT' '2WD 2.0 AT' '2.0 Crdi 4wd' 'Gls'
#  'HYUNDAI TUCSON 2,0 4X2 GL AT' '2.0 CDRI 4WD DE 180CV'
#  '2.0 4X2 STYLE AT L18' '2.7 N V6 4wd At 6abg' '1.6 TGDI tct 4x4'
#  '2.0 Crdi 4wd 4at' '2.0 4x4 Crdi' '2.0 CRDI 4X4 PREMIUM'
#  '2.0 Crdi 4wd Mt 6abg' 'Tucson GL 2.0 2WD' '2wd At' 'Automatico'
#  '2.0 Gls 154cv 6mt 4wd' '2wd Techo Panorámico' '2WD 2.0'
#  '1.6 4X4 FULL PREMIUM AT L17' '2.0 Crdi 4wd 4at 6abg' '2.0 4x4'
#  '2.7 4x4 V6 At' '2 WD 2.0' '2.0 4x2']
# Veracruz
# ['3.0 Gls Premium 7as Crdi V6 At' '3.8 Gls Premium 7as L V6 At']
# volkswagen
# Crossfox
# ['Trendline' 'Highline']
# Ecosport
# ['Xls 1.6']
# Nivus
# ['1.0 Tsi 200 Comfortline' '1.0 Tsi Tiptronic Comfortline'
#  '1.0 Tsi 170 Mt' '1.0 Tsi 200 Highline' '1.0 Tsi 170 Mt Confortline'
#  '1.0 Tsi Tiptronic Highline' '1.0 Tsi Tiptronic Hero'
#  'COMFORTLINE 200TSI 1.0 TIP' '1,0 170TSI MT' 'Highline 200TSI AT'
#  '200 tsi At Confortline' '1.0 Trendline 170 TSI' '170 TSI'
#  'COMFORTLINE TSI 170 MT' '200tsi Automática Vw 0km 2024'
#  '170tsi Manual Vw 0km 2024' 'COMFORTLINE 200TSI'
#  'Concesionario Oficial Verificado. Todas las versiones disponibles'
#  'Highline At' 'HIGLINE AT 1.0 200 TSI 116 CV' 'COMFORTLINE TSI 200 AT'
#  'Comfortline' '200 TSI HIGHLINE AT L20' '1.0 COMFORTLINE MT'
#  '1.0 Tsi Comfortline At' '1.0 TSI COMFORTLINE 200 AT'
#  '1.0 TSI HIGHLINE 200 AT' 'Nivus Comfortline 200 TSI AT' 'Highline'
#  '200 Tsi Highline Tiptronic' '170TSI MT' 'HIGHLINE 200 AT'
#  'HIGHLINE 1.0 TSI 200' 'Highline 200 tsi' '200 TSI COMFORTLINE AT L20'
#  'comfortline 200 TSI']
# Suran
# ['1.6 HIGHLINE L15' '1.6 TRENDLINE L15' '1.6 5D' 'Confort Line'
#  'MSI 1.6 16V' '1.6 TRACK L17' '1.6 COMFORTLINE L15'
#  '1.6 CROSS HIGHLINE L13' '1.6 I Comfortline 90a' 'Trendline']
# T-Cross
# ['1.0 170 Tsi Mt' '1.6 Trendlinde Mt' '1.6 Comfortline At'
#  'Trendline 170 TSI MT' '1.0 200 Tsi Highline Aut'
#  '1.0 200 Tsi Comfortline Aut' 'Trendline 170 TSI' '1.6 Comfortline Mt'
#  '170 TSI' '1.6 Highline At' 'T-Cross Trendline 170 TSI MT'
#  'TRENDLINE 1.6 MSI 110CV' 'comfortline 1.6 MSl'
#  '1.6 Trendlinde Mt Puertas: 5' '170 TSI manual' '170 Tsi Mt'
#  '1.0 170 TSI Manual' '1.6 TRENDLINE L19' '1.6 HIGHLINE AT6 L19'
#  '1.6 Trendline Mt' 'trendline 170 tsi mt' '1.0 TSI MT'
#  'T-Cross 1.6 Trendline' '1.0 170 TSI' '1.0 Comfortline 200 TSI AT'
#  '170 Tsi' '1.6 COMFORTLINE AT6 L19' '1.6 COMFORTLINE L19' 'Trendline'
#  '170TSI' '170 TSI MT' '170tsi Trendline' '170Tsi MT' 'highline hero 1.6']
# Taos
# ['1.4 250 Tsi Highline' '1.4 250 Tsi Comfortline' '1.4 250 Tsi Hero'
#  'BI tono 1.4 250 tsi Aut' '1.4 250 TSI COMFORTLINE TIPTRONIC L23'
#  'Highline' 'HIGHLINE BI-TONO 250TSI 1.4 TIP' 'HIGHLINE 250TSI 1.4 TIP'
#  'Highline Bi Tono' 'Comfortline 1.4 Tsi 150cv Tiptronic'
#  'Comfortline 1.4 Tsi Aut 150 Cv' 'HIGHLINE BI TONO' 'Confortline 250 Tsi'
#  'Comfortline' '1,4 250TSI 150HP COMFORTLINE' 'HIGHLINE 250 TSI AT MY24'
#  'CONFORTLINE 1.4 TSI' 'COMFORTLINE 250 TSI AT' 'HIGHLINE 250TSI AT'
#  '1.4TSi Comfortline 250Nm' '250 TSI COMFORTLINE TIPTRONIC'
#  'COMFORTLINE MY24' 'HIGHLINE BITONO' 'Comfortline 250 tsi At'
#  'Concesionario Oficial Verificado 0810-112-7211 Opcion 1'
#  'Highline 250 Tsi At' 'Highline 250 TSI AT'
#  'Concesionario Oficial Verificado 0810-112-7211 Opción 1'
#  'highline bitono' '2024' 'Highline 250 tsi bi Tono' 'Comfortline 250 TSI'
#  'Highline 250 TSI' '1.4T HIGHLINE AT' 'HIGHLINE 250 TSI BT'
#  '1.4 250 TSI Highline Tiptronic' 'HIGHLINE 1.4 TSI 150cv TIPTRONIC'
#  '1.4 250 Tsi Highline Tip' 'Comfortline my24' 'High Line' 'BITONO'
#  'Comfortline At' 'Comfortline 250 tsi' 'Comfortline 250Tsi AT'
#  '1.4 250 TSI HIGHLINE TIPTRONIC L21' 'HIGHLINE BI TONO 250TSI'
#  'Highline 250Tsi AT' '1.4 TSi Highline 250' 'COMFORTLINE 250TSI'
#  'Confortline tsi' '1.4 250 Tsi Comfortline Tip' 'HIGHLINE 2024'
#  'Comfortline 1.4 Tsi' '250 TSI HIGH BI TONO' '1.4' 'CONFORTLINE 1.4T'
#  '1.4T COMFORTLINE AT']
# Tiguan
# ['2.0 Tsi Sport Style Tiptronic' '2.0 Exclusive Tsi 200cv Tiptronic'
#  '2.0 Tsi Premium Tiptronic' '2.0 Premium Tsi 200cv'
#  '2.0 Premium Tsi 200cv Tiptronic' '2.0 Exclusive Tsi 200cv'
#  '2.0 Premium I 140cv Tiptronic' '2.0 Tsi Exclusive Tiptronic'
#  '2.0 Sport & Style Tsi 200cv' '2.0 Tsi Sport Style Mt'
#  '2.0 Sport & Style Tsi 200cv Tiptronic'
#  '2.0 T ALLSPACE COMFORTLINE AT L17' '250 Tsi Dsg' 'LIFE 350 TSI 4M'
#  '1.4 Tsi Dsg' '1.4T ALLSPACE' '1.4 T 250 TSI ALLSPACE TRENDLINE AT L20'
#  'E-MOTION AT' '1.4 TSI TRENDLINE DSG 7AS'
#  '1.4 T ALLSPACE TRENDLINE AT L17'
#  '2.0 T 350 TSI 4MOTION ALLSPACE LIFE DSG'
#  '2.0 Sport & Style I 140cv Tiptronic' '2.0 PREMIUM TSI TIPTRONIC 4x4'
#  '2.0 Tsi Exclusive Mt' '2.0 Elegance Tsi 200cv' 'Life 350 TSI DSG 4x4'
#  '2.0 I Exclusive Tiptronic' 'TSI DSG' '2.0 I Sport Style Tiptronic'
#  '2.0 TSI 4MOTION' '2.0 TDI 4 imotion exclusive Dsg'
#  '2.0 Elegance Tsi 200cv Tiptronic' '2.0Sport Style Dsg'
#  '2.0 Elegance I 140cv Tiptronic' 'Trendline' '1.4 TSI DSG At' '250 TSi'
#  '2.0 Tsi Sport Plus Mt' 'ALLSPACE 1.4 TSI' '2.0 Tdi 4 Motion'
#  'ALLSPACE 1.4 TSI AT' 'HIGHLINE 2.0 TSI 4MOTION DSG' 'TSI SPORT MT'
#  '2.0 TSI 4 MOTION' '2.0 COMFORTLINE TSI 4MOTION DSG'
#  '2.0 Exclusive I 140cv Tiptronic' 'sporto style dsg'
#  '1.4allspace trendlin' '2.0 Tsi Sport Plus Tiptronic']
# Tiguan Allspace
# ['2.0 Tsi Life 4Motion Dsg' '2.0 Tsi Highline Dsg'
#  '2.0 Tsi Comfortline Dsg' '1.4 Tsi Trendline 150cv Dsg'
#  '2.0 Highline Tdi 4Motion Dsg' 'Trendline' '250TSI DSG Comfortline'
#  'LIFE 350TSI' '2024' 'Life! 350 Tsi' '2.0 HIGHLINE TDI DSG 4MOTION AT'
#  '1.4 TSI TRENDLINE DSG' 'LIFE 2.0 350TSI 220cv'
#  'Life 350 Tsi 4Motion DSG' '250' 'ALLSPACE 2.0 350 TSI 4X4 AT 220CV'
#  'LIFE' '2.0 TDI HIGHLINE DSG' '1.4 Trendline R LINE']
# Touareg
# ['3.6 V6 Premium' '3.0 V6 I Elegance 240cv' '2.5 I' '2.5 R5 I Premium'
#  '4.2 V8 Premium' '3.6 V6 Fsi Elegance' '4.2 V8' '3.6 V6 Style' '5.0 I'
#  '4.2 V8 Fsi Premium' '3.2 V6' '3.0 V6 I Premium 240cv'
#  '3.0 V6 I Style 204cv']
# land rover
# Defender
# ['2.5 110 Sw County' '2.5 110 Sw Aa' '2.4 Sw 110 7s Plus'
#  'HSE X-DYNIMIC PLUG IN HYBRID' '90 TDI SOFT TOP' '2.4 Sw 110 5 Alloy'
#  'Hse X-dynimic Phev' '2.5 110 Sw' 'HSE X-DYNAMIC PLUG IN HYBRID'
#  '2.5 110 5 Sw' '2.5 110 5 Sw Aa' '2.4 Sw 110 7s M' '2.4 C Sw 110 7-seat']
# Discovery
# ['2.0 Sport Se 240cv' '4.4 3 V8 Hse At' '2.0 Sport Hse 240cv'
#  '2.7TD V6 HSE' '4.0 V8 At' '4.0 V8 Es At' '2.7 3 V6 At' '3.0 I'
#  '2.7 4 V6 Se' '3.0 I Es' '3.0 5 S']
# Evoque
# ['2.0 Hse Dynamique Coupe 240cv' '2.0 Prestige Plus 240cv'
#  '2.0 Hse Dynamic 240cv' '2.0 Pure Plus 240cv' '2.0 Dynamic 240cv'
#  '2.0 Hse Plus 240cv' '2.0 Hse 240cv' '2.0 Coupe 240cv'
#  '2.0 Se Mhev Hibrid' '2.2 Prestige 190cv' '2.0 Pure Se 240cv'
#  'SI4 2.0 TODO TERRENO' '2.0 Se R-dynamic Mhev Hibrid'
#  '2.0 Prestige 240cv' '2.0 Dynamic Plus 240cv' 'Si']
# Freelander
# ['2.0 4 Hse At' '2.0 Xedi' '2.2 2 S 4 At Plus' '2.0 S Plus 240cv Awd At6'
#  '3.2 2 S I6 At Plus' '2.2 2 Se 4 At' '2.0 4 Se' '2.2 2 Hse 4 At'
#  '2.2 2 Se 4 Mt' '1.8 Xei' '1.8 Gs']
# Range Rover
# ['4.0 Se' 'Range Rover Velar P250S R-Dynamic' '4.4 Sport Hse'
#  '2.7 V6 Sport Hse' '2.5 I' 'Sport TDV6 Hse 4x4' '4.6 Vogue' '2.7 V6 HSE']
# Range Rover Sport
# ['3.6 Hse V8' '5.0 V8 S/c' '5.0 V8 S/c Hse' 'AT 3.6 V8' '3.0 V6 Hse']
# audi
# E-tron
# ['Sportback 55 S Line Quattro' 'SPORTBACK S LINE 55 QUATTRO 408CV'
#  '55 Quattro' 'Sportback 55 Sline Quattro']
# Q2
# ['1.5 35 Tfsi Advanced 150 Cv' '2.0 40 Tfsi Stronic Sport Quattro'
#  '1.4 35 Tfsi Sport 150 Cv' '1.4 Tfsi Serie 150 Cv' '40tfsi Quattro'
#  '1.4 Tfsi Sport 150 Cv' '1.0 30 Tfsi Stronic Sport' '35 tfsi Advanced'
#  '1.4 TFSI STRONIC' '2.0 Tfsi Stronic Sport Quattro' '40 Tfsi Quattro'
#  '1.4 T FSI S-Tronic Sport' '1.5 35 TFSI ADVANCED 150CV']
# Q3
# ['1.4 35tfsi 150 Cv' '1.4 Tfsi Stronic 150 Cv' '1.4 Tfsi Sport 150 Cv'
#  '2.0 Tfsi Sport 220cv' '2.0 T 170HP QUATTRO L12'
#  '2.0 Tfsi Stronic Quattro 220cv' '2.0 Quattro Tfsi 170cv Stronic'
#  '2.0 Quattro Tfsi 211cv Stronic' '2.0 40tfsi Quattro 220cv'
#  '1.4 Tfsi 150 Cv' '1.4 Tfsi 120cv 4x2' '2.0T QUATTRO S-TRONIC'
#  '2.0 40Tfsi Quattro Advance 180Cv' '2.0 Quattro I 177cv Stronic'
#  '2.0 Quattro Tfsi 170cv' '2.0 QUATTRO TFSI S-TRONIC']
# Q3 Sportback
# ['1.4 35tfsi Sportback 150 Cv' '2.0 40tfsi Quattro Sportback 220cv'
#  '40tfsi quattro' '35 TFSI' '2.0 40Tfsi Quattro S Line 190Cv']
# Q5
# ['2.0 45 Tfsi Sport 252cv' '2.0 Tfsi 225cv Tiptronic Quattro'
#  '2.0 Tfsi Stronic Quattro Security 252cv'
#  '2.0 Tfsi Tiptronic Quattro 225cv' '2.0 Tfsi Stronic 252cv'
#  '45 tfsi S-tronic quattro' '3.0 I 240cv Stronic Quattro'
#  '2.0 Tfsi 211cv Stronic Quattro' '2.0 45 Tfsi Offroad 252cv'
#  '2.0 Tfsi 252cv' 'Advanced 45 Quattro 252cv Stronic'
#  'Sportback 45 TFSI Advanced' '2.0 45 Tfsi Security 252cv'
#  '3.2 Fsi 270cv Stronic Quattro' '2.0 I 177cv Stronic Quattro'
#  '2.0 Tfsi 225cv Quattro' '2.0 Tfsi 211cv Quattro'
#  'SPORTBACK 45 TFSI S LINE QUATTRO'
#  '45 TFSI ADVANCED S TRONIC QUATTRO 245cv' 'Advanced 45 TFSI'
#  'Advanced 45 tfsi Quattro' '3.0 Tfsi Tiptronic Quattro 272cv'
#  'Sportback Sline 45tfsi' '45 Tfsi' '2.0 TFSI 45 252CV' '45 tfsi advanced'
#  '2.0 Tfsi Tiptronic Quattro 250cv'
#  'Q5 45 TFSI Advanced ( 245cv ) Mild Hybrid'
#  '2.0 Tfsi S Tronic Quattro 252cv - Anticipo -' 'TDI QUATTRO' 'Offroad'
#  '2.0 Tfsi 180cv Quattro' '2.0 Tfsi Quattro' 'Audi Q5 Advanced 45'
#  'Tdi 3.0 Quatro' 'Advanced 2.0 quattro' 'Q5 2.0 tfsi quattro'
#  '2.0 I 170cv Stronic Quattro' '2.0 I 170cv Quattro'
#  '2.0 Tfsi 211cv Quattro Luxury' '2.0T LUXURY FSI QUATTRO'
#  'TFSI S TRONIC QUATTRO' '3.0 Tfsi 272cv Tiptronic Quattro']
# q5 sportback
# ['2.0 45Tfsi Quattro S Tronic S-Line 245Cv'
#  '2.0 45Tfsi Quattro S Tronic Advanced 245Cv'
#  '2.0 45Tfsi Quattro S Tronic Advanced 265Cv'
#  'Q5 Sportback Advanced 45 TFSI quattro 245 cv Stronic'
#  'Sline 45 TFSI 245cv']
# Q7
# ['3.0 Tfsi 333cv Tiptronic Quattro' '3.0 Tdi 233cv Tiptronic Quattro'
#  '3.0 Tdi 240cv Tiptronic Quattro' '3.0 Tdi 249cv Tiptronic Quattro'
#  '3.0 Tdi Tipt. Quattro' '4.2 Tdi 340cv Tiptronic Quattro'
#  '3.0 Tfsi 272cv Tiptronic Quattro' '55 tfsi Sline'
#  '4.2 Fsi 350cv Tiptronic Quattro' '3.0 Tdi Tipt. Quattro Luxury'
#  '3.0 V6T FSI QUATTRO' '4.2 Tdi 326cv Tiptronic Quattro']
# Q8
# ['3.0 55 Tfsi Quattro' '3.0 55 TFSI QUATTRO S LINE']
# SQ5
# ['3.0 Tfsi Stronic 354cv']
# geely
# Emgrand X7 Sport
# ['2.0 Gs' '2.4 Gt At' '2.4 Gl At' 'GL AT 2.4']
# jaguar
# F-PACE
# ['2.0 Prestige' '2.0d Prestige' '3.0 Sc Prestige']
# daihatsu
# Feroza
# ['1.6 4x4']
# Terios
# ['1.3 Sx 4wd' '1.3 Sx 4wd At']
# subaru
# Forester
# ['2.0 Awd Cvt Dynamic' '2.5 Awd Cvt Limited Sport'
#  '2.5 Awd Cvt Limited Sport l23' '2.5 Awd Cvt Si Driver Diynamic'
#  '2.5 Awd Cvt Si Driver Limited Sport' '2.0 X 5mt Sawd' '2.0 2 Awd Xs At'
#  '2.0 Awd X 6mt' '2.0 2 Awd X 5mt' 'DYNAMIC 2.0 4x4 CVT' '2.0 X 4at Sawd'
#  '2.0 Awd Cvt Xt' '2.0 Awd Cvt Dynamic Eyesight'
#  '2.0 Awd Cvt Si Driver Xt 8at' '2.0 A' '2.0 Xs 4at Sawd'
#  '2.5 Awd Cvt Si Driver Xs' '2.0 X' '2.0 5mt Sawd Limited'
#  '2.5 Xt 4at Sawd Turbo Sportshift']
# Outback
# ['3.6 R Limited' '2.5 Un 4at Sawd 165cv' '2.5 Awd Cvt Xs 173cv'
#  '2.5 Awd Cvt Limited 173cv' '2.5I AWD LIMITED CVT TECH L12'
#  '3.0 R 6at Si-driver Vdc 245cv' '2.5 3s 4at Sawd 173cv Sportshift'
#  '2.5 Awd 6mt Xs 173cv']
# suzuki
# Grand Vitara
# ['2.0 Mt' '2.4 Jlx-l 4wd 4at' '2.7 Xl-7 V6 183 hp' '2.4 Jiii' '2.0 Jiii'
#  '2.4 Jlx-l 4wd 5mt' '1.6 Gas Mt' '2.7 Xl-7 V6 170 hp' 'Jiii'
#  '2.0Nafta 4x4 MT' 'Jlx TD mazda diesel' 'Full' '2.0 Tdi 4x4' 'Tdi'
#  '2.0 I Mt' '2.4 Jx 4dw 5mt' '2.7 Xl-7 V6' '2.0 At' '2.0 Nafta'
#  'TD 2.0 4x4' '5 puertas 2.0 MT' 'HDI 2.0' '1.6 3ptas' '2.4 Jlx 2wd 5mt'
#  'Suzuki grand vitara' '2.0 TD MAZDA' '5 PUERTAS 2.0TD']
# Jimny
# ['1.3 Jlx 4x4' '1.3 Jlx' 'All Grip' '1.3 Jx 4x4 Aa']
# Samurai
# ['1.3 Metal/lona']
# Vitara
# ['1.6 Jlx Sidekick' '1.6 Glx Allgrip 120cv' '1.6 Gl Plus Allgrip 120cv'
#  '1.6 Jx Sidekick' '1.6 Jlx Sidekick 4X4' '1.6 Jlx T/lonasidekick'
#  '2.0 Jlx D Aa' 'Jlx 1.6' 'Jlx' '1.9 4x4 SUV' 'GLX SR 1.6L 4X4  A/T'
#  '1.9 Jx D']
# haval
# H1
# ['1.5 Luxury' '1.5 Elite']
# H6
# ['2.0t Coupe Dignity At 2wd' '4x4' '4wd' 'Luxury'
#  '2.0T 4Wd 3Ra Generacion' '2.0T 4Wd' 'H6 2.0T 4x4' '2wd']
# Jolion
# ['1.5T 2Wd']
# dodge
# Journey
# ['2.4 Se 170cv Atx' '2.4 Sxt 170cv (techo, Dvd, Nav)'
#  '2.4 Sxt Atx Techo 2filas' '2.4 Sxt Atx (3 Filas)'
#  '2.7 Rt Atx (3 Filas)+dvd+techo' '2.7 Rt' '2.4 Sxt Atx Techo 3filas'
#  '2.4 Sxt (3 Filas) 170cv Atx' '2.4 Sxt' '2.4 Sxt 170cv Atx6 (techo, Dvd)'
#  '3.6 R/t Atx Awd 280cv' '2.4 SE 170cv 2 filas' '2.4 Sxt Atx (2 Filas)'
#  '2.7 Rt Atx (3 Filas)' '3.6 R/t Fwd 286cv'
#  '2.4 Sxt Atx (3 Filas)+dvd+techo' '2.4 Sxt 170cv Atx4 (techo, Dvd)'
#  '2.7 Rt Atx (3 Filas)+techo' '3.6 R/t' '"2.4 SXT ATX6 (TECHO, DVD)"'
#  '"""2.4 SXT (TECHO"' '3.6 R/t Awd 286cv' 'SXT 2.4 3 FILAS' 'SE 2.4'
#  '3.6 sxt atx techo 3f' 'SXT' '2.4 SXT DVD techo' 'sxt 2.4']
# nissan
# Kicks
# ['1.6 SENSE L21' '1.6 Special Edition Cvt 120cv' 'Exclusive Cvt'
#  'Advance Cvt' 'Advance' '1.6 X-PLAY NFT CVT' '1.6 ADVANCE CVT L17'
#  '1.6 UEFA CHAMPIONS LEAGUE EL L19' '1.6 Sense Mt'
#  '1.6 UEFE CHAMPIONS LEAGUE EL AT' '1.6 EXCLUSIVE CVT L17'
#  '1.6 Advance Cvt' '1.6 Advance 120cv' '1.6 EXCLUISIVE CVT'
#  'Advance CVT Plus' 'Sense MT F2' '1.6 Sense' '1.6 EXCLUSIVE CVT L21'
#  '1.6 Exclusive Cvt' '1.6 Exclusive 120cv' '1.6 Advance Cvt l21'
#  'Special Edition Cvt' '1.6 SENSE L18' 'SENSE 1.6 MT'
#  'UEFA CHAMPION LEAGUE' 'Sense']
# Murano
# ['3.5 V6 260cv 4wd Cvt' '3.5 Exclusive']
# Pathfinder
# ['3.3 Se Wide' '2.5 Le 4x4 5at' '2.4 4x4' '3.0 Se' '3.3 Se' '2.7 4x4 D'
#  '3.3 Se Wide At' '2.4 4x2']
# Terrano II
# ['2.7 I' '2.7 I Luxury']
# X-Terra
# ['2.8 Td Se 4X4' '2.8 Se 4x4' '2.8 Dte Se 4x4' '2.8D MWM 4x4']
# X-Trail
# ['2.5 Exclusive Cvt Xtronic' '2.5 Exclusive' 'EPower Exclusive Cvt'
#  '2.5 EXCLUSIVE CVT' '2.5 4X4 EXCLUSIVE CVT L21'
#  '2.5 4X4 EXCLUSIVE CVT L23' 'Exclusive' '2.5 Tekna Cvt Xtronic' '2.5 Mt'
#  'E-Power' 'E-POWER' 'ePower' '2.5 Visia Cvt Xtronic' '2.5 Visia 6mt'
#  '2.5 4x4 At' 'X TRAIL 2.5 NAFTA EXCLUSIVE CVT' 'TECKNA'
#  '2.5 4X4 EXCLUSIVE CVT L18' '2.5 Acenta 6mt' '2.5 Acenta Cvt Xtronic'
#  '4X4 2.2 TDI MT6' '2.5 At' '2.2 DIESEL MT6' '2.2 TDI 4X4 MT6'
#  '2.2 DIESEL T30' '2.5 4x4' '2.2 4x4']
# lexus
# LX
# ['LX 570 Luxury']
# NX
# ['300h Luxury' '350h Luxury' '450h F-sport' '300 F-sport']
# UX
# ['UX250H' '250H' '250h Luxury']
# kia
# Mohave
# ['3.8 At' 'Ex']
# Seltos
# ['1.6 Ex' 'Sx' 'Ex' 'EX 1.6 Automatico']
# Sorento
# ['2.2 Crdi Ex' '2.4 Ex 4x2 6at' '2.2 Ex' '2.2 Crdi Gt-line Ex 4x4'
#  '2.4 Ex 4x4 6at' '2.2 CRDI 4X2 MT' '2.2 Crdi Ex 4x4' '2.2 Crdi Ex At 4x2'
#  '2.5 Crdi Ex 4x4 170cv Tgv Esp' '2.4 Ex' '2.2 Ex Premium 4x4 6at'
#  '2.4 Ex Premium 4x4 6at' '2.5 Ex Crdi 140 Hp At Exe' '2.2 CRDI EX 4x4 AT'
#  '2.4 Ex At 4x2' '2.5 Ex Crdi 140 Hp At' '2.2 4WD CRDI EX AT L16'
#  '2.2 Crdi Ex 4x2 Mt' '2.2 Crdi 4×2 Mt' 'Sorento ex 2.4 l 4x2' 'Nafta'
#  'EX 3.8 V6 4X4 AT' '2.5 Crdi Ex 4x4 At 140cv' '3.8 Ex 4x4 At Esp'
#  '2.5 Ex Crdi 170 Hp At' '2.2 CRDI AT' '3.5 Ex At Executive'
#  '3.5 Ex 4x4 At' '2.5 Ex 4x4 At' '3.5 Exclusive 4x4 At' '2.2 Ex 4x4 6at'
#  '3.8 Ex At']
# Soul
# ['1.6 Pop 4at' '1.6 Ex At' '1.6 Classic 5mt' '1.6 Ex 132cv 6at'
#  '1.6 Ex Bc 132cv 6at' '1.6 EX AT 4x2' '1.6 Pop 132cv 6at' '1.6 Pop 5mt'
#  '1.6 Ex Premium 6at' '1.6 Ex 132cv 6mt' '1.6 Rock 132cv 6at'
#  '1.6 Classic 132cv 6mt' 'EX 1.6 A/T' '1.6 Ex Bc 132cv 6mt' '1.6 Rock 5mt'
#  '1.6 Rock 4at']
# Sportage
# ['2.0 Ex 154cv' '2.0 Crdi Ex Gt-line At 4x4' '2.0 Crdi Ex' '2.0 Ex 4x2'
#  '2.0 Ex Mt 4x4 Esp' '2.0 Ex 2wd 163cv At' '2.0 Ex Premium At 154cv 4x2'
#  '2.0 Ex' '1.6 Ex X-Line T-Gdi Awd' '2.0 Crdi Ex 4x2 Automática'
#  '2.0 Ex At 154cv 4x2' 'EX 1.6 T TGDI DCT A/T 4x2' '2.0 Ex At 154cv 4x4'
#  '2.0 Ex 4wd 163cv At' 'Xline' 'Kia Sportage Xline' 'Kia New Sportage'
#  'New Awd 1.6 Turbo A7' 'Kia New Sportage 4x2' 'EX 1.6 TGDI 4x2'
#  'X-Line 1.6 TGDI' 'EX 1.6 T-GDI 4X2' '4x4 New Sportage 1.6 T / At'
#  'EX X-Line 1.6 Turbo' 'X-Line' 'Ex TGDI' 'Ex 4X4' 'Lx' '4X2 7AT'
#  'GDI AT 1.6 TURBO' 'X- Line T-GDI 4x4 1.6 Turbo' '2.0 Crdi Ex At 4x2'
#  'Ex 1.6 T-gdi 4x2' '2.0 Ex 4wd 163cv 6at' '2.0 EX AT 4x2'
#  '2.0 Crdi Ex At 4x4 Esp' '2.0 EX AWD' '2.2 4x4 D' 'EX PREMIUM 4WD'
#  'EX 1.6 T-GDI 4x2' '2.0 4X2 EX AT L18' 'X-line 4x4 1.6t'
#  'EX 1.6 TGDI DCT 4X' '4x2' 'X LINE 1.6T' 'X - LINE 1.6T'
#  '2.0 Crdi Ex Mt 4x4 Esp' 'EX 2.0' 'EX 2.0 AT 4x4 GT LINE'
#  'EX 2.0 A/T 4X4 CRDI' '2.0 Ex 2wd 163cv Mt' 'EX 2.0 AT' '2.0 4x4 Crdi At'
#  '2.0 Ex 154cv 4x2' 'Ex' 'EX 2.0 A/T 4X2' 'EX 2.0 A/T' '2.0 Ex Mt 4x2 Esp'
#  'EX 2.0 A/T CRDI' '2.0 4x4' '2.0 4x4 Crdi' 'EX 2.0 A/T 4x4 CRDI']
# mitsubishi
# Montero
# ['3.5 Semi High V6 At' '3.2 Di-d Gls At Abcp+cu' '2.8 Gls I Tc' '2.5 Glx'
#  '3.2 Gls Di-d 190cv At C/t' '3.2 Gls Di-d Tc Cu At' '3.2 Gls Di-d At'
#  '2.8 Glx D' '2.8 Gls I' '2.6 Gl Metal Top' '2.8 Gls I Tc At'
#  '2.8 Gls I At' '3.0 V6' '3.2 Di-d Gls Mt Abcp+cu' '3.2 Gls Di-d Tc Cu']
# Nativa
# ['3.0 Ls V6 4x4' '2.5 Glx I 4x4' '3.0 Ls V6 4x4 At']
# Outlander
# ['2.4 Gls At' '2.4 Gls At Ab Lat Cu Cortina' '2.4 Gls 170cv At C/t'
#  'Gls 4x4 At' '2.4 Gls 169cv' '3.0 V6 4X4 At' '2.0 Sport 2wd Gls 150cv Mt'
#  '2.4 Gls At Tc+cu' '2.4 GLS AUT 4x4' '2.0 Sport 4wd Gls 150cv At'
#  '3.0 Gls 220cv At C/t']
# lifan
# Myway
# ['Nafta' '1.8 16v' '1.8 vtv']
# X70
# ['2.0 Vvt-i Cvt']
# jac
# S2
# ['1.5 Intelligent']
# S5
# ['2.0t Intelligent At' 'S5 INTELLIGENT DCT']
# bmw
# Serie 4
# ['3.0 440i Gran Coupe M Package 326cv']
# X1
# ['2.0 Sdrive 25i Xline 231cv' '2.0 Sdrive 20i Sportline 192cv'
#  '2.0 Sdrive 18i Active' '2.0 Sdrive 20i Msport X'
#  '3.0 Xdrive 28i Executive 265cv' '2.0 Sdrive 18i Active 150 Cv'
#  '2.0 Sdrive 20i Sportline' 'xDrive 25i (231 cv)'
#  '2.0 Xdrive 25i Xline 231cv' '2.0 Xdrive 20i Executive 184cv'
#  '18i sdrive' '2.0 XDrive 231cv AT 4WD' '2.0 Xdrive 20d Executive 177cv'
#  '18I SDRIVE' 'X1 linea nueva 2024 - Tablero curvo Okm - Full'
#  'X1 Linea nueva 2023 - Black edition (limitada)'
#  'X1 20i Linea nueva 2024 - 4x4'
#  'X1 Linea nueva 2024 - Black edition (limitada) 4x4 - 205 CV'
#  'X1 Linea nueva 2023 - 205 CV' 'X1 25i 2031 cv - 4x4 - Automática'
#  'X1 25i xdrive xline' '18i' '2.0 Sdrive 20d Active 177cv Manual'
#  'Xdrive 20 I' '25I XDRIVE 231CV' '2.0 Sdrive 20i Active 184cv'
#  'Xdrive 25i' 'Xdrive' '2.0 SDRIVE ACTIVE' '20i Sdrive Sport'
#  '2.0 Sdrive 20d Active 177cv' 'xDrive 25i' 'X1 20i X-Drive'
#  '2.0 Xdrive 20d Active 177cv' '20i Sportline' '1.8I S-Drive AT'
#  '25i XDrive' 'BMW X1 Xdrive 2.0 L' '25i xLine xDrive' 'TODOTERRENO'
#  '2.0 Xdrive pack M' 'X1 SDRIVE 18I' '25i Xdrive Xline'
#  'XDrive 25i XLine 231cv' 'BMW X1 2.0 Xdrive 25i Xline 231cv'
#  'X drive 2.0 diesel' 'X25i']
# X2
# ['2.0 Sdrive20i Msportx' '2.0 Sdrive 20i Msport X' '2.0 Sdrive20I Gp'
#  '2.0 M35i Mpa' 'X2 35i M Performance 4x4 con 306 CV' '35 I'
#  'sDrive 20i M Sport X' '20i Sport' 'Sdrive 20 I']
# X3
# ['2.0 Xdrive 30i Xline' '2.0 Xdrive 20i Executive 184cv'
#  '3.0 X3 Xdrive 35i M Package 306cv' '2.0 Xdrive 20I Xline 184Cv'
#  '3.0 X3 Xdrive' 'Xdrive 30e' '2.0 Xdrive 20d Active 184cv'
#  '2.5 Si Selective' '3.0 X3 Xdrive 35i Executive 306cv'
#  '2.0 Xdrive 20d Executive 184cv' '2.5 X3 I Executive'
#  '2.0 Xdrive 28i Xline 245cv' '30i Xdrive' '2.5 Si Xdrive Limited Edition'
#  'BMW X3 30i Okm 2024 Linea nueva - Tablero digital - 258 CV - 4X4' '30e'
#  'BMW X3 Hibrida Okm 2024 - Linea nueva - Llantas 20' 'M40I'
#  '2.0 Xdrive 30E Xline' 'X3 XDrive 3.0' 'Xdrive 30I' '30i XDRIVE PACK M'
#  '2.0 30i' '2.0 Xdrive 30i Executive' '3.0 Iexecutive Stept' 'Hibrida'
#  'M40i Sport' 'X3 M40i Drive Sport' 'xDrive 30e' '3.0 X3 I Executive'
#  '2.5 2.5si Selective' '2.5 Xdrive25i' '2.5 2.5si Selective Stept'
#  '2.0 Xdrive 20i 184cv' 'M' 'hibrida' '3.0 D Executive Stept'
#  '3.0 X3 D Executive' '30E']
# X4
# ['3.0 Xdrive 35i 306cv M Package' '2.0 Xdrive 20i 184cv'
#  '2.0 Xdrive 28i Xline 245cv' '2.0 Xdrive 20i Executive 184cv'
#  '20i xdrive' 'X4 20i automática 184 cv - 4x4 año 2019']
# X5
# ['3.0 Xdrive 40d M Package 313cv' '3.0 Xdrive 35i Executive 306cv'
#  '3.0 D Executive Stept' '40i Xdrive' '3.0 D Executive'
#  '3.0 Xdrive 35i 306cv Pure Excellence' '3.0 Si Executive' '4.4 M 555cv'
#  '4.4 Xdrive 50i 449cv M Package' '4.4 Xdrive 50i Premium 407cv'
#  '4.8 4.8l Premium Stept' '40i' 'X5XDRIVE40I' 'xDrive 40i'
#  '4.4 Xdrive 50i 449cv Security' '40i xDrive' '40I X DRIVE'
#  '3.0 Xdrive 30d Executive 245cv' '40i XDrive' '4.8 Is Premium'
#  '4.8 4.8is Premium' '4.8 4.8i Premium Stept' '3.0 I Executive Stept'
#  '3.0 Si Executive Stept.' '4.8 Is Premium Stept'
#  '4.4 4.4i Premium Security' '40M' 'X5 XDRIVE 40i'
#  '3.0 D Executive Stept.' '3.0 Iexecutive Stept']
# X6
# ['3.0 Xdrive 35i Sportive 306cv' '4.4 M 555cv' 'M'
#  '3.0 Xdrive 35i Pure Extravagance' '4.4 Xdrive 50i Premium 407cv'
#  '4.4 Xdrive 50i M Package 449cv' 'BMW X6 xDrive 40i'
#  '3.0 Xdrive 30d Sportive 245cv' 'X6 M']
# alfa romeo
# Stelvio
# ['2.0 280cv At Q4 Super' '2.0 200cv Distinctive Q4'
#  '2.0 280cv At Q4 Veloce' 'NEW Veloce Q4' '2.0 280cv' '2.0 200cv']
# chery
# Tiggo
# ['2.0 F2 Confort 4x2 138cv' '2.0 F2 Luxury 4x4 138cv'
#  '1.6 F2 Confort 4x2 125cv' '2.0 F2 Luxury 4x2 At 138cv'
#  '2.0 Confort 4x2 127cv' '3 1.6 4X2 CONFORT L16' '2.0 Luxury 4x4 127cv'
#  'luxury manual' '2.0 4X4 LUXURY L13' '2.0 Confort 4x2 GNC'
#  '5 2.0 LUXURY CVT']
# Tiggo 2
# ['1.5 Confort' '1.5 Luxury' 'Luxury 4x2 At']
# Tiggo 3
# ['1.6 3 Confort' '1.6 3 Luxury' '1.6 3 Luxury Cvt' '1.6 CONFORT MT'
#  'Luxury' 'cvt luxury 1.6' '1.6 Luxury Cvt' 'Confort manual 4x2']
# Tiggo 4
# ['2.0 Comfort Cvt' 'LUXURY CVT AUTOMÁTIC' '1.5 Confort Manual'
#  '1.5 pro luxury cvt' '1.5 Turbo Luxury Cvt' 'PRO']
# Tiggo 4 Pro
# ['1.5 Comfort Cvt' '1.5T Luxury Cvt' 'Comfort cvt' 'Luxury cvt'
#  'Confort Cvt 1.5L' '1.5 Comfort Mt' '1.5 Luxury Cvt' 'Luxury CVT 1.5T'
#  '1.5 Confort Manual' 'Confort Mt']
# Tiggo 5
# ['2.0 Luxury At' '2.0 Luxury' '2.0 5 Comfort' '2.0 Comfort']
# Tiggo 8 Pro
# ['1.6 Luxury Cvt' 'Luxury cvt' '1.6 T luxury Cvt 7 Plazas' 'Luxury CVT']
# baic
# X25
# ['1.5 Elite' '1.5 Elite At']
# X35
# ['1.5 Luxury At' '1.5 Luxury' 'CONFORT TURBO "SPORT" CVT'
#  'CONFORT TURBO CVT' 'LUXURY TURBO SPORT BI-TONO' '1.5 Fashion At'
#  '1.5 Cvt Fashion' 'Turbo' 'Fashion Turbo']
# X55
# ['1.5t Elite Cvt' '1.5T' 'II LUXURY TURBO' 'II LUXURY BI-TONO' 'II LUXURY'
#  'Ii' '1.5T Luxury Dct AT' '1.5 Turbo Dct - Luxury'
#  '1.5 TURBO DCT - LUXURY BI-TONO' '1.5 TURBO CTV - LUXURY'
#  '1.5T LUXURY DCT AT' '1.5 TURBO DCT - LUXURY' '1.5 turbo Honor'
#  '1.5T DCT LUXURY' 'SUV' 'Luxury']
# jetour
# X70
# ['1.5 Lt At' 'Turbo' 'x70 7 plazas' 'At Premium' '2.0 T']
# volvo
# XC40
# ['2.0t T4 Momentum Fwd' '2.0t T5 R-design Awd' '2.0t T4 Inscription Awd'
#  'XC 40 T5 AWD' 'PLUS B4 MILD HYBRID' 'Plus' 'XC40 T5 PHEV'
#  'B4 ULTIMATE MILD HYBRID' 'B4 MILD HYBRID' 'B4 PLUS MILD HYBRID'
#  'T4 MOMENTUM' 'ULTIMATE B4 MILD HYBRID' 'T5 MOMENTUM AWD 247HP'
#  'Ultimate' 'XC40 T5 262HP ULTIMATE DARK' 'T5 R-design AWD 247hp'
#  'B4 PLUS SEMIHIBRIDO']
# XC60
# ['2.0 T5 Awd Comfort 240cv' '3.0 T6 High Plus 304cv At Awd'
#  '2.0 Awd 203cv' '3.0 T6 High 304cv At Awd' '2.0 T5 High Plus 240cv At'
#  '2.0 T5 High 240cv At' '2.0 T5 Inscription' 'INSCRIPTION T6 AWD AT'
#  '2.5 T5 Momentum' '2.0t T5 Momentum Awd' 'T8 ULTIMATE DARK'
#  'T5 Awd Inscription' '3.0 T6 Awd High Luxury 304cv'
#  '3.0 T6 High Lux R-design 304cv At Awd' 'T5 240CV'
#  '3.0 T6 Awd High Plus 304cv' '2.0 T5 Awd High Plus 240cv'
#  'T6 INSCRIPTION 320HP' '3.0 T6 High Luxury Awd' '2.5 T5 Inscription']

# %%
import re

# Definir la función para limpiar las versiones
def clean_version(version):
    cleaned_version = " ".join(str(version).split()).strip().lower()
    #si dentro de una palabra hay una tilde la reemplazo por la vocal sin tilde
    cleaned_version = re.sub(r'[á]', 'a', cleaned_version)
    cleaned_version = re.sub(r'[é]', 'e', cleaned_version)
    cleaned_version = re.sub(r'[í]', 'i', cleaned_version)
    cleaned_version = re.sub(r'[ó]', 'o', cleaned_version)
    cleaned_version = re.sub(r'[ú]', 'u', cleaned_version)
    return cleaned_version

# Hago una copia de la columna 'Titulo' para ver si la función funciona correctamente
data['Título versión'] = data['Título'].apply(clean_version).str.cat(data['Versión'].apply(clean_version), sep=' ')
data['Título versión motor'] = data['Título versión'].str.cat(data['Motor'].apply(clean_version), sep=' ')

# %%
keywords_motor = ['1.6', '2.0', '2.8', '2.7', '1.8', '3.0', '4.0', '4.5', '4.2', '2.5', '2.4', '1.4', '1.0', '1.3', '1.2', '2.3', '2.9']
#1.8l
#2,8
#2.5l
#2.8tdi
# 2.8srx204cv4x4
#1.0t
# 1,3
# 1,6 

keywords_turbo = ['thp', 'turboalimentado', 'gt', 'gt line', 'hdi', 'grs', 'gr sport', 'gazoo racing', 'tdi', 'tc', 'td', 'gr-s', 't', '1.4t', 't3', '2.8tdi', 'turbo', '1.0t']

# 'peugeor 3008 gt pack am24 gt pack at 3008 gt pack am23.5' -> 1.6
#  '3008 gt pack am23.5 ultima unidad (p) 3008 gt pack am23.5 ultima unidad (p) 3008 gt pack am23.5 ultima unidad (p)' -> 1.6
#  'peugeot 3008 gt pack thp tip. 0km 2024 gt pack thp tip. thp'
# 'peugeot 5008 gt pack - 7 asientos gt pack turbo'
#  'peugeot 5008 allure plus hdi tiptronic allure plus hdi tiptronic 1997']

# 'toyota corolla cross seg hybrid hibrido nafta / hibrido' -> 2.0
#  'toyota corolla cross seg hybrida seg hybrida ecvt'
#  'toyota corolla cross seg hv seg hv hibrido'
#  'corolla cross xli automatico xli automatico nan'

#  'toyota hilux sw4 srx 7a aut full titular vendo o permuto sw4 srx 7a aut full nan' -> 2.8

# 'toyota rav4 limited limited nafta' -> 2.5
#  'vendo impecable toyota rav limited hibrida 4x4 at 38.000 km limited hibrida 4x4 at nan'  -> 2.5
#  'toyota rav4 4wd 4wd nan'

# 'toyota sw4 diamond ii 0km año 2024 rentaltrucks vial diamond toyota 1gd' -> 2.8
#  'toyota sw4 diamond ii 0km año 2024 rentaltrucks vial diamond toyota'
#  'toyota sw4 srx y diamond 2024 entrega inmediata - rc srx y diamond 2.8tdi c/tgv 204cv y cadena distr'

#  'toyota sw4 srv m/t - 2013 srv m/t srv sw4' -> 3.0

# 'toyota sw4 gr gr -' -> 2.8 

#  'toyota fortuner sw4 año 2022 fortuner nan' (ver si 2.8)

#  'fiat pulse abarth turbo 270 at6 abarth turbo 270 at6 nan' -> 1.3

#  'fiat pulse audace turb0 1000 1000 turbo' -> 1.0

#  'ds7 bastille 215 bastille 215 my 23 215 cv' -> 2.0
#  'ds ds7 bastille 0km - ds store nuñez bastille nan'
#  'ds ds7 bastille 215 - 0km bastille 215 my23 nan'

# %%
for marca in data['Marca'].unique():
    print(marca)
    print(data[data['Marca'] == marca]['Título versión motor'].unique())
    print()
# Out:
# peugeot
# ['peugeot 2008 1.6 feline tip am20 1.6 feline tip am20 1.6'
#  'peugeot 2008 1.6 allure 1.6 allure 1.6'
#  'peugeot 2008 1.6 feline 1.6 feline 1.6'
#  'peugeot 2008 1.6 thp sport 1.6 thp sport 1.6'
#  'peugeot 2008 1.6 thp sport tip 1.6 thp sport tip 1.6'
#  'peugeot 2008 1.6 feline tip 1.6 feline tip 1.6'
#  'peugeot 2008 1.6 allure am20 1.6 allure am20 1.6'
#  'peugeot 2008 1.6 allure tip 1.6 allure tip 1.6'
#  'peugeot 2008 1.6 in concert tiptronic 1.6 in concert tiptronic 1.6'
#  'peugeot 2008 1.6 feline am20 1.6 feline am20 1.6'
#  'peugeot 2008 1.6 in concert 1.6 in concert 1.6'
#  'peugeot 2008 1.6 feline tiptronic at 1.6 feline tiptronic at 1.6'
#  'peugeot 2008 concert 1.6 thp tiptronic am20 concert 1.6 thp tiptronic am20 1.6'
#  'peugeot 2008 1.6 active 1.6 active 1.6'
#  'peugeot 2008 1.6 thp sport am20 1.6 thp sport am20 1.6'
#  'peugeot 2008 1.6 crossway 1.6 crossway 1.6'
#  'peugeot 2008 active pack tiptroni active pack tiptroni 1.6'
#  'peugeot 2008 1.6 feline l/19 tiptronic 1.6 feline l/19 tiptronic 1'
#  'peugeot 2008 1.6 thp sport tiptronic 1.6 thp sport tiptronic 1'
#  'peugeot 2008 1.6 feline mt 4x2 1.6 feline mt 4x2 1'
#  'peugeot 2008 1.6 feline mt 1.6 feline mt 1'
#  'peugeot 2008 1.6 thp sport mt 1.6 thp sport mt 1'
#  'peugeot 2008 1.6 active mt 4x2 1.6 active mt 4x2 1'
#  'peugeot 2008 1.6 feline tiptronic 1.6 feline tiptronic 1'
#  'peugeot 2008 1.6 allure mt 1.6 allure mt 1'
#  'peugeot 2008 1.6 feline 1.6 feline inyeccion multi punto'
#  'peugeot 2008 1.6 allure l/19 mt 1.6 allure l/19 mt 1'
#  'peugeot 2008 1.6 thp in concert 1.6 thp in concert 1.6'
#  'peugeot 2008 1.6 feline tiptronic l19 1.6 feline tiptronic l19 inyeccion multi punto'
#  'peugeot 2008 allure 1.6 allure 1.6 1.6'
#  'peugeot 2008 1.6 allure l19 1.6 allure l19 inyeccion multi punto'
#  'peugeot 2008 1.6 feline tiptronic 1.6 feline tiptronic inyeccion multi punto'
#  'peugeot 2008 1.6 allure tiptronic l16 1.6 allure tiptronic l16 inyeccion multi punto'
#  'peugeot 2008 1.6 feline l16 1.6 feline l16 inyeccion multi punto'
#  'peugeot 2008 1.6 feline tiptronic l17 1.6 feline tiptronic l17 inyeccion multi punto'
#  'peugeot 2008 1.6 thp sport l19 1.6 thp sport l19 turboalimentado'
#  'peugeot 2008 1.6 crossway l18 1.6 crossway l18 inyeccion multi punto'
#  'peugeot 2008 1.6 feline l19 1.6 feline l19 inyeccion multi punto'
#  'peugeot 2008 1.6 allure l16 1.6 allure l16 inyeccion multi punto'
#  'peugeot 2008 1.6 active am20 1.6 active am20 1.6'
#  'peugeot 2008 sport 1.6 thp sport 1.6 thp 1.6'
#  'peugeot 2008 1.6 thp sport l16 1.6 thp sport l16 turboalimentado'
#  'peugeot 2008 allure allure 1.6' 'peugeot 2008 active 1.6 active 1.6 1.6'
#  'peugeot 208 feline tiptronic feline tiptronic 1.6'
#  'peugeot 208 feline 1.6 nafta 0km nv feline 1.6'
#  'peugeot 208 active pack at active pack at nan'
#  'peugeot 3008 1.6 gt-line thp pack tiptronic 1.6 gt-line thp pack tiptronic 1.6'
#  'peugeot 3008 2.0 gt-line hdi tiptronic 2.0 gt-line hdi tiptronic 2.0'
#  'peugeot 3008 2.0 gt-line hdi pack tiptronic 2.0 gt-line hdi pack tiptronic 2.0'
#  'peugeot 3008 1.6 gt-line thp tiptronic 1.6 gt-line thp tiptronic 1.6'
#  'peugeot 3008 gt pack tip gt pack tip 1.6'
#  'peugeot 3008 gt-line hdi tiptronic gt-line hdi tiptronic 2.0'
#  'peugeot 3008 gt pack hdi tiptronic gt pack hdi tiptronic 2.0 hdi'
#  'peugeot 3008 gt line thp tiptronic gt line thp tiptronic 1.6'
#  'peugeot 3008 gt line 2.0 hdi triptonic gt line 2.0 hdi triptonic 2.0'
#  'peugeot 3008 1.6 allure tiptronic l17 1.6 allure tiptronic l17 turboalimentado'
#  'peugeot 3008 hybrid 4 2022 pocos kms como nueva mk hybrid 4 1.6 plug-in hybrid vehicle'
#  'peugeot 3008 gt pack mp gt pack 1.6 thp'
#  'peugeot 3008 gt line 1.6thp at 0km 2024 gt line 1.6thp at 1.6thp'
#  'peugeot 3008 gt pack 1.6 gt thp pack tiptronic 1.6'
#  'peugeot 3008 gt pack thp 1.6 2024 gt pack thp 1.6 turbo 1.6 thp turbo'
#  'peugeot 3008 gt pack thp 1.6 2024 gt pack thp 1.6 1.6 thp turbo'
#  'peugeor 3008 gt pack am24 gt pack at 3008 gt pack am23.5'
#  'peugeot 3008 gt pack thp turbo gt pack thp 1.6 turbo thp 1.6 turbo'
#  '3008 gt pack am23.5 ultima unidad (p) 3008 gt pack am23.5 ultima unidad (p) 3008 gt pack am23.5 ultima unidad (p)'
#  'peugeot 3008 gt pack thp tiptronic gt pack thp tiptronic 1.6'
#  'peugeot 3008 gt pack thp tiptronic mc gt pack thp tiptronic 1.6 nafta thp'
#  'peugeot 3008 gt pack hybrid 2022 smart garage gt pack hybrid4 nan'
#  'peugeot professional - 3008 allure - ultima unidad!!! allure pack am23,5 1.6 cilindrada 1.598 cm3'
#  'peugeot 3008 2.0 hdi gt pack tiptronic 2.0 hdi gt pack tiptronic 2.0'
#  'peugeot 3008 1.6 hybrid 4 // 4630000 1.6 hybrid 4 1.6'
#  'peugeot 3008 gt pack ls gt pack 1598cc'
#  'peugeot 3008 2.0 gt-line hdi pack tiptronic 2.0 gt-line hdi pack tiptronic 2'
#  'peugeot 3008 2.0 feline hdi 163cv 2.0 feline hdi 163cv 2'
#  'peugeot 3008 gt pack 1.6 thp gt pack 1.6 thp 1.6 thp'
#  'peugeot 3008 1.6 gt-line thp 1.6 gt-line thp 1.6'
#  'peugeot 3008 1.6 allure thp tiptronic 1.6 allure thp tiptronic 1.6'
#  'peugeot 3008 gt pack thp tip. 0km 2024 gt pack thp tip. thp'
#  'peugeot 3008 gt-pack nafta gt-pack nafta 2.0'
#  'peugeot 3008 gt 2024 gt 1.6 t'
#  'peugeot 3008 1.6 gt pack tiptronic okm 2024, en stock 1.6 gt-line thp pack tiptronic 1.6'
#  'peugeot 3008 1.6 gt pack tiptronic okm 2024 1.6 gt-line thp pack tiptronic 2'
#  'peugeot 3008 gt line tiptronic gt line tiptronic 1.6'
#  'peugeot 4008 2.0 feline 4x4 150cv cvt 2.0 feline 4x4 150cv cvt 2.0'
#  'peugeot 4008 2.0 allure 4x4 150cv cvt 2.0 allure 4x4 150cv cvt 2.0'
#  'peugeot 4008 2.0 allure 4x4 mt 2.0 allure 4x4 mt 1'
#  'peugeot 4008 2.0 allure 4x4 150cv mt5 2.0 allure 4x4 150cv mt5 2.0'
#  'peugeot 5008 1.6 allure at 1.6 allure at 1.6 thp'
#  'peugeot 5008 1.6 allure tiptronic 1.6 allure tiptronic 1.6'
#  'peugeot 5008 gt pack tiptronic gt pack tiptronic 1.6 thp'
#  'peugeot 5008 gt pack thp 7 asientos okm aq gt pack thp 1.6 thp'
#  'peugeot 5008 gt pack thp tiptronic 1.6l aa gt pack thp 1.6 thp'
#  'peugeot 5008 gt pack gt pack nafta 1.6 turbo thp'
#  'peugeot 5008 gt pack thp am23.5 gt pack am 23.5 thp 1.6 165 cv'
#  'peugeot 5008 gt pack - 7 asientos gt pack turbo'
#  'peugeot 5008 2024 - avec peugeot gt pack 1.6'
#  'peugeot 5008 allure plus hdi tiptronic allure plus hdi tiptronic 1997']
#
# toyota
# ['toyota 4runner 2.8 sl d 2.8 sl d 2.4'
#  'toyota 4runner 2.8 l d 2.8 l d 2.4'
#  'toyota 4runner 2.7n limited 1997 2.7 nafta limited 4x4 2.7 nafta'
#  'toyota c-hr hev cvt 2023 hev cvt nan'
#  'toyota c-hr hev cvt 2023 hev cvt hev'
#  'toyota corolla cross 2.0 seg cvt 2.0 seg cvt 2.0'
#  'toyota corolla cross 2.0 xli cvt 2.0 xli cvt 2.0'
#  'toyota corolla cross 1.8 seg ecvt 1.8 seg ecvt 1.8'
#  'toyota corolla cross 2.0 xli cvt 2.0 xli cvt inyeccion multi punto'
#  'toyota corolla cross 2.0 xei cvt 2.0 xei cvt 2.0'
#  'toyota corolla cross 1.8 xei ecvt 1.8 xei ecvt 1.8'
#  'toyota corolla cross 2.0 grs cvt 170cv 2.0 grs cvt 170cv 2'
#  'toyota corolla cross 2.0 cross gr-sport cvt 2.0 cross gr-sport cvt 2'
#  'toyota corolla cross 2.0 seg cvt 2.0 seg cvt inyeccion multi punto'
#  'toyota corolla cross 2.0 seg grs cvt 2.0 seg grs cvt 2.0'
#  'toyota corolla cross 2.0 grs cvt 170cv 2.0 grs cvt 170cv 2.0'
#  'toyota corolla cross xli cvt xli cvt 2.0'
#  'toyota corolla cross 2.0 xei cvt 2.0 xei cvt 2'
#  'toyota corolla cross seg 2.0 cvt seg 2.0 cvt 2.0'
#  'toyota corolla cross hibrida 1.8 ecvt hibrida 1.8 ecvt 1.8'
#  'toyota corolla cross xli 2.0 cvt xli 2.0 cvt 2.0'
#  'toyota corolla cross seg hv 1.8 ecvt seg hv 1.8 ecvt 1.8'
#  'toyota corolla cross seg hybrid seg hybrid 1.8 nafta combinado con uno electrico'
#  'toyota corolla cross 2024 1.8 xei ecvt hibrida blanca suv 1.8 xei ecvt hibrida 1.8 hibrido'
#  'toyota corolla cross 1.8 seg hv e-cvt 2024, okm stock fisico 1.8 seg ecvt 1.8'
#  'toyota corolla cross xei hibrida 2024 xei hev 1.8 hibrido'
#  'toyota corolla cross 1.8 seg hv e-cvt 2024, 0km en stock! 1.8 seg ecvt 1.8'
#  'toyota corolla cross 1.8 seg ecvt 0km 1.8 seg ecvt 1.8'
#  'toyota corolla cross seg hybrid hibrido nafta / hibrido'
#  '(blois) toyota - corolla cross gr sport 2.0 cvt 2.0 n 2024 gazoo racing 2.0 cvt'
#  'toyota corolla cross 2.0 seg cvt 2.0 seg cvt 1'
#  'toyota corolla cross 2.0 xei cvt 2.0 xei cvt 1'
#  'toyota corolla cross 1.8 xei hv e-cvt 1.8 xei hv e-cvt 1.8'
#  'toyota corolla cross 2.0 xli cvt 2.0 xli cvt 1'
#  'toyota corolla cross 2.0 seg cvt 2.0 seg cvt 2'
#  'toyota corolla cross seg seg 2.0'
#  'toyota corolla cross seg 2.0cvt seg 2.0cvt 2.0'
#  'toyota corolla cross 1.8 xei ecvt 1.8 xei ecvt 18hv'
#  'toyota corolla cross xei hev 1.8 ecvt xei hev 1.8 ecvt 1.8'
#  'toyota corolla cross seg hybrido 2022 seg hev 1.8'
#  'toyota corolla cross seg 2.0 cvt 2024 okm 2.0 seg cvt 2.0'
#  'toyota corolla cross xli cvt blanco 2024 automatico 0km xli cvt 2.0'
#  'toyota corolla cross xei hibrido 1.8l cvt 0km sin rodar 2023 xei hibrido 1.8l'
#  'toyota corolla cross 1.8 seg hv okm 2024, en stock fisico! 1.8 seg ecvt 1.8'
#  'toyota corolla cross 1.8 seg hv okm 2024, stock fisico ! 1.8 seg ecvt 1.8'
#  'toyota corolla cross seg 0km patentada 2024 seg 2.0'
#  'toyota corolla cross 2.0 seg cvt 2.0'
#  'toyota corolla cross xei nafta xei nafta 2.0'
#  'toyota corolla croos 2.0 cvt 2.0' 'toyota corolla 2.0 xei cvt 2.0'
#  'toyota corolla cross 1.8 xei hibrido 1.8 xei hibrido 1.8'
#  'toyota corolla cross seg hev 1.8 ecvt seg hev 1.8 ecvt 1.8 hev'
#  'toyota corolla cross 1.8 seg hv e-cvt 1.8 seg hv e-cvt inyeccion multi punto'
#  'toyota corolla cross xli cvt 2.0 xli cvt 2.0 2.0'
#  'toyota corolla cross 1.8 xei hybrid hibri 1.8 xei hybrid hibri 1.8'
#  'toyota corolla cross seg hybrida seg hybrida ecvt'
#  'toyota corolla cross 2.0 seg a/t cvt 0km 2024 46655831 2.0 seg cvt 2.0'
#  'toyota corolla cross 2.0 seg cvt 2.0 seg cvt nan'
#  'oportunida corolla cross 2.0 xli at 0km 2024 2.0 xli at 2.0'
#  'toyota corolla cross seg hv seg hv hibrido'
#  'corolla cross xli automatico xli automatico nan'
#  'toyota corolla cross 1.8 xei ecvt hibrid 1.8 xei ecvt hibrid 1.8'
#  'toyota corolla cross xei 2.0 cvt xei 2.0 cvt 2.0'
#  'toyota hilux 2.8 cd srx 177cv 4x4 2.8 cd srx 177cv 4x4 2.8'
#  'toyota hilux sw4 2.8 srx 177cv 4x4 7as at 2.8 srx 177cv 4x4 7as at 2.8'
#  'toyota hilux sw4 sw4 4x4 srx 2.8 tdi sw4 4x4 srx 2.8 tdi 2.8'
#  'toyota hilux sw4 2.8 sr 177cv 4x4 2.8 sr 177cv 4x4 2.8'
#  'toyota hilux sw4 3.0 srv cuero i 171cv 4x4 4at 3.0 srv cuero i 171cv 4x4 4at 3.0'
#  'toyota hilux sw4 srx 4x4 srx 4x4 2.8'
#  'toyota hilux sw4 hilux sw4 4x4 at cue hilux sw4 4x4 at cue 3.0'
#  'toyota hilux sw4 3.0 srv cuero manual 3.0 srv cuero manual 3.0'
#  'toyota hilux sw4 srx 7 as at srx 7 as at 2.8'
#  'toyota hilux sw4 3.0 srv cuero at 3.0 srv cuero at 3.0'
#  'toyota hilux sw4 srx 7a aut full titular vendo o permuto sw4 srx 7a aut full nan'
#  'toyota hilux sw4 srx at 7a srx at 7a 2.8'
#  'toyota hilux sw4 3.0 srv cuero 3.0 srv cuero 3.0'
#  'toyota hilux sw4 3.0 srv cuero i 171cv 4x4 3.0 srv cuero i 171cv 4x4 3.0'
#  'toyota hilux sw4 3.0 srv 3.0 srv 3.0'
#  'toyota hilux sw4 3.0 i runner tc cu 3.0 i runner tc cu 3.0'
#  'toyota hilux sw4 srv cuero 4x4 manual srv cuero 4x4 manual 3.0'
#  'toyota hilux sw4 3.0 td srv 3.0 td srv 3.0'
#  'toyota hilux sw4 grs grs 2.8' 'toyota hilux sw4 diamons diamons 2.8'
#  'toyota hilux sw4 sw4 srx at sw4 srx at diesel 2.8'
#  'toyota hilux sw4 2.8 tdi diamante ii 4x4 7as 6at 2.8 tdi diamante ii 4x4 7as 6at 2.8'
#  'toyota hilux sw4 sw4 sw4 3.0' 'toyota hilux sw4 3.0 3.0 3.0'
#  'toyota hilux sw4 2.7 srv cuero vvti 4x2 4at 7 as - c4 2.7 srv cuero vvti 4x2 4at 7 as - c4 2.7'
#  'toyota hilux sw4 srx 2.8 tdi at6 7as srx 2.8 tdi at6 7as 2.8'
#  'toyota hilux sw4 3.0 srv cuero i 171cv 4x4 5at 3.0 srv cuero i 171cv 4x4 5at 3.0'
#  'toyota hilux sw4 3.0 i srv c/cuero 3.0 i srv c/cuero 3.0'
#  'toyota hilux sw4 4x4 srx at 7 asiento 4x4 srx at 7 asiento 2.8'
#  'toyota hilux sw4 sw4 4x4 srv 3.0 tdi sw4 4x4 srv 3.0 tdi 3.0'
#  'toyota hilux sw4 srx srx 2,8' 'toyota hilux sw4 srx at srx at 2.8'
#  'toyota hilux sw4 sw4 3.0 srv 4x4 sw4 3.0 srv 4x4 3.0'
#  'toyota hilux sw4 srv 4x4 3.0 manual srv 4x4 3.0 manual 3.0'
#  'toyota hilux sw4 3.0 srv cuero 4x4 3.0 srv cuero 4x4 3.0'
#  'toyota hilux sw4 sw4 con cuero sw4 con cuero 3.0'
#  'toyota hilux sw4 2.8 srx 4 x 4 2.8 srx 4 x 4 2.8'
#  'toyota hilux sw4 sw4 srv manual cuero sw4 srv manual cuero 3.0'
#  'toyota hilux sw4 3.0 srv manual/pana 3.0 srv manual/pana 3.0'
#  'toyota hilux sw4 srx 177cv automatica srx 177cv automatica 2.8'
#  'toyota hilux sw4 3.0 srv cuero 171cv 4x4 5at - a4 3.0 srv cuero 171cv 4x4 5at - a4 3.0'
#  'toyota hilux sw4 toyota sw4 toyota sw4 2.7'
#  'toyota hilux sw4 2.8 srx 177cv 4x4 at 2.8 srx 177cv 4x4 at 2.8'
#  'toyota hilux sw4 2.8 tdi srx 4x4 at 7 2.8 tdi srx 4x4 at 7 2.8'
#  'toyota hilux sw4 3.0 srv 4x4 manual 3.0 srv 4x4 manual 3.0'
#  'toyota land cruiser 4.0 prado vx at 4.0 prado vx at 4.0'
#  'toyota land cruiser 4.5 200 v8 d4-d 235cv at 4.5 200 v8 d4-d 235cv at 4.5'
#  'toyota land cruiser 3.0 prado at 3.0 prado at 3.0'
#  'toyota land cruiser 4.2 dl 4.2 dl 4.2'
#  'toyota land cruiser prado vx prado vx 4.0'
#  'toyota land cruiser 4.5 200 vx 265cv at w/floormat 4.5 200 vx 265cv at w/floormat 4.5'
#  'toyota land cruiser 4.0 prado txl at 4.0 prado txl at 4.0'
#  'toyota land cruiser 4.0 prado vx mt 4.0 prado vx mt 4.0'
#  'toyota land cruiser 3.0 prado mt 3.0 prado mt 3.0'
#  'toyota land cruiser 4.0 v6 4.0 v6 4.0'
#  'toyota land cruiser 3.0 prado 3.0 prado 3.0'
#  'toyota land cruiser vx 100 vx 100 4.2'
#  'toyota land cruiser vx 3.0 vx 3.0 3.0'
#  'toyota land cruiser prado vx a/t prado vx a/t 4.0'
#  'toyota land cruiser 4.5 td 200 vx 265cv at w/floormat 4.5 td 200 vx 265cv at w/floormat 4.5'
#  'toyota land cruiser prado vx prado vx 3.0'
#  'toyota land cruiser prado prado 2.8 4x4 at 2.8'
#  'toyota rav4 2.0 4x2 vx cvt 2.0 4x2 vx cvt 2.0'
#  'toyota rav4 2.5 vx 2.5 vx 2.5' 'toyota rav4 2.4 4x4 at 2.4 4x4 at 2.4'
#  'toyota rav4 2.4 4x2 at 2.4 4x2 at 2.4' 'toyota rav4 2.0 vx 2.0 vx 2.0'
#  'toyota rav4 2.5 tx 2.5 tx 2.5' 'toyota rav4 2.0 4x2 cvt 2.0 4x2 cvt 2.0'
#  'toyota rav4 2.0 tx 2.0 tx 2.0'
#  'toyota rav4 2.5 4x4 vx 6at 2.5 4x4 vx 6at 2.5'
#  'rav4 hv 2.5 limited 4x2 f hv 2.5 limited 2.5'
#  'toyota rav4 2019 hibrida limited 4x2 2.5 limited hv 2.5'
#  'toyota rav4 hv 2.5 limited 4x2 uct - 2019 2.5 limited 2.5'
#  'toyota rav hybrid 2.5l limited cvt 2019 limited cvt 2.5'
#  'toyota rav 4 2.5 5ptas 4x4 lim hybrid l19 2019 rav 4 2.5 hybrid limited 2.5'
#  'toyota rav4 hv 2.5 limited 4x2 2019 hv 2.5 limited 4x2 2.5'
#  'toyota rav4 limited limited nafta'
#  'toyota rav4 hv 2.5 awd limited hv 2.5 awd limited 2.5 awd'
#  'rav 4 hybrid limited 4x4 limited 4x4 hv hibrida 2.5'
#  'toyota rav 4 hibrida xle 2.4'
#  'toyota rav4 2.5 4x4 vx at 2.5 4x4 vx at 1'
#  'toyota rav4 2.5 vx at 4x4 2.5 vx at 4x4 1'
#  'toyota rav4 2.0 4x2 tx cvt 2.0 4x2 tx cvt 2.0'
#  'toyota rav4 2.5 4x4 6at 2.5 4x4 6at 2.5'
#  'toyota rav4 2.5 hybrid limited at 4x2 2.5 hybrid limited at 4x2 1'
#  'rav4 hv 2.5 awd limited cvt rav4 hv 2.5 awd limited cvt nan'
#  'rav4 hv 2.5 limited cvt rav4 hv 2.5 limited cvt 2.5'
#  'toyota rav4 hv 2.5 awd limited cvt - 2020 hv 2.5 awd limited cvt 2.5'
#  'toyota rav4 2.0 4x2 tx cvt 2.0 4x2 tx cvt 2'
#  'toyota rav4 2.5 4x4 vx 6at 2.5 4x4 vx 6at 2'
#  'toyota rav4 hv 2.5 awd limited cvt 2020 rav4 2.5'
#  'toyota rav4 hv 2.5 awd limited cvt 2020 - car cash hv 2.5 awd limited cvt 2.5'
#  'toyota rav4 xle hybrida hv 2.5 xle cvt 2.5'
#  'toyota rav4 hv 2.5 xle cvt hibrida hv 2.5 xle cvt 2.5'
#  'toyota rav4 hibrida 4x4 hv 2.5 awd limited nan'
#  'toyota rav4 4x2 4x2 2.4'
#  'toyota rav4 hv 2.5 4x2 limited cvt hv 2.5 limited cvt 222 cv'
#  'toyota rav4 hv 2.5 4x2 limited cvt hv 2.5 4x2 limited cvt 222 cv'
#  'toyota rav4 4x4 at acep.men valor 2.0 n 4x4 at o pmto. 2.0'
#  'toyota rav 4 hv 2.5 awd limited cvt hv 2.5 limited cvt hibrido'
#  'toyota rav4 4wd 4wd nan'
#  'toyota rav 4 hib. 4x4 2.5 awd limited cvt tope de linea hd 2.5 awd limited cvt 2.5 awd'
#  'vendo impecable toyota rav limited hibrida 4x4 at 38.000 km limited hibrida 4x4 at nan'
#  'toyota sw4 2.8 srx 204cv 4x4 7as at 2.8 srx 204cv 4x4 7as at 2.8'
#  'toyota sw4 3.0 i srv at c/cuero 4x4 (2009) 3.0 i srv at c/cuero 4x4 (2009) 3.0'
#  'toyota sw4 2.8 tdi gr-s 4x4 7as 6at 2.8 tdi gr-s 4x4 7as 6at 2.8'
#  'toyota sw4 2.8 tdi diamante ii 4x4 7as 6at 2.8 tdi diamante ii 4x4 7as 6at 2.8'
#  'toyota sw4 2.8 srx 177cv 4x4 7as 6at 2.8 srx 177cv 4x4 7as 6at 2.8'
#  'toyota sw4 2.8 srx 177cv 4x4 7as at 2.8 srx 177cv 4x4 7as at 2.8'
#  'toyota sw4 2.8 sr 177cv 4x4 2.8 sr 177cv 4x4 2.8'
#  'toyota sw4 3.0 3.0 3.0'
#  'toyota sw4 3.0 srv cuero i 171cv 4x4 3.0 srv cuero i 171cv 4x4 3.0'
#  'toyota sw4 2.8 srx 177cv 4x4 7as 2.8 srx 177cv 4x4 7as 2.8'
#  'toyota sw4 3.0 srv cuero 171cv 4x4 - e4 3.0 srv cuero 171cv 4x4 - e4 3.0'
#  'toyota sw4 3.0 srv cuero 3.0 srv cuero 3.0'
#  'toyota sw4 3.0 srv 171cv 4x4 - c3 3.0 srv 171cv 4x4 - c3 3.0'
#  'toyota sw4 3.0 srv cuero 171cv 4x4 5at 3.0 srv cuero 171cv 4x4 5at 3.0'
#  'toyota sw4 2.7 srv cuero vvti 4x2 4at 7 asientos 2.7 srv cuero vvti 4x2 4at 7 asientos 2.7'
#  'toyota sw4 3.0 srv i 171cv 4x4 3.0 srv i 171cv 4x4 3.0'
#  'toyota sw4 3.0 i srv c/cuero 4x4 (2009) 3.0 i srv c/cuero 4x4 (2009) 3.0'
#  'toyota sw4 3.0 srv cuero i 171cv 4x4 4at 3.0 srv cuero i 171cv 4x4 4at 3.0'
#  'toyota sw4 srx 204cv 7a at srx 204cv 7a at 2.8'
#  'toyota sw4 3.0 srv cuero i 171cv 4x4 5at 3.0 srv cuero i 171cv 4x4 5at 3.0'
#  'toyota sw4 sw4 srx 2.8 tdi 6 at sw4 srx 2.8 tdi 6 at 2.8'
#  'toyota sw4 3.0 i srv 4x4 (2009) 3.0 i srv 4x4 (2009) 3.0'
#  'toyota sw4 3.0 srv cuero at 3.0 srv cuero at 3.0'
#  'toyota sw4 2.7 srv cuero vvti 4x2 4at 7 as - c4 2.7 srv cuero vvti 4x2 4at 7 as - c4 2.7'
#  'toyota sw4 3.0 srv 3.0 srv 3.0'
#  'toyota sw4 3.0 srv at/cuero 4x4 3.0 srv at/cuero 4x4 3.0'
#  'toyota sw4 srx 2.8 tdi 204 cv srx 2.8 tdi 204 cv 2.8 td 204cv'
#  'toyota sw4 srx at 7a srx at 7a 2.8'
#  'toyota sw4 3.0 i runner 3.0 i runner 3.0'
#  'sw4 4x4 srx 2.8 tdi 6 at e.f srx 4x4 at 2.8 204cv'
#  'toyota sw4 srx nuevo modelo 2024 - a srx at 7a 2.8 204cv toyota'
#  'sw4 4x4 diamond ii 2.8 tdi 6 at 7a l5 ahora con totota plan 4x4 diamond ii 2.8 tdi 6 at 2.8'
#  'toyota sw4 4x4 srx 2.8 tdi 6 a/t 7a 4x4 srx 2.8 tdi 6 a/t 7a 2.8'
#  'toyota sw4 diamond ii 0km año 2024 rentaltrucks vial diamond toyota 1gd'
#  'toyota sw4 4x4 diamond ii 2.8 tdi 6 at 7a 4x4 diamond ii 2.8 tdi 6 at 7a 2.8'
#  'toyota sw4 diamond ii 0km año 2024 rentaltrucks vial diamond toyota'
#  'toyota sw4 srx y diamond 2024 entrega inmediata - rc srx y diamond 2.8tdi c/tgv 204cv y cadena distr'
#  'toyota sw4 diamond diamond 2.8' 'toyota sw4 diamond 2.8'
#  'toyota sw4 2.8 srx 7as at 4x4 2.8 srx 7as at 4x4 1'
#  'toyota sw4 2.7 srv cuero vvti 4x2 4at 5 asientos 2.7 srv cuero vvti 4x2 4at 5 asientos 2.7'
#  'toyota sw4 3.0 srv at 3.0 srv at 3.0'
#  'toyota sw4 4x4 sr 2.8 tdi 6a/t 5a 4x4 sr 2.8 tdi 6a/t 5a 2.8'
#  'toyota sw4 2.8 gr-sport 224cv 4x4 7as at 2.8 gr-sport 224cv 4x4 7as at 2.8'
#  'toyota sw4 sw4 srv 4x4 tdi 3.0 mt 5as sw4 srv 4x4 tdi 3.0 mt 5as 3.0'
#  'toyota sw4 3.0 srv 171cv 4x4 3.0 srv 171cv 4x4 3.0'
#  'toyota sw4 3.0 srv cuero i 171cv 4x4 5at - a4 3.0 srv cuero i 171cv 4x4 5at - a4 3.0'
#  'toyota sw4 srx 204cv srx 204cv 2.8'
#  'toyota sw4 sw4 tdi srv cuero at l/12 sw4 tdi srv cuero at l/12 3.0'
#  'toyota sw4 3.0 srv cuero i 171cv 4x4 - e4 3.0 srv cuero i 171cv 4x4 - e4 3.0'
#  'toyota sw4 srv m/t - 2013 srv m/t srv sw4' 'toyota sw4 gr gr -'
#  'toyota sw4 srx 4x4 0km - 2024 disponible srx srx'
#  'toyota sw4 204 cv srx 7 asiento 204 cv srx 7 asiento 2.8'
#  'toyota sw4 gr gr sport 2.8 tdi' 'toyota sw4 gr gr 2.8'
#  'toyota sw4 2.8 tdi gr-s 4x4 7as 6at. hoffen gr-sport 2.8'
#  'toyota sw4 2.8 srx 177cv 4x4 7as at 2016 - permuto 4x4 2.8'
#  'toyota hilux sw4 hilux asientos de cuero 3.0'
#  'toyota sw4 2.8 tdi diamond ii 7as at 4x4 0km financiada 2.8 tdi diamond ii 7as at 4x4 2.8'
#  'toyota sw4 3.0 srv cuero 171cv 4x4 5at - a4 3.0 srv cuero 171cv 4x4 5at - a4 3.0'
#  'toyota sw4 srv 4x4 cuero 7 asie srv 4x4 cuero 7 asie 3.0'
#  'toyota sw4 3.0 i runner tc cu 3.0 i runner tc cu 3.0'
#  'toyota sw4 2.8 gr-sport 204cv 4x4 7as at 2.8 gr-sport 204cv 4x4 7as at 2.8'
#  'toyota sw4 2.8 srv 4x4 2.8 srv 4x4 2.8'
#  'toyota sw4 3.0 srv cuero i 171cv 4x4 3.0 srv cuero i 171cv 4x4 3'
#  'toyota sw4 3.0 srv cuero 171cv 4x4 3.0 srv cuero 171cv 4x4 3.0'
#  'toyota sw4 srx 2.8 tdi at 7as srx 2.8 tdi at 7as 2.8'
#  'toyota sw4 2.7 runner 2.7 runner 2.7'
#  'toyota sw4 srx 2.8tdi 204cv 4x4 at srx 2.8tdi 204cv 4x4 at my24 l/nva diesel td'
#  'toyota fortuner sw4 año 2022 fortuner nan'
#  'toyota hilux sw4 tdi srx at l21 2024 2.8 srx 177cv 4x4 7as at 2.8'
#  'toyota 2006 hilux sw4 td srv cuero l05 3.0 wide body 3'
#  'toyota sw4 toyota sw4 srx 4x4 2.8 204cv toyota sw4 srx 4x4 2.8 204cv 2.8 204cv'
#  'toyota sw4 4x4 diamond ii 2.8 tdi 6 at 7as 4x4 diamond ii 2.8 tdi 6 at 7as 2.8'
#  'toyota sw4 3.0 wide body 3.0 wide body 3.0'
#  'toyota sw4 3.0 turbo 3.0 turbo 3.0'
#  'toyota sw4 2.8 srx 204cv 7as at 2.8 srx 204cv 7as at 2.8'
#  'toyota sw4 toyota sw4 2.8 srx toyota sw4 2.8 srx 2.8'
#  'toyota sw4 3.0 srv 4x4 3.0 srv 4x4 3.0'
#  'toyota sw4 sw4 4x4 srx 2.8 tdi 6 at 7a full sw4 4x4 srx 2.8 tdi 6 at 7a full 2.8'
#  'toyota sw4 2.8srx204cv4x4 7a6at 2.8srx204cv4x4 7a6at 2.8'
#  'toyota sw4 2.8 srx 204cv 4x4 7a 2.8 srx 204cv 4x4 7a 2.8'
#  'toyota sw4 sw4 4x4 srv 3.0 tdi c/cuero sw4 4x4 srv 3.0 tdi c/cuero 3.0'
#  'toyota sw4 4x4 sr 2.8 tdi 6a/t 4x4 sr 2.8 tdi 6a/t 2.8'
#  'toyota sw4 2.8 srx 204cv 4x4 2.8 srx 204cv 4x4 2.8'
#  'toyota sw4 srx 2.8 tdi 6 a/t 7a 2017 srx 2.8 tdi 6 a/t 7a 4 cilindros en linea con turbocompresor de geometria variable (tgv) e intercooler'
#  'toyota sw4 sw4 3.0 td sw4 3.0 td 3.0']
#
# fiat
# ['fiat 500x 1.4 t 16v cross at9 1.4 t 16v cross at9 1.4'
#  'fiat 500x 1.4 t 16v pop 1.4 t 16v pop 1.4'
#  'fiat 500x 1.4 pop star mt 1.4 pop star mt 1' 'fiat 500x x x 1.4'
#  'fiat 500x cross 1.4t at9 4x4 cross 1.4t at9 4x4 1.4'
#  'fiat pulse 1.0 impetus t3 cvt 1.0 impetus t3 cvt 1.0'
#  'fiat pulse 1.3 abarth gse at 1.3 abarth gse at 1.3'
#  'fiat pulse 1.3 drive gse cvt 1.3 drive gse cvt 1.3'
#  'fiat pulse 1.3 drive gse mt 1.3 drive gse mt 1.3'
#  'fiat pulse 1.0 impetus t3 cvt 1.0 impetus t3 cvt 1'
#  'fiat pulse drive 1.3 drive 1.3 1.3 100cv.'
#  'fiat pulse full 0km 2024 retira ya tomo usados anticipo y cuotas 1.3'
#  'fiat pulse audace 1.0 turbo tr#3 audace 1.0 turbo 1.0 turbo'
#  'fiat pulse audace 1.0 turbo 0km entrega inmediata audace 1.0 turbo 1.0 turbo'
#  'fiat pulse audace 1.0 turbo cvt 0km audace 1.0 turbo'
#  'fiat pulse audace cvt turbo 0km entrega inmediata audace 1.0 turbo'
#  'fiat pulse abarth - 0km 2024 entrega inmediata c abarth 1.3 turbo t270'
#  'fiat pulse 1.3 ,financiada ,anticipo con usado u efec ( men) pack plus 1.3'
#  'fiat pulse abarth edicion limitada 1.3 turbo 175cv cvt abarth 1.3t'
#  'fiat pulse 1.0t audace okm 1.0t audace 1.0t'
#  'fiat pulse audance 1.0 cvt 0km 2024 audance 1.0 1.0'
#  'fiat pulse abarth 1.3 t 270 0km 2024 tomo focus golf 500 c abarth 1.3 t 270 1.3 t 270'
#  'fiat pulse audace 1.0t cvt 0km tomo usado cruze golf focus c audace 1.0t cvt nan'
#  'fiat pulse audace 1.0 t. cvt 2024///luisp audace turbo 1.0 turbo'
#  'fiat pulse drive cvt 2024 0km precio enero 2024 drive cvt 2024 1.3'
#  'fiat pulse drive 2024 0km precio enero 2024 drive mt 2024 1.3'
#  'pulse abarth abarth 1.3'
#  'fiat pulse abarth 1.3 turbo cvt (jr) abarth 1.3 turbo'
#  'fiat pulse abarth 1,3 turbo 175hp at6 0km ultima unidad abarth 1.3'
#  'fiat pulse 1.3 t abarth at6 l24 - autocity 1.3 t abarth at6 l24 turboalimentado'
#  'fiat pulse audace 1.0 turbo - c audace nan'
#  'fiat pulse abarth turbo 270 at6 0km (arg) abarth turbo 270 1.3'
#  'fiat pulse 1.0 turbo 0km entrega inmediata audace 1.0 turbo'
#  'fiat pulse 1.0 impetus l24 1.0 impetus l22 turboalimentado'
#  'fiat pulse abarth turbo 270 at6 abarth turbo 270 at6 nan'
#  'fiat pulse 1.0t para retirar/ jz 1.0 turbo audace 1.0'
#  'fiat puse audace cvt audace 1.0t cvt 1.0 turbo'
#  'fiat pulse 1.3 drive 4x2 cvt 1.3 drive 4x2 cvt 1'
#  'fiat pulse 1.3 drive 4x2 mt 1.3 drive 4x2 mt 1'
#  'fiat pulse impetus 1.0t cvt impetus 1.0t cvt 1.0'
#  'fiat pulse impetus 1.0t cvt impetus 1.0t cvt 1.0 turbo'
#  'abarth pulse 1.3 turbo 270 - 0km 1.3 turbo 270 1.3 turbo'
#  'fiat pulse abarth abarth 1.3 turbo' 'fiat pulse drive cvt drive cvt 1.3'
#  'fiat pulse abarth 1.3 turbo 270 at6 / #2 b. abarth 1.3'
#  'fiat cronos style 2024 #4 contado o financiado entrega ya gi audace 1.0t'
#  'fiat pulse 1.3 drive gse mt drive mt 1.3' 'fiat pulse abarth abarth 1.3'
#  'fiat pulse audance 1.0 cvt audance 1.0'
#  'fiat pulse 1.3 drive gse cvt 2024 cvt 1.3'
#  'fiat pulse drive gse 1.3 mt5 mt 1.3 1.3'
#  'fiat pulse 1.0 impetus 1.0 impetus turboalimentado'
#  'fiat pulse 1.3 drive mt 1.3 drive mt inyeccion multi punto'
#  'fiat pulse impetus impetus 1.0t 1.0 turbo'
#  'fiat pulse audace 1.0 turbo audace 1.0 turbo 1.0 t'
#  'fiat pulse drive mt drive cvt 1.3'
#  'fiat pulse 0 km 2024 automatica gs cvt 1.0'
#  'fiat pulse drive mt drive mt 1.3'
#  'fiat pulse abarth 1.0 turbo 270 at6 jr 1.o turbo 270 abarth 1.0 turbo 270'
#  'fiat pulse 0km 2024 automatica gs audace 1.0'
#  'fiat pulse impetus 1.0 turbo automatica nafta nan'
#  'fiat pulse audace 0km/ entrega inmediata/ #1 r.m audace 1.0 turbo'
#  'fiat pulse 1.0 impetus t3 cvt 2024 1.0 impetus t3 cvt 1'
#  'fiat pulse - 2023 audace 1.0t cvt 1.0'
#  'fiat pulse audace turb0 1000 1000 turbo'
#  'fiat pulse audace 1.0t audace 1.0t 1.0t' 'fiat pulse audace audace 1.0']
#
# ds
# ['ds7 7 bastille bastille 1.6t' 'ds 7 rivoli rivoli 1.6 t'
#  'ds 7 bastille 1.6t 215 hp bastille 1.6t 215 hp 1.6 t'
#  'ds ds3 rivoli 130 my 23 0km rivoli 1.2'
#  'ds 3 rivoli 130 my23 rivoli puretech 1.2'
#  'ds ds7 bastille 0km - ds store nuñez bastille 1.6'
#  'ds7 rivolli 215 rivolli 215 puretech 1.6 215cv'
#  'ds7 bastille 215 my23 bastille 215 puretech 1.6 215cv'
#  'ds7 bastille 215 ca bastille 1.6'
#  'ds 7 bastille 215 my23 - ds stores ds 7 bastille 215 my23 2.0'
#  'ds7 bastille 215 bastille 215 my 23 215 cv'
#  'ds ds7 bastille 0km - ds store nuñez bastille nan'
#  'ds ds7 bastille 215 - 0km bastille 215 my23 nan'
#  'ds automobiles ds7 1.6 thp crossback ptech b chic id:8463 1.6 thp crossback ptech b chic turboalimentado'
#  'ds 7 bastille 215 my23 - ds stores ds 7 bastille 215 my23 1.6'
#  'ds 7 bastille 1.6 215 at8 my24 new bastille 215 at8 my23 1.6 puretech 215'
#  'ds7 bastille 1.6 215cv at8 my24 bastille 215 my23 1.6 puretech at 215'
#  'ds ds7 crossback 2.0 hdi bastille+ 2.0 hdi bastille+ 2.0 hdi'
#  'ds 7 bastille nafta linea nueva bastille nafta 1,6'
#  'ds7 crossback etense 4x4 300cv phev hibrido enchufable 1,6 turbo'
#  'ds7 e-tense hibrida 4x4 300 hp bastille+ ds ds7 e-tense hibrida 4x4 300 bastille+ 2.0'
#  'ds ds7 crossback hdi 180 automatic rivoli my21 hdi 180 automatic rivoli my21 2.0'
#  'ds ds7 crossback 1.6 puretech 165 at be chic 1.6 puretech 165 at be chic 1.6'
#  'ds7 crossback hibrido enchufable 4x4 modelo 2022 ds7 crossback e-tense 4x4 300 bastille 1.6 thp 200 cv + 2 motores electricos 1 en cada eje de 110 cv c/u']
#
# ssangyong
# ['ssangyong actyon 2.3 equipamiento 2 150cv 4x2 2.3 equipamiento 2 150cv 4x2 2.3'
#  'ssangyong musso 2.3 601 d 2.3 601 d 2.3'
#  'ssangyong musso 2.9 602 d el at 2.9 602 d el at 2.9'
#  'ssangyong musso 2.9 602 dti 2.9 602 dti 2.9'
#  'ssangyong musso 2.9 602 d el 2.9 602 d el 2.9']
#
# chevrolet
# ['chevrolet agile lt 1.4n lt 1.4n 1.4'
#  'chevrolet blazer 2.8 cdoble dlx 4x2 electronico 2.8 cdoble dlx 4x2 electronico 2.8'
#  'chevrolet blazer 2.8 dlx 4x2 2.8 dlx 4x2 2.8'
#  'chevrolet blazer 2.8 dlx i 4x2 2.8 dlx i 4x2 2.8'
#  'chevrolet blazer 2.8 dlx 4x2 turbo diesel 2008 dlx 2.8 4x2 turbodiesel'
#  'chevrolet blazer 4.3 4x4 200 hp tahoe lt 4.3 4x4 200 hp tahoe lt 4.3'
#  'chevrolet blazer 2.8 dlx 4x4 2.8 dlx 4x4 2.8'
#  'chevrolet blazer 4.3 4x2 160 hp 4.3 4x2 160 hp 4.3'
#  'chevrolet blazer 2.8 dlx i 4x4 2.8 dlx i 4x4 2.8'
#  'chevrolet blazer 4.3 4x4 160 hp 4.3 4x4 160 hp 4.3'
#  'chevrolet blazer 4.3 4x4 200 hp 4.3 4x4 200 hp 4.3'
#  'chevrolet blazer 2.8 cdoble dlx 4x4 electronico 2.8 cdoble dlx 4x4 electronico 2.8'
#  'chevrolet blazer 2.4 2.4 2.4'
#  'chevrolet blazer 2.4 2006 con gnc (2 tubos abajo) 2.4 2.4'
#  'chevrolet captiva 2.4 ls mt fwd 167cv 2.4 ls mt fwd 167cv 2.4'
#  'chevrolet captiva 2.2 ltz 184cv 2.2 ltz 184cv 2.2'
#  'chevrolet captiva 2.4 ls 167cv 2.4 ls 167cv 2.4'
#  'chevrolet captiva 2.4 lt 167cv 2.4 lt 167cv 2.4'
#  'chevrolet captiva 2.0 vcdi lt mt 2.0 vcdi lt mt 2.0'
#  'chevrolet captiva 2.4 lt mt awd 167cv 2.4 lt mt awd 167cv 2.4'
#  'chevrolet captiva 2.2 ltz 184cv 7as mt 2.2 ltz 184cv 7as mt 2.2'
#  'chevrolet captiva 2.2 ltz awd d 184cv at 2.2 ltz awd d 184cv at 2.2'
#  'chevrolet captiva 2.2 lt awd d 184cv mt 2.2 lt awd d 184cv mt 2.2'
#  'chevrolet captiva lt 2.2 d 7 asientos lt 2.2 d 7 asientos 2.2'
#  'chevrolet captiva 2.0 vcdi ltz at 2.0 vcdi ltz at 2.0'
#  'chevrolet captiva 2.4 lt mt 2.4 lt mt 2.4'
#  'chevrolet captiva 2.4 ls mt 4x2 2.4 ls mt 4x2 1'
#  'chevrolet captiva 2.4 ls 167cv mt 4x2 2.4 ls 167cv mt 4x2 1'
#  'chevrolet captiva lt 2.4 2008 lt 2.4 2.4'
#  'chevrolet captiva 2.4 ls 2.4 ls 2.4'
#  'chevrolet captiva 2.2 ltz 200 cv 2.2 ltz 200 cv 2.2'
#  'chevrolet captiva 2.4 ls - 167 cv 2.4 ls - 167 cv 2.4'
#  'chevrolet captiva lt diesel 3 filas de asientos lt diesel 2.2'
#  'chevrolet equinox 1.5t premier 4wd 1.5t premier 4wd 1.5'
#  'chevrolet equinox 1.5t lt 2wd 1.5t lt 2wd 1.5'
#  'chevrolet equinox 1.5t rs fwd at 1.5t rs fwd at 1.5'
#  'chevrolet equinox 1.5 t awd premier at6 l18 1.5 t awd premier at6 l18 turboalimentado'
#  'chevrolet equinox rs 2024 (nd) rs 1.5'
#  'chevrolet equinox 1.5t rs fwd at mm rs 1.5 turbo'
#  'nueva equinox 1.5t a/t rs 2024 0km entrega inmediata!!!jb22 rs 1.5t 1.5 turbo'
#  'chevrolet tracker premier 1.2 turbo at rs 1.5 turbo fwd 1.5 turbo'
#  'chevrolet equinox 1.5t premier at 4x4 1.5t premier at 4x4 1'
#  'chevrolet equinox 1.5t ls at 4x2 1.5t ls at 4x2 1'
#  'chevrolet equinox 1.5 t ls 2wd at 1.5 t ls 2wd at 1.5'
#  'chevrolet equinox rs at turbo 0km fh rs 1.5 turbo'
#  'chevrolet equinox rs y premier turbo at my 24 go rs 1.5 turbo 171 cv'
#  'chevrolet equinox 1.5t rs fwd at 1.5t rs fwd at 1.5 turbo'
#  'chevrolet equinox 1.5 turbo rs 2wd 1.5 turbo rs 2wd 1.5 turbo'
#  'chevrolet s10 high country at 4x4 rs 1.5 turbo fwd 1.5 turbo'
#  'chevrolet equinox version rs 0km año 2023 entrega inmediata rs 1.5 turbo 170cv'
#  'chevrolet grand blazer 4.2 dlx 4.2 dlx 4.2'
#  'chevrolet grand vitara 2.0 2.0 2.0'
#  'chevrolet grand vitara 2.0 i 2.0 i 2.0'
#  'chevrolet spin 1.8 activ 7as at 1.8 activ 7as at 1.8'
#  'chevrolet spin 1.3 d 7p ltz m/t 2017 ltz 1.3'
#  'chevrolet spin 1.8 nafta activ 7 asientos automatica 2024 activ 1.8'
#  'chevrolet spin 1.8 lt 5as 105cv 1.8 lt 5as 105cv nan'
#  'chevrolet spin 1.8 activ ltz at 5as 1.8 activ ltz at 5as 1.8'
#  'chevrolet spin premier m/t 7as 2022 no gnc kicks ds7 hdi 2.0 premier m/t 7as 1.8'
#  'chevrolet spin premier 7as 1.8 2022 no ltz 5as kicks 2016 lt premier 7p 1.8 1.8'
#  'chevrolet tracker 1.2 turbo mt 1.2 turbo mt 1.2'
#  'chevrolet tracker 1.2 ltz turbo at 1.2 ltz turbo at 1.2'
#  'chevrolet tracker 1.2 premier turbo at 1.2 premier turbo at 1.2'
#  'chevrolet tracker 1.8 ltz 1.8 ltz 1.8'
#  'chevrolet tracker 1.2 turbo at 1.2 turbo at 1.2'
#  'chevrolet tracker 1.2 turbo ltz at 1.2 turbo ltz at 1.2'
#  'chevrolet tracker 1.8 ltz+ awd at 140cv 1.8 ltz+ awd at 140cv 1.8'
#  'chevrolet tracker 1.8 ltz fwd mt 140cv 1.8 ltz fwd mt 140cv 1.8'
#  'chevrolet tracker 1.8 ltz awd at 140cv 1.8 ltz awd at 140cv 1.8'
#  'chevrolet tracker 1.2 turbo premier at 1.2 turbo premier at 1.2'
#  'chevrolet tracker 1.8 ltz+ 140cv 1.8 ltz+ 140cv 1.8'
#  'chevrolet tracker 1.8 ltz 140cv 1.8 ltz 140cv 1.8'
#  'chevrolet tracker 1.2 t premier at 4x2 1.2 t premier at 4x2 1'
#  'chevrolet tracker 1.8 ltz fwd at 140cv 1.8 ltz fwd at 140cv 1.8'
#  'chevrolet tracker premier at premier at 1.2'
#  'chevrolet tracker premier premier 1.2 turbo'
#  'chevrolet tracker tracker lt at tracker lt at 3 en linea 12 v'
#  'chevrolet tracker premier 1.2 at premier 1.2 at 1.2t'
#  'chevrolet tracker premier 1.2t at premier 1.2t at 1.2t at'
#  'chevrolet tracker 1.2 turbo at argentina 1.2 turbo at argentina 1.2'
#  'chevrolet tracker ltz ltz 1.2'
#  'chevrolet tracker ltz at ltz at 1.2 turbo'
#  'chevrolet tracker 1.2 turbo premier 1.2 turbo premier 1.2 turbo'
#  'chevrolet tracker 1.8 ltz+ 1.8 ltz+ 1.8'
#  'chevrolet tracker 1.2 turbo premier at 1.2 turbo premier at 1.2 turbo'
#  'chevrolet tracker ltz ltz 1.2 turbo'
#  'chevrolet tracker ltz 1.2t at ltz 1.2t at 1.2t'
#  'chevrolet tracker 1.2 t at premier cr 1.2 t at premier cr 1.2 turbo 3 cilindros'
#  'chevrolet tracker premier 1.2t at premier 1.2t at 1.2 turbo'
#  'chevrolet tracker ltz 1.2 at ltz 1.2 at 1.2t'
#  'chevrolet tracker premier at 1.2 premier at 1.2 1.2 turbo 3 cilindros'
#  'chevrolet tracker premier premier 1.2t'
#  'chevrolet tracker premier turbo at premier turbo at 1.2 turbo'
#  'chevrolet tracker premier 1.2 at premier 1.2 at 1.2 turbo 3 cilindros'
#  'chevrolet tracker 1.2 turbo mt argentina 1.2 turbo mt argentina 1.2'
#  'chevrolet tracker 1.8 ltz plus 4x4 aut 1.8 ltz plus 4x4 aut 1.8'
#  'chevrolet tracker premier premier 1.2 turbo 132 cv'
#  'chevrolet tracker 1.2t at premier 1.2t at premier 1200 cc'
#  'chevrolet tracker 1.8 4x4 ltz + awd premier 1.8 4x4 ltz + awd premier 1.8'
#  'chevrolet tracker 1.8 4x2 fwd ltz l 1.8 4x2 fwd ltz l 1.8'
#  'chevrolet tracker 1.8 ltz + awd 4x4 premier at 1.8 ltz + awd 4x4 premier at 1.8'
#  'chevrolet tracker 1.8 oremier ltz 1.8 oremier ltz 1.8'
#  'chevrolet tracker 1.8 lt fwd mt 4x2 1.8 lt fwd mt 4x2 1.8'
#  'chevrolet tracker ,8 ltz 4x4 nafta a/t 5 puertas 2017 tracker 5p 1,8 ltz a/t 4x4 a 1.8'
#  'chevrolet tracker 1.2t at ltz 1.2t at ltz 1.2 turbo 3 cilindros'
#  'chevrolet tracker ltz automatica 0km oportunidad st t ltz automatica 0km 2022 stock 1.2 turbo'
#  'chevrolet tracker 1.8 premier 4x2 mt 2019 imolaautos 1.8 premier 4x2 mt 1.87 premier 4x2 mt'
#  'chevrolet tracker lt at 1.2 turbo cr lt at 1.2 turbo 1.2 turbo 3 cilindros'
#  'chevrolet tracker ltz at ltz at 1.2'
#  '(blois) chevrolet - tracker ltz + awd at 1.8 n 2018 ltz + awd at 1.8 n'
#  'chevrolet tracker 1.2 t at 4x2 1.2 t at 4x2 1'
#  'chevrolet tracker 1.8 ltz l/17 mt 4x2 1.8 ltz l/17 mt 4x2 1'
#  'chevrolet tracker 1.8 ltz mt 4x2 1.8 ltz mt 4x2 1'
#  'chevrolet tracker 1.2 t ltz at 4x2 1.2 t ltz at 4x2 1'
#  'chevrolet tracker 1.8 ltz+ at 4x4 1.8 ltz+ at 4x4 1'
#  'chevrolet tracker 1.2 turbo mt 1.2 turbo mt 1.2 turbo'
#  'chevrolet tracker 1.2 at 1.2 at 1.2'
#  'chevrolet tracker 1.8 ltz mt 1.8 ltz mt 1.8'
#  'chevrolet tracker tracker ltz at tracker ltz at 1.8'
#  'chevrolet tracker 1.2 turbo at6 1.2 turbo at6 turboalimentado'
#  'chevrolet tracker 1.8 ltz+ 4x4 aut 1.8 ltz+ 4x4 aut 1.8'
#  'chevrolet tracker awd ltz 4x4 awd ltz 4x4 1.8'
#  'chevrolet tracker 1.2 t automatica ltz 1.2 t automatica ltz chevrolet 1.2 turbo'
#  'chevrolet tracker 1.8 ltz awd 140cv 1.8 ltz awd 140cv 1.8'
#  'chevrolet tracker 1.8 ltz premier 1.8 ltz premier 1.8'
#  'chevrolet tracker 1.2 at 1.2 at 1.2 turbo'
#  'chevrolet tracker 1.8 ltz 4x4 1.8 ltz 4x4 1.8'
#  'chevrolet tracker premier 1.8n premier 1.8'
#  'chevrolet tracker awd premier awd premier nan'
#  'chevrolet tracker ltz fwd 1.8 mt 140hp 2017 - anticipo - ltz fwd 1.8 mt 140hp 178nm torque - anticipo - 1.8'
#  'chevrolet tracker premier 1.2t at premier 1.2t at 1.2t'
#  'chevrolet tracker 1.8 fwd premier 2018 1.8 fwd premier 1.8'
#  'chevrolet tracker fwd premier 2019 fwd premier 1.8'
#  'chevrolet tracker premier+at4x4 año: 2018 km: 53.400 unica!! premier at 1.8 nafta'
#  'chevrolet tracker premier at 1,2 turbo premier at 1,2 turbo 1.2'
#  'chevrolet tracker premier 1.8 mt premier 1.8 mt 1.8'
#  'chevrolet tracker fwd premier fwd premier 1.8'
#  'chevrolet tracker awd premier + 2018 awd premier + nan'
#  'chevrolet tracker 1.8 4x2 ltz l13 1.8 4x2 ltz l13 inyeccion multi punto'
#  'chevrolet tracker 1.8 4x4 ltz plus premier at l17 1.8 4x4 ltz plus premier at l17 inyeccion multi punto'
#  'chevrolet tracker 1.8 4x2 ltz premier l17 1.8 4x2 ltz premier l17 inyeccion multi punto'
#  'chevrolet tracker 1.8 4x4 ltz plus at l13 1.8 4x4 ltz plus at l13 inyeccion multi punto'
#  'chevrolet tracker 1.2 t ltz at6 1.2 t ltz at6 turboalimentado'
#  'chevrolet tracker 1.8 4x4 ltz at l13 1.8 4x4 ltz at l13 inyeccion multi punto'
#  'chevrolet tracker ltz ltz 1.2 lt'
#  'chevrolet tracker 1.8 ltz mt 4x2 1.8 ltz mt 4x2 1.8'
#  'chevrolet tracker 1.8 premier ltz 1.8 premier ltz 1.8'
#  'chevrolet tracker 1.8 4x4 ltz at awd 1.8 4x4 ltz at awd 1.8'
#  'chevrolet tracker premier premier 1.8'
#  'chevrolet tracker 1.8 fwd premier 2019 1.8 fwd premier 1.8'
#  'chevrolet tracker 1.2 turbo at6 l/22 1.2 turbo at6 l/22 1.2'
#  'chevrolet tracker premier ltz mt premier ltz mt 1.8'
#  'chevrolet tracker 2024 automatica lt automatica nan'
#  'chevrolet tracker 1.8 ltz premier mt 1.8 ltz premier mt 1.8'
#  'chevrolet tracker ltz+4x4 ltz+4x4 1.8'
#  'chevrolet tracker tracker fwd premier tracker fwd premier 1.2'
#  'chevrolet tracker 1.8 ltz awd 1.8 ltz awd 1.8'
#  'chevrolet tracker awd ltz awd ltz 1.8'
#  'chevrolet tracker premier premier 1800'
#  'chevrolet trailblazer 2.8 nueva ltz tdci 200cv 2.8 nueva ltz tdci 200cv 2.8'
#  'chevrolet trailblazer 2.8 4x4 ltz at tdci 180cv 2.8 4x4 ltz at tdci 180cv 2.8'
#  'chevrolet trailblazer premier 2.8d turbo automatico awd 2024 chevrolet trailblazer premier 2.8 diesel turbo automatico awd motor 2.8 turbo diesel'
#  'chevrolet trailblazer premier 2.8d turbo automatico awd 2024 chevrolet trailblazer premier 2.8d turbo automatico awd 2024 motor 2.8 l turbo diesel'
#  'chevrolet trailblazer 2.8 4x4 premier at (2023) mm 2.8 4x4 premier at 2.8 td'
#  'chevrolet trailblazer 2.8 4x4 premier premier 4x4 2.8 tdi 200 cv'
#  'chevrolet trailblazer 2.8 4x4 premier at fc 2.8 4x4 premier at nan'
#  'chevrolet trailblazer 2.8 tdi 4x4 premier at 2022 imolaautos 2.8 tdi 4x4 premier at 2.8'
#  'chevrolet trailblazer 4x4 2.8 premier at kb 4x4 premier 2.8 at kb 2.8'
#  'chevrolet trailblazer 2.8 4x4 premier at bl 2.8 4x4 premier at bl 2.8'
#  'chevrolet trailblazer premier premier nan'
#  'chevrolet trailblazer trailblazer trailblazer 2.8'
#  'chevrolet trailblazer 2.8 4x4 lt at tdci 180cv 2.8 4x4 lt at tdci 180cv 2.8'
#  'chevrolet trailblazer 2.8 nueva ltz tdci 2.8 nueva ltz tdci 1'
#  'chevrolet trailblazer 2.8 4x4 ltz at l16 2.8 4x4 ltz at l16 turbo diesel inyeccion'
#  'chevrolet trailblazer 2.8 ctdi 4x4 ltz a/t 2.8 ctdi 4x4 ltz a/t nan']
#
# citroën
# ['citroën aircross 1.6 shine 115cv 1.6 shine 115cv 1.6'
#  'citroën aircross t200 at7 shine t200 at7 shine t200'
#  'citroën aircross t200 shine 0km 2024 entrega inmediata (s) t200 shine 0km 2024 t200'
#  'citroen c.3 aircross t.200 120 cv shine 1.0 120 cv t.200'
#  'citroën c3 1.6 tendance pk secure 1.6 tendance pk secure 1.6'
#  'citroen c3 aircross nuevo thp automatico 0km 2024 ml aircross t200 shine 1.2 thp'
#  'citroen c3 aircross thp at6 nuevo 0km 2024 ml aircross t200 shine 1.2 thp'
#  'citroen c3 aircross thp automatico nuevo 0km 2024 aircross t200 shine 1.2 thp'
#  'citroen c3 firts edition vti 0km no renegade cronos 208 firts edition eat6 1.6'
#  'citroen c3 first edition vti 115 no cronos onix 208 etios firts edition eat6 1.6'
#  'citroën c3 aircross 1.6 shine aircross 1.6 shine 1.6'
#  'citroën c3 aircross aircross 1.6'
#  'citroen c3 aircross shine automatico aircross shine 1.0'
#  'citroën c3 vti 1.6 n vti 1.6 n 1.6'
#  'citroen c3 1.6 feel pack desing 0km fr feel pack desing 1.6'
#  'citroen c3 picasso c3 picasso 1.6'
#  'citroen c3 aircross shine aircross t200 shine 1.0 turbo'
#  'citroen c3 aircross shine 1.0 turbo t200 ag shine t200 1.0 turbo'
#  'citroën c3 aircross t200 shine at7 (fu) t200 shine 1.0'
#  'citroën c3 aircross t200 shine eat7 (fu) t200 shine 1.0'
#  'nuevo c3 aircros shine t200 shine t200 t200'
#  'nuevo c3 aircross shine at 1.0 turbo shine 1.0'
#  'citroën c3 aircross t200 shine 5p t200 shine 1.0'
#  'citroën c3 aircross t200 shine 0km no tracker t cross (s) t200 shine 0km (s) t200'
#  'citroen c3 aircross ci shine 1.0'
#  'citroen suv c3 aircross ie manual y automatico 1.0'
#  'citroen suv c3 aircross ie shine 1.0'
#  'citroen c3 aircross shine t200 shine t200 1.0 turbo t200 120 cv'
#  'citroen c3 aircross t200 shine t200 shine 1.0 turbo'
#  'citroen c4 cactus shine turbo 165 cv shine tope de gama 1.6 thp'
#  'citroën c4 cactus feel pack plus 2022 c4 catus 1.6'
#  'citroën c4 aircross 2.0 tendance 4wd 150cv at6 2.0 tendance 4wd 150cv at6 2.0'
#  'citroën c4 aircross 2.0 tendence 2wd mt 2.0 tendence 2wd mt 1'
#  'citroën c4 aircross 2.0 tendence 2wd 150cv at 2.0 tendence 2wd 150cv at 2.0'
#  'citroën c4 aircross 2.0 tendence 2wd 150cv mt 2.0 tendence 2wd 150cv mt 2.0'
#  'citroën c4 cactus 1.6 vti 115 at6 feel pk 1.6 vti 115 at6 feel pk 1.6'
#  'citroën c4 cactus 1.6 vti 115 at6 shine 1.6 vti 115 at6 shine 1.6'
#  'citroën c4 cactus 1.6 thp 165 at6 shine 1.6 thp 165 at6 shine 1.6'
#  'citroën c4 cactus 1.6 vti 115 feel pk 1.6 vti 115 feel pk 1.6'
#  'citroën c4 cactus 1.2 puretech 110 at6 s&s shine 1.2 puretech 110 at6 s&s shine 1.2'
#  'citroën c4 cactus 1.6 noir 165 at6 1.6 noir 165 at6 1.6'
#  'citroën c4 cactus 1.6 vti 115 at6 shine bi tono 1.6 vti 115 at6 shine bi tono 1.6'
#  'citroën c4 cactus 1.2 puretech 110 at6 rip curl 1.2 puretech 110 at6 rip curl 1.2'
#  'citroën c4 cactus thp at noir thp at noir 1.6'
#  'citroën c4 cactus 1.6 vti 115 feel 1.6 vti 115 feel 1.6'
#  'citroën c4 cactus 1.6 vti rip curl at 1.6 vti rip curl at 1.6l'
#  'citroën c4 cactus 1.6 vti 115 at6 x-series 1.6 vti 115 at6 x-series 1.6'
#  'citroën c4 cactus 1.6 vti 115 x-series 1.6 vti 115 x-series 1.6'
#  'citroën c4 cactus noir noir nafta'
#  'citroën c4 cactus 1.6 feel at plus 1.6 feel at plus 1.6'
#  'citroën c4 cactus thp at noir thp at noir thp 1.6'
#  'citroen c4 cactus shine automatica 1.6 165 cv shine tope de gama 1.6 thp'
#  'citroen c4 cactus feel+ automatica feel + automatica 1.6 vti 115 cv'
#  'citroen c4 cactus shine thp 165 eat6 no tcross, sandero joi shine 1.6 turbo'
#  'citroen c4 cactus shine thp 165 eat6 no compass, tracker shine 1.6 turbo'
#  'citroen c4 cactus noir thp at noir thp 1.6i'
#  'c4 cactus vti at feel +my23 a feel design 1.6'
#  'c4 cactus shine my23 feel + vti 115'
#  'citroen c4 cactus 1.6 thp 163 cv shine shine tope de gama 1.6 thp'
#  'citroen c4 cactus feel + automatico feel + 1.6 vti'
#  'citroen c4 cactus vti 1.6 at feel +-my23 a feel at +my23 nan'
#  'citroen c4 cactus feel + my23 at feel + my 23 1.6 115cv'
#  'nuevo citroen c4 cactus shine noir thp 165 2024 no usado fm shine 1.6'
#  'c4 cactus vti at feel + feel+ at 1.6 vti'
#  'citroën c4 cactus thp at noir - 0km 1.6 noir 165 at6 nan'
#  'citroën c4 cactus 1.6 thp 165 shine bi tono at 1.6 thp 165 shine bi tono at 1'
#  'citroën c4 cactus 1.6 vti 115 feel mt 1.6 vti 115 feel mt 1'
#  'citroën c4 cactus 1.6 thp shine at 1.6 thp shine at 1'
#  'citroën c4 cactus 1.6 thp 165 shine at 1.6 thp 165 shine at 1'
#  'citroën c4 cactus 1.6 vti 115 feel pk mt 1.6 vti 115 feel pk mt 1'
#  'citroën c4 cactus 1.6 vti 115 feel+ at 1.6 vti 115 feel+ at 1'
#  'citroën c4 cactus 1.6 thp 165 at6 shine 1.6 thp 165 at6 shine nan'
#  'citroën c4 cactus shine thp tip. shine thp tip. thp'
#  'citroën c4 cactus 1.6 vti 115 live 1.6 vti 115 live 1.6'
#  'citroën c4 cactus 1.6 115 feel pack 1.6 115 feel pack 1.6'
#  'citroën c4 cactus c4 cactus noir c4 cactus noir 1.6'
#  'citroën c4 cactus 1.6 vti 115 origins 1.6 vti 115 origins 1.6'
#  'citroën c4 cactus citroën c4 cactus 1.6 thp 165 at6 shine citroën c4 cactus 1.6 thp 165 at6 shine 1.6'
#  'citroen c4 cactus feel + at bitono feel + at bitono nan'
#  'c4 cactus vti at feel + my23 feel + 1.6 vti'
#  'citroën c4 cactus thp noir 0km 2024 thp noir 1.6 thp'
#  'citrown c4 cactus feel + automatico 0km feel + 1.6 vti 115'
#  'citroen c4 feel+ tip. 0km 2024 c4 cactus feel+ tip. 1.6'
#  'citroën c4 cactus 1.6 vti feel pack 1.6 vti feel pack inyeccion multi punto'
#  'citroen c4 cactus fell + 1.6'
#  'citroën c4 cactus 1.6 vti live 1.6 vti live inyeccion multi punto'
#  'citroën c4 cactus c4 1.6 thp 165 at6 c4 1.6 thp 165 at6 1.6 turbo 165 hp'
#  'citroën c4 cactus 1.6 vti feel pack plus bt 1.6 vti feel pack plus bt inyeccion multi punto'
#  'citroën c4 cactus 1.6 thp shine at6 bt l18 1.6 thp shine at6 bt l18 turboalimentado'
#  'citroën c4 cactus shine 1.6 turbo auto shine 1.6 turbo auto 1.6'
#  'citroen c4 cactus thp shine 2019 thp shine 1.6 thp 165 cv'
#  'citroen c4 cactus automatico feel + at 1.6 vti'
#  'citroen c4 cactus automatico feel + feel + 1.6 vti'
#  'citroen c4 cactus shine thp shine 1.6 thp 165 cv'
#  'citroen c4 cactus 1.6 feel+ automatico feel + 1.6 vti'
#  'citroën c4 cactus 1.6 vti feel l18 1.6 vti feel l18 inyeccion multi punto'
#  'citroen c4 cactus 1.6 feel pack c-series feel pack c-series 1.6 mt5 1.6'
#  'citroen c4 cactus feel pack am 21 feel pack am 21 116 hp'
#  'citroen c4 cactus feel + 1.6'
#  'citroën c5 aircross 1.6 thp eat6 feel pack 1.6 thp eat6 feel pack 1.6'
#  'citroën c5 aircross feel pack thp 1.6 eat6 feel pack thp 1.6 eat6 1.6'
#  'citroën c5 aircross thp 165 eat6 feel pack thp 165 eat6 feel pack 1.6 thp 165cv'
#  'citroën c5 aircross 1.6 thp feel pack at6 l20 1.6 thp feel pack at6 l20 turboalimentado'
#  'citroën c5 aircross 1.6 thp feel pack at6 1.6 thp feel pack at6 turboalimentado']
#
# isuzu
# ['isuzu amigo 2.2 xs 4x4 2.2 xs 4x4 2.2'
#  'isuzu rodeo 3.2 xs v6 4x4 3.2 xs v6 4x4 3.2'
#  'isuzu rodeo 3,1 nafta v6 4x4 3,1 nafta v6 4x4 3.2'
#  'isuzu rodeo 3.2 v6 4x4 at 3.2 v6 4x4 at 3.2'
#  'isuzu rodeo 3.2 ls v6 4x4 ct 3.2 ls v6 4x4 ct 3.2'
#  'isuzu rodeo 3.2 ls v6 4x4 ct at 3.2 ls v6 4x4 ct at 3.2'
#  'isuzu rodeo 4x4 4x4 3.2' 'isuzu trooper 2.6 ls 2.6 ls 2.6'
#  'isuzu trooper 3.1 di banzai wagon 3.1 di banzai wagon 3.1'
#  'isuzu trooper 3.1 i scout wagon 3.1 i scout wagon 3.1'
#  'isuzu trooper 3.0 i kuroi wagon 3.0 i kuroi wagon 3.0'
#  'isuzu trooper 3.1 i ls wagon 3.1 i ls wagon 3.1'
#  'isuzu trooper 2.6 hard top 2.6 hard top 2.6'
#  'isuzu trooper 3.2 v6 wagon 3.2 v6 wagon 3.2'
#  'isuzu trooper 3.0 i ls at wagon 3.0 i ls at wagon 3.0'
#  'isuzu trooper 3.0 i ls wagon 3.0 i ls wagon 3.0'
#  'isuzu trooper tdi 3.1 turbo diesel tdi 3.1 turbo diesel turbo diesel 3.0']
#
# ford
# ['ford bronco wildtrack wildtrack 2.0 l'
#  'ford bronco sport 2.0 wildtrak 2022 bronco 2.0t sport wildtrack ecoboost 2.0'
#  'ford bronco wildtrack 2024 2.0l 4x4 wildtrack 2.0 4x4 2.0'
#  'ford bronco big beng 4x4 at 1.5 big beng 1.5 4x4 1.5'
#  'ford bronco wildtrak 0km 2023 wildrack 2.0'
#  'ford bronco sport 1.5 big bend 2022 20.000 km! bronco 1.5t sport big bend ecoboost 1.5'
#  'ford bronco sport 2.0 4wd wildtrak at8 2.0 4wd wildtrak at8 2.0'
#  'ford bronco sport 1.5 ecoboost 4wd big bend at8 1.5 ecoboost 4wd big bend at8 1.5'
#  'ford bronco sport 1.5 4wd big bend at8 1.5 4wd big bend at8 1.5'
#  'ford bronco sport 2.0 ecoboost 4wd wildtrak at8 2.0 ecoboost 4wd wildtrak at8 2.0'
#  'ford bronco sport big bend 1.5 at. big bend 1.5 at 1.5 175cv at'
#  'ford bronco wildtrack 2024 wildtrack 2.0l'
#  'ford ecosport 2.0 titanium 143cv 4x2 2.0 titanium 143cv 4x2 2.0'
#  'ford ecosport 1.6 xl plus mp3 4x2 1.6 xl plus mp3 4x2 1.6'
#  'ford ecosport 1.6 my10 xls 4x2 1.6 my10 xls 4x2 1.6'
#  'ford ecosport 2.0 titanium powershift 143cv 4x2 2.0 titanium powershift 143cv 4x2 2.0'
#  'ford ecosport 1.6 freestyle 110cv 4x2 1.6 freestyle 110cv 4x2 1.6'
#  'ford ecosport 1.6 titanium 110cv 4x2 1.6 titanium 110cv 4x2 1.6'
#  'ford ecosport 1.5 titanium 123cv 4x2 manual 1.5 titanium 123cv 4x2 manual 1.5'
#  'ford ecosport 1.5 s 123cv 4x2 1.5 s 123cv 4x2 1.5'
#  'ford ecosport 2.0 my10 xls 4x2 2.0 my10 xls 4x2 2.0'
#  'ford ecosport 1.5 se tdci 90cv 4x2 1.5 se tdci 90cv 4x2 1.5'
#  'ford ecosport 1.5 se 123cv 4x2 automatica 1.5 se 123cv 4x2 automatica 1.5'
#  'ford ecosport 1.5 se 123cv 4x2 1.5 se 123cv 4x2 1.5'
#  'ford ecosport 1.5 se 123cv 4x2 manual 1.5 se 123cv 4x2 manual 1.5'
#  'ford ecosport 1.6 se 110cv 4x2 1.6 se 110cv 4x2 1.6'
#  'ford ecosport 2.0 freestyle 143 4x4 2.0 freestyle 143 4x4 2.0'
#  'ford ecosport 1.6 s 110cv 4x2 1.6 s 110cv 4x2 1.6'
#  'ford ecosport 2.0 titanium powershift 4x2 dps6 2.0 titanium powershift 4x2 dps6 2.0'
#  'ford ecosport 1.5 freestyle 123cv 4x2 1.5 freestyle 123cv 4x2 1.5'
#  'ford ecosport 1.6 my10 xl plus mp3 4x2 1.6 my10 xl plus mp3 4x2 1.6'
#  'ford ecosport 2.0 xlt plus 4x2 2.0 xlt plus 4x2 2.0'
#  'ford ecosport 1.6 xls 1.6 xls 1.6' 'ford ecosport 2.0 xlt 2.0 xlt 2'
#  'ford ecosport 2.0 gdi freestyle 170cv 4x4 2.0 gdi freestyle 170cv 4x4 2.0'
#  'ford ecosport 1.6 my10 xls plus 4x2 1.6 my10 xls plus 4x2 1.6'
#  'ford ecosport 1.5 d se 100cv 4x2 1.5 d se 100cv 4x2 1.5'
#  'ford ecosport 1.5 titanium 123cv 4x2 automatica 1.5 titanium 123cv 4x2 automatica 1.5'
#  'ford ecosport 1.5 s tdci 90cv 4x2 1.5 s tdci 90cv 4x2 1.5'
#  'ford ecosport titanium 2.0l at titanium 2.0l at 2.0'
#  'ford ecosport 2.0 freestyle 4x4 2.0 freestyle 4x4 2'
#  'ford ecosport 1.6 freestyle 110cv 4x2 1.6 freestyle 110cv 4x2 nan'
#  'ford ecosport 2.0 titanium at 2.0 titanium at 2.0'
# ...
#  'bmw x1 xdrive 25i xdrive 25i 231cv' 'bmw x1 xdrive xdrive 2.0'
#  'bmw x1 2.0 sdrive active 2.0 sdrive active 2.0'
#  'bmw x1 20i sdrive sport 20i sdrive sport 2.0t'
#  'bmw x1 2.0 sdrive 20d active 177cv 2.0 sdrive 20d active 177cv 2.0'
#  'bmw x1 xdrive 25i xdrive 25i 2.0'
#  'bmw x1 x1 20i x-drive x1 20i x-drive 2.0'
#  'bmw x1 2.0 xdrive 20d active 177cv 2.0 xdrive 20d active 177cv 2.0'
#  'bmw x1 18i 18i 18i' 'bmw x1 25i xdrive xdrive nan'
#  'bmw x1 2.0 sdrive 20d active 177cv 2.0 sdrive 20d active 177cv 2'
#  'bmw x1 20i sportline 20i sportline 2.0 t'
#  'bmw x1 1.8i s-drive at 1.8i s-drive at 3'
#  'bmw x1 25i xdrive 25i xdrive 2.0'
#  'bmw x1 bmw x1 xdrive 2.0 l bmw x1 xdrive 2.0 l 2.0'
#  'bmw x1 25i xline xdrive 25i xline xdrive 2.0t'
#  'bmw x1 2024 linea nueva / bremen motors palermo todoterreno nan'
#  'bmw x1 2.0 xdrive pack m 2.0 xdrive pack m 2.0'
#  'bmw x1 x1 sdrive 18i x1 sdrive 18i 1.5'
#  'bmw x1 25i xdrive xline 25i xdrive xline 2.0'
#  'bmw x1 xdrive 25i xline 231cv xdrive 25i xline 231cv turbo 2.0 l 231cv'
#  'bmw x1 bmw x1 2.0 xdrive 25i xline 231cv bmw x1 2.0 xdrive 25i xline 231cv 2000'
#  'bmw x1 x drive 2.0 diesel x drive 2.0 diesel 2.0' 'bmw x1 x25i x25i 2.0'
#  'bmw x2 2.0 sdrive20i msportx 2.0 sdrive20i msportx 2.0'
#  'bmw x2 2.0 sdrive 20i msport x 2.0 sdrive 20i msport x 2.0'
#  'bmw x2 2.0 sdrive20i gp 2.0 sdrive20i gp 2.0'
#  'bmw x2 2.0 m35i mpa 2.0 m35i mpa 2.0'
#  'bmw x2 35i año 2021 - bmw x2 35 no audi q3 ni audi q5 x2 20i x2 35i m performance 4x4 con 306 cv turbo m performance con 306 cv'
#  'bmw x2 m35i 2023 0km - garantia oficial 3 años o 200.000 km 35 i nan'
#  'bmw x2 sdrive 20i m sport 2018 nave 1 garage sdrive 20i m sport x 2.0'
#  'bmw x2 20i sport 20i sport 2.0' 'bmw x2 sdrive 20 i sdrive 20 i 2.0'
#  'bmw x3 2.0 xdrive 30i xline 2.0 xdrive 30i xline 2.0'
#  'bmw x3 2.0 xdrive 20i executive 184cv 2.0 xdrive 20i executive 184cv 2.0'
#  'bmw x3 3.0 x3 xdrive 35i m package 306cv 3.0 x3 xdrive 35i m package 306cv 3.0'
#  'bmw x3 2.0 xdrive 20i xline 184cv 2.0 xdrive 20i xline 184cv 2.0'
#  'bmw x3 3.0 x3 xdrive 3.0 x3 xdrive 3.0'
#  'bmw x3 xdrive 30e xdrive 30e 2.0'
#  'bmw x3 2.0 xdrive 20d active 184cv 2.0 xdrive 20d active 184cv 2.0'
#  'bmw x3 2.5 si selective 2.5 si selective 2.5'
#  'bmw x3 3.0 x3 xdrive 35i executive 306cv 3.0 x3 xdrive 35i executive 306cv 3.0'
#  'bmw x3 2.0 xdrive 20d executive 184cv 2.0 xdrive 20d executive 184cv 2.0'
#  'bmw x3 2.5 x3 i executive 2.5 x3 i executive 2.5'
#  'bmw x3 2.0 xdrive 28i xline 245cv 2.0 xdrive 28i xline 245cv 2.0'
#  'bmw x3 30i xdrive 30i xdrive 2.0'
#  'bmw x3 2.5 si xdrive limited edition 2.5 si xdrive limited edition 2.5'
#  'bmw x3 30i okm 2024 - bmw x3 - no audi q8 ni glc 300 okm bmw x3 30i okm 2024 linea nueva - tablero digital - 258 cv - 4x4 turbo 258 cv - 2.0'
#  'nuevo bmw x3 30e plug-in hibryd 0km - natalio automotores 30e 292hp'
#  'bmw x3 hibrida enchufable okm 2024 - bmw x3 hibrida okm 2024 bmw x3 hibrida okm 2024 - linea nueva - llantas 20 292 cv - turbo - hibrido enchufable + nafta'
#  'bmw x3 m40i xdrive m40i 3.0 turbo intercooler'
#  'bmw x3 2.0 xdrive 30e xline 2.0 xdrive 30e xline 2.0'
#  'bmw x3 x3 xdrive 3.0 x3 xdrive 3.0 3.0'
#  'bmw x3 xdrive 30i xdrive 30i 3.0'
#  'bmw x3 30i xdrive pack m 30i xdrive pack m 30'
#  'bmw x3 2.0 30i 2.0 30i 2.0'
#  'bmw x3 3.0 x3 xdrive 35i executive 306cv 3.0 x3 xdrive 35i executive 306cv 3'
#  'bmw x3 2.0 xdrive 30i executive 2.0 xdrive 30i executive 2.0'
#  'bmw x3 3.0 iexecutive stept 3.0 iexecutive stept 3.0'
#  'bmw x3 xdrive 30i 2.0 xdrive 30i xline 2.0'
#  'bmw x3 30e hibrida 2024 / bremen motors palermo hibrida hibrido'
#  'bmw x3 m40i sport 2018 m40i sport 3000cc 6cil 360hp'
#  'bmw x3 m40i sport 2018 impecable x3 m40i drive sport 3000cc 6cil 360hp'
#  'bmw x3 xdrive 30e genco bmw xdrive 30e nafta / electrico'
#  'bmw x3 3.0 x3 i executive 3.0 x3 i executive 3.0'
#  'bmw x3 2.0 xdrive 20d executive 184cv 2.0 xdrive 20d executive 184cv 3'
#  'bmw x3 2.0 xdrive 28i xline 245cv 2.0 xdrive 28i xline 245cv 2'
#  'bmw x3 2.5 2.5si selective 2.5 2.5si selective 2.5'
#  'bmw x3 2.5 xdrive25i 2.5 xdrive25i 2,5'
#  'bmw x3 2.5 2.5si selective stept 2.5 2.5si selective stept 2.5'
#  'bmw x3 2.0 xdrive 20i 184cv 2.0 xdrive 20i 184cv 2.0'
#  'bmw x3 30e 30e 292cv' 'bmw x3 xdrive 30i - genco bmw xdrive 30i nan'
#  'bmw x3 m m 3.0'
#  'bmw x3e hibrida enchufafle / bremen motors palermo hibrida hibrido enchufable'
#  'bmw x3 3.0 d executive stept 3.0 d executive stept 3.0'
#  'bmw x3 3.0 x3 d executive 3.0 x3 d executive 3.0'
#  'bmw x3 30e hybrida enchufable patentada 30e 3.0'
#  'bmw x4 3.0 xdrive 35i 306cv m package 3.0 xdrive 35i 306cv m package 3.0'
#  'bmw x4 2.0 xdrive 20i 184cv 2.0 xdrive 20i 184cv 2.0 184cv'
#  'bmw x4 2.0 xdrive 28i xline 245cv 2.0 xdrive 28i xline 245cv 2.0'
#  'bmw x4 2.0 xdrive 20i executive 184cv 2.0 xdrive 20i executive 184cv 2.0'
#  'bmw x4 20i xdrive 20i xdrive 2.0'
#  'bmw x4 20i año 2019 - no bmw x4 28i ni audi q5 x4 20i automatica 184 cv - 4x4 año 2019 turbo 2.0 con 184 cv'
#  'bmw x5 3.0 xdrive 40d m package 313cv 3.0 xdrive 40d m package 313cv 3.0'
#  'bmw x5 3.0 xdrive 35i executive 306cv 3.0 xdrive 35i executive 306cv 3.0'
#  'bmw x5 3.0 d executive stept 3.0 d executive stept 3.0'
#  'bmw x5 40i xdrive 40i xdrive 3.0'
#  'bmw x5 3.0 d executive 3.0 d executive 3.0'
#  'bmw x5 3.0 xdrive 35i 306cv pure excellence 3.0 xdrive 35i 306cv pure excellence 3.0'
#  'bmw x5 3.0 si executive 3.0 si executive 3.0'
#  'bmw x5 4.4 m 555cv 4.4 m 555cv 4.4'
#  'bmw x5 4.4 xdrive 50i 449cv m package 4.4 xdrive 50i 449cv m package 4.4'
#  'bmw x5 4.4 xdrive 50i premium 407cv 4.4 xdrive 50i premium 407cv 4.4'
#  'bmw x5 4.8 4.8l premium stept 4.8 4.8l premium stept 4.8'
#  'bmw x5 xdrive 40i 2024 + adicionales autopremium 40i 40i'
#  'bmw x5xdrive40i nueva !!!!! 0km x5xdrive40i 3.0'
#  'bmw x5 xdrive 40i xdrive 40i 3.0'
#  'bmw x5 4.4 xdrive 50i 449cv security 4.4 xdrive 50i 449cv security 4.4'
#  'bmw x5 40i x drive 40i x drive 3.0'
#  'bmw x5 3.0 xdrive 30d executive 245cv 3.0 xdrive 30d executive 245cv 3.0'
#  'bmw x5 40i xdrive 2024 / bremen motors 40i xdrive 3.0'
#  'bmw x5 40i 40i 340cv' 'bmw x5 4.8 is premium 4.8 is premium 4.8'
#  'bmw x5 4.8 4.8is premium 4.8 4.8is premium 4.8'
#  'bmw x5 4.8 4.8i premium stept 4.8 4.8i premium stept 4.8'
#  'bmw x5 3.0 i executive stept 3.0 i executive stept 3.0'
#  'bmw x5 3.0 si executive stept. 3.0 si executive stept. 3.0'
#  'bmw x5 4.8 is premium stept 4.8 is premium stept 4.8'
#  'bmw x5 4.4 4.4i premium security 4.4 4.4i premium security 4.4'
#  'bmw x5 40i xdrive 2024 / bremen motors palermo 40m nafta'
#  'bmw x5 xdrive 40i automunich x5 xdrive 40i 3.0'
#  'bmw x5 3.0 d executive stept. 3.0 d executive stept. 3.0'
#  'bmw x5 3.0 iexecutive stept 3.0 iexecutive stept 3.0'
#  'bmw x6 3.0 xdrive 35i sportive 306cv 3.0 xdrive 35i sportive 306cv 3.0'
#  'bmw x6 4.4 m 555cv 4.4 m 555cv 4.4'
#  'bmw x6 3.0 xdrive 35i sportive 306cv 3.0 xdrive 35i sportive 306cv 3'
#  'bmw x6 m m m'
#  'bmw x6 3.0 xdrive 35i pure extravagance 3.0 xdrive 35i pure extravagance 3.0'
#  'bmw x6 4.4 xdrive 50i premium 407cv 4.4 xdrive 50i premium 407cv 4.4'
#  'bmw x6 3.0 xdrive 35i pure extravagance 3.0 xdrive 35i pure extravagance 3'
#  'bmw x6 4.4 xdrive 50i m package 449cv 4.4 xdrive 50i m package 449cv 4.4'
#  'bmw x6 bmw x6 xdrive 40i bmw x6 xdrive 40i 4.4'
#  'bmw x6 3.0 xdrive 30d sportive 245cv 3.0 xdrive 30d sportive 245cv 3.0'
#  'bmw x6 m x6 m 4.4l 8 cilindros en v , 575 cv']
#
# alfa romeo
# ['alfa romeo stelvio 2.0 280cv at q4 super 2.0 280cv at q4 super 2.0'
#  'alfa romeo stelvio 2.0 200cv distinctive q4 2.0 200cv distinctive q4 2.0'
#  'alfa romeo stelvio 2.0 280cv at q4 veloce 2.0 280cv at q4 veloce 2.0'
#  'alfa romeo stelvio new veloce q4 new veloce q4 2.0'
#  'alfa romeo stelvio 2.0 280cv 2.0 280cv 2'
#  'alfa romeo stelvio 2.0 280cv 2.0 280cv 2.0'
#  'alfa romeo stelvio 2.0 200cv 2.0 200cv 2.0']
#
# chery
# ['chery tiggo 2.0 f2 confort 4x2 138cv 2.0 f2 confort 4x2 138cv 2.0'
#  'chery tiggo 2.0 f2 luxury 4x4 138cv 2.0 f2 luxury 4x4 138cv 2.0'
#  'chery tiggo 1.6 f2 confort 4x2 125cv 1.6 f2 confort 4x2 125cv 1.6'
#  'chery tiggo 2.0 f2 luxury 4x2 at 138cv 2.0 f2 luxury 4x2 at 138cv 2.0'
#  'chery tiggo 2.0 confort 4x2 127cv 2.0 confort 4x2 127cv 2.0'
#  'chery tiggo 3 1.6 4x2 confort l16 3 1.6 4x2 confort l16 inyeccion multi punto'
#  'chery tiggo 2.0 luxury 4x4 127cv 2.0 luxury 4x4 127cv 2.0'
#  'chery tiggo luxury manual luxury manual 2.0'
#  'chery tiggo 2.0 4x4 luxury l13 2.0 4x4 luxury l13 inyeccion multi punto'
#  'chery tiggo 2.0 confort 4x2 gnc 2.0 confort 4x2 gnc 2.0'
#  'chery tiggo 5 2.0 luxury cvt 5 2.0 luxury cvt 2.0'
#  'chery tiggo 2 1.5 confort 1.5 confort 1.5'
#  'chery tiggo 2 1.5 luxury 1.5 luxury 1.5'
#  'chery tiggo 2 luxury 4x2 at luxury 4x2 at nan'
#  'chery tiggo 3 1.6 3 confort 1.6 3 confort 1.6'
#  'chery tiggo 3 1.6 3 luxury 1.6 3 luxury 1.6'
#  'chery tiggo 3 1.6 3 luxury cvt 1.6 3 luxury cvt 1.6'
#  'chery tiggo 3 1.6 confort mt 1.6 confort mt 1'
#  'chery tiggo 3 luxury luxury 1.6'
#  'chery tiggo 3 cvt luxury 1.6 cvt luxury 1.6 1.6'
#  'chery tiggo 3 1.6 luxury cvt 1.6 luxury cvt 1.6'
#  'chery tiggo 3 confort manual 4x2 confort manual 4x2 1.6'
#  'chery tiggo 4 2.0 comfort cvt 2.0 comfort cvt 2.0'
#  'chery tiggo 4 luxury cvt automatic luxury cvt automatic 1.5'
#  'chery tiggo 4 1.5 confort manual 1.5 confort manual 1.5'
#  'chery tiggo 4 pro turbo 1.5 luxury cvt okm sin rodar 2023 1.5 pro luxury cvt 1.5 turbo'
#  'chery tiggo 4 1.5 turbo luxury cvt 0km 2024 1.5 turbo luxury cvt 1500 turbo'
#  'chery tiggo 4 pro 1.5t luxury pro 1.5'
#  'chery tiggo 4 pro 1.5 comfort cvt 1.5 comfort cvt 1.5'
#  'chery tiggo 4 pro 1.5t luxury cvt 1.5t luxury cvt 1.5t'
#  'chery tiggo 4 pro comfort cvt comfort cvt 1.5'
#  'chery tiggo 4 pro luxury cvt luxury cvt 1.5 turbo'
#  'chery tiggo 4 pro confort cvt 1.5l confort cvt 1.5l 1.5'
#  'chery tiggo 4 pro 1.5 comfort mt 1.5 comfort mt 1.5'
#  'chery tiggo 4 pro 1.5 luxury cvt 1.5 luxury cvt 1.5'
#  'chery tiggo 4 pro luxury cvt 1.5t luxury cvt 1.5t 1.5 t'
#  'chery tiggo 4 pro 1.5 confort manual 1.5 confort manual 1500'
#  'chery tiggo 4 pro confort mt confort mt 1.5'
#  'chery tiggo 5 2.0 luxury at 2.0 luxury at 2.0'
#  'chery tiggo 5 2.0 luxury at 2.0 luxury at 1'
#  'chery tiggo 5 2.0 luxury 2.0 luxury 2.0'
#  'chery tiggo 5 2.0 5 comfort 2.0 5 comfort 2.0'
#  'chery tiggo 5 2.0 comfort 2.0 comfort 2.0'
#  'chery tiggo 8 pro 1.6 luxury cvt 1.6 luxury cvt 1.6'
#  'chery tiggo 8 pro luxury cvt luxury cvt 1.6 turbo'
#  'chery tiggo 8 pro 1.6 t luxury cvt 7 plazas 1.6 t luxury cvt 7 plazas 1600'
#  'chery tiggo 8 pro luxury cvt luxury cvt 1.6 t']
#
# baic
# ['baic x25 1.5 elite 1.5 elite 1.5'
#  'baic x25 1.5 elite at 1.5 elite at 1.5'
#  'baic x35 1.5 luxury at 1.5 luxury at 1.5'
#  'baic x35 1.5 luxury 1.5 luxury 1.5'
#  'baic x35 confort turbo sport cvt - 2024 - baic vicente l - confort turbo "sport" cvt 1.5 turbo 148 hp'
#  'baic x35 confort turbo sport cvt - 2024 - baic palermo - confort turbo "sport" cvt 1.5 turbo 148 hp'
#  'baic x35 confort turbo cvt - 2024 - baic palermo - confort turbo cvt 1.5 turbo 148 hp'
#  'baic x35 luxury turbo sport bi-tono - 2024 - baic palermo - luxury turbo sport bi-tono 1.5 turbo 148 hp'
#  'baic x35 confort turbo cvt - 2024 - baic vicente lopez - confort turbo cvt 1.5 turbo 148 hp'
#  'baic x35 confort turbo - 2024 - baic ramos mejia- confort turbo cvt 1.5 turbo 148 hp'
#  'baic x35 confort turbo - 2024 - baic ramos mejia - confort turbo cvt 1.5 turbo 148 hp'
#  'baic x35 fashion at 2024 imolaautos 1.5 fashion at 1.5'
#  'baic x 35 1.5 luxury at 1.5 luxury at inyeccion multi punto'
#  'baic x35 1.5 cvt fashion 1.5 cvt fashion 1.5'
#  'baic x35 turbo / martelli automotores turbo 1.5 turbo 148hp cadenero'
#  'baic x35 turbo 2023 / martelli automotores fashion turbo 1.5 turbo mitsubishi cadenero 148hp'
#  'baic x55 1.5t elite cvt 1.5t elite cvt 1.5' 'baic x55 1.5t 1.5t 1.5t'
#  'baic x55 ii luxury turbo - 2024 - baic vicente lopez - ii luxury turbo 1.5 turbo 185 hp'
#  'baic x55 ii luxury turbo - 2024 - baic palermo - ii luxury turbo 1.5 turbo 185 hp'
#  'baic x55 ii luxury turbo - 2024 - baic palermo - ii luxury bi-tono 1.5 turbo 185 hp'
#  'baic x55 ii luxury turbo - 2024 - baic vicente lopez - ii luxury bi-tono 1.5 turbo 185 hp'
#  'baic x55 ii luxury turbo - 2024 - baic ramos mejia- ii luxury bi-tono 1.5 turbo 185 hp'
#  'baic x55 ii luxury turbo - 2024 - baic ramos mejia- ii luxury 1.5 turbo 185 hp'
#  'baic x55 ii luxury trubo - 2024 - baic ramos mejia - ii luxury 1.5 turbo 185 hp'
#  'baic x55 ii luxury turbo - 2024 - baic vicente lopez - ii luxury 1.5 turbo 185 hp'
#  'baic x55 ii luxury turbo - 2024 - baic palermo - ii luxury 1.5 turbo 185 hp'
#  'baic x55 ii luxury turbo - 2024 - baic palermo - ii 1.5 turbo 185 hp'
#  'baic x55 ii 1.5 luxury turbo 2024 imolaautos 1.5t luxury dct at 1.5t luxury dct at'
#  'baic x55 ii 1.5 luxury turbo 2024 imolaautos 1.5 turbo dct - luxury 1.5 turbo dct - luxury'
#  'baic x55 ii 1.5 luxury turbo 2024 imolaautos 1.5 turbo dct - luxury bi-tono 1.5 turbo dct - luxury bi-tono'
#  'baic x55 ii 1.5 luxury turbo 2024 imolaautos 1.5 turbo ctv - luxury 1.5 turbo ctv - luxury'
#  'baic x55 ii 1.5 luxury turbo 2024 imolaautos 1.5 turbo dct - luxury x55 1.5 turbo dct - luxury'
#  'baic x55 ii 1.5 luxury 2024 imolaautos 1.5t luxury dct at 1.5t'
#  'baic x55 ii 1.5 luxury turbo 2024 imolaautos 1.5 turbo dct - luxury nan'
#  'baic x55 1.5 turbo honor 2022 1.5 turbo honor 1.5 turbo'
#  'baic x 55 ii 1.5t dct luxury 1.5 turbo'
#  'baic x55 bi-tono 2024 suv 1.5 turbo geometria variable 183hp'
#  'baic x55 luxury 2021 luxury mitsubishi 1.5 turbo']
#
# jetour
# ['jetur x70 1.5 lt at 1.5 lt at 1.5' 'jetour x 70 at. turbo 1.5'
#  'jetour x70 7 plazas 1.5 turbo' 'jetur at premium 1.5 turbo'
#  'jetour x70 turbo 8at 7 asientos 2023 2.0 t 1.5']
#
# volvo
# ['volvo xc40 2.0t t4 momentum fwd 2.0t t4 momentum fwd 2.0'
#  'volvo xc40 2.0t t5 r-design awd 2.0t t5 r-design awd 2.0'
#  'volvo xc40 2.0t t4 inscription awd 2.0t t4 inscription awd 2.0'
#  'volvo xc40 xc 40 t5 awd cassano automobili xc 40 t5 awd 2.0 t5'
#  'xc40 plus b4 mild hybrid plus b4 mild hybrid 2.0t 198 mild hybrid'
#  'volvo xc40 b4 plus mild hybrid plus b4 mild hybrid 2.0t 198hp mild hybrid'
#  'volvo xc40 b4 plus plus b4' 'volvo xc40 t5 phev xc40 t5 phev 1.5 turbo'
#  'volvo xc40 b4 ultimate mild hybrid b4 ultimate mild hybrid 2.0'
#  'volvo xc40 b4 mild hybrid 2024 autopremium b4 mild hybrid 2.0'
#  'volvo xc40 b4 plus mild hybrid b4 plus mild hybrid 2.0'
#  'volvo xc40 t4 momentum 2020 22.000 kms autopremium t4 momentum turbo'
#  'volvo xc40 ultimate b4 mild hybrid ultimate b4 mild hybrid 2.0t 198hp mild hybrid'
#  'volvo xc40 t5 awd momentum t5 momentum awd 247hp 2.0t 247hp'
#  'volvo xc40 b4 ultimate ultimate b4'
#  'xc40 t5 262hp ultimate dark - plug in hybrid xc40 t5 262hp ultimate dark 262hp plug in hybrid'
#  'volvo xc40 t5 t5 r-design awd 247hp 2.0t 247hp'
#  'volvo xc40 2.0t t5 r-design awd cassano 2.0t t5 r-design awd 2.0'
#  'volvo xc40 b4 plus b4 plus semihibrido 2.0'
#  'volvo xc60 2.0 t5 awd comfort 240cv 2.0 t5 awd comfort 240cv 2.0'
#  'volvo xc60 3.0 t6 high plus 304cv at awd 3.0 t6 high plus 304cv at awd 3.0'
#  'volvo xc60 2.0 awd 203cv 2.0 awd 203cv 2.0'
#  'volvo xc60 3.0 t6 high 304cv at awd 3.0 t6 high 304cv at awd 3.0'
#  'volvo xc60 2.0 t5 high plus 240cv at 2.0 t5 high plus 240cv at 2.0'
#  'volvo xc60 2.0 t5 high 240cv at 2.0 t5 high 240cv at 2.0'
#  'volvo xc60 2.0 t5 inscription 2.0 t5 inscription 2.0'
#  'volvo xc60 inscription t6 awd at inscription t6 awd at t6'
#  'volvo xc60 2.5 t5 momentum 2.5 t5 momentum 2.5'
#  'volvo xc60 2.0t t5 momentum awd 2.0t t5 momentum awd 2.0'
#  'volvo xc60 t8 462hp plug in hybrid t8 ultimate dark t8 462hp'
#  'volvo xc60 t5 awd inscription t5 awd inscription 2.5t'
#  'volvo xc60 3.0 t6 awd high luxury 304cv 3.0 t6 awd high luxury 304cv 3.0'
#  'volvo xc60 3.0 t6 high lux r-design 304cv at awd 3.0 t6 high lux r-design 304cv at awd 3.0'
#  'volvo xc60 t5 240cv t5 240cv 2.0'
#  'volvo xc60 3.0 t6 awd high plus 304cv 3.0 t6 awd high plus 304cv 3.0'
#  'volvo xc60 2.0 t5 awd high plus 240cv 2.0 t5 awd high plus 240cv 2.0'
#  'volvo xc60 t6 inscription 320hp t6 inscription 320hp 320hp'
#  'volvo xc60 3.0 t6 high luxury awd 3.0 t6 high luxury awd 3.0'
#  'volvo xc60 2.5 t5 inscription 2.5 t5 inscription 2.5']

# %% [markdown]
# Borramos los autos que tienen precios sin sentidos (muy bajos)

# %%
#borrar un dato que no tiene sentido
data = data.drop(data[data['Precio'] < 1000 ].index)

# %% [markdown]
# Arreglamos los kilómetros:

# %%
# Eliminar ' km' y convertir a enteros
data['Kilómetros'] = data['Kilómetros'].replace(' km', '', regex=True).astype(int)

# Reiniciar el índice para asegurarse de que es continuo
data.reset_index(drop=True, inplace=True)

# Aplicar las reglas de sustitución usando .loc para una indexación segura
for i in range(len(data)):
    if data.loc[i, 'Kilómetros'] in [111, 1111, 11111, 111111, 1111111, 99999, 999999, 9999999]:
        data.loc[i, 'Kilómetros'] = data.loc[i, 'Edad'] * 10000

# %% [markdown]
# Guardamos el CSV

# %%
data.to_csv('fixed_dataset.csv', index=True)
